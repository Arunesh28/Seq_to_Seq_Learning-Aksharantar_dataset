# %%
from __future__ import unicode_literals, print_function, division
import unicodedata
import numpy as np
import pandas as pd
from io import open
import random
import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
import random
import wandb
import re

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## DATA PROCESSING

# %%
SOS_token = 0
EOS_token = 1

class Lang:
    def __init__(self, name):
        self.name = name
        self.chr2index = {}
        self.chr2count = {}
        self.index2chr = {0: "$", 1: "#"}
        self.n_chrs = 2 

    def addword(self, word):
        for ch in word:
            self.addchr(ch)

    def addchr(self, ch):
        if ch not in self.chr2index:
            self.chr2index[ch] = self.n_chrs
            self.chr2count[ch] = 1
            self.index2chr[self.n_chrs] = ch
            self.n_chrs += 1
        else:
            self.chr2count[ch] += 1

# %%
MAX_LENGTH = 25
# def unicodeToAscii(s):
#     return ''.join(
#         c for c in unicodedata.normalize('NFD', s)
#         if unicodedata.category(c) != 'Mn'
#     )


# def normalizeString(s):
#     s = unicodeToAscii(s.strip())
#     s = re.sub(r"([.!?])", r" \1", s)
#     s = re.sub(r"[^a-zA-Z.!?]+", r" ", s)
#     return s

# %%
def readLangs(lang1,lang2):
    pairs = ()
    for i in ['train','valid','test']:
        fd = open('aksharantar_sampled/'+lang2+'/'+lang2+'_'+i+'.csv')
        lines = fd.read().strip().split('\n')
        pairs += ([[s for s in l.split(',')] for l in lines],)
    return pairs

# %%
OUTPUT_LANGUAGE = "mni"

input_lang = Lang("eng")
output_lang = Lang(OUTPUT_LANGUAGE)
train_pairs,valid_pairs,test_pairs = readLangs("eng",OUTPUT_LANGUAGE)

for pair in train_pairs:
    input_lang.addword(pair[0])
    output_lang.addword(pair[1])

# %%
def indexesFromWord(lang, word):
    return [lang.chr2index[ch] for ch in word]


def tensorFromWord(lang,word):
    indexes = indexesFromWord(lang, word)
    indexes.append(EOS_token)
    return torch.tensor(indexes, dtype=torch.long, device=device).view(-1, 1)


def tensorsFromPair(pair):
    input_tensor = tensorFromWord(input_lang, pair[0])
    target_tensor = tensorFromWord(output_lang, pair[1])
    return (input_tensor, target_tensor)

# %% [markdown]
# ## ENCODER

# %%
class EncoderRNN(nn.Module):
    def __init__(self, input_size, embedding_size, hidden_layer_size, num_encoder_layers, cell_type, dropout_prob, bidirectional):
      super(EncoderRNN, self).__init__()
      self.input_size = input_size
      self.hidden_layer_size = hidden_layer_size
      self.num_encoder_layers = num_encoder_layers
      self.cell_type = cell_type

      self.embedding = nn.Embedding(self.input_size, embedding_size)

      if cell_type == 'RNN':
        self.rnn = nn.RNN(input_size = embedding_size, hidden_size = hidden_layer_size, num_layers = num_encoder_layers, dropout = dropout_prob, bidirectional = bidirectional)
      elif cell_type == 'LSTM':
        self.rnn = nn.LSTM(input_size = embedding_size, hidden_size = hidden_layer_size, num_layers = num_encoder_layers, dropout = dropout_prob, bidirectional = bidirectional)
      elif cell_type == 'GRU':
        self.rnn = nn.GRU(input_size = embedding_size, hidden_size = hidden_layer_size, num_layers = num_encoder_layers, dropout = dropout_prob, bidirectional = bidirectional)
      self.dropout = nn.Dropout(dropout_prob)
      self.D = 1
      if bidirectional == True :
        self.D = 2

    def forward(self, input_tensor, prev_hidden, prev_cell = None):
      embedded = self.embedding(input_tensor).view(1,-1)
      embedded = self.dropout(embedded)
      if self.cell_type == 'RNN':
        output, hidden = self.rnn(embedded,prev_hidden)
      elif self.cell_type == 'LSTM':
        output, (hidden,cell) = self.rnn(embedded,(prev_hidden,prev_cell))
        return output, (hidden,cell)
      elif self.cell_type == 'GRU':
        output, hidden = self.rnn(embedded,prev_hidden)
        
      return output,hidden

    def initHidden(self):
      if self.cell_type == 'LSTM':
        hidden = torch.zeros(self.D*self.num_encoder_layers,self.hidden_layer_size,device = device)
        cell = torch.zeros(self.D*self.num_encoder_layers,self.hidden_layer_size,device = device)
        return hidden,cell
      else :
        hidden = torch.zeros(self.D*self.num_encoder_layers,self.hidden_layer_size,device = device)
      return hidden

# %% [markdown]
# ## DECODER

# %%
# class Decoder

class DecoderRNN(nn.Module):
  def __init__(self, output_size, embedding_size, hidden_layer_size, num_decoder_layers, cell_type, dropout_prob, bidirectional):
    super(DecoderRNN, self).__init__()
    self.output_size = output_size
    self.hidden_layer_size = hidden_layer_size
    self.num_decoder_layers = num_decoder_layers
    self.cell_type = cell_type
    self.embedding_size = embedding_size
    self.embedding = nn.Embedding(output_size, embedding_size)
   
    if cell_type == 'RNN':
      self.rnn = nn.RNN(input_size = embedding_size, hidden_size = hidden_layer_size, num_layers = num_decoder_layers, dropout = dropout_prob, bidirectional = bidirectional)
    elif cell_type == 'LSTM':
      self.rnn = nn.LSTM(input_size = embedding_size, hidden_size = hidden_layer_size, num_layers = num_decoder_layers, dropout = dropout_prob, bidirectional = bidirectional)
    elif cell_type == 'GRU':
      self.rnn = nn.GRU(input_size = embedding_size, hidden_size = hidden_layer_size, num_layers = num_decoder_layers, dropout = dropout_prob, bidirectional = bidirectional)
      
    self.D = 1
    if bidirectional == True :
      self.D = 2
      
    self.dropout = nn.Dropout(dropout_prob)
    self.out = nn.Linear(self.D*hidden_layer_size, output_size)
    self.softmax = nn.LogSoftmax(dim = 1)
      
  def forward(self, input_tensor, prev_hidden, prev_cell = None):
    embedded = self.embedding(input_tensor).view(1,-1)
    embedded = F.relu(embedded)
    embedded = self.dropout(embedded)
    
    if self.cell_type == 'RNN':
      output, hidden = self.rnn(embedded,prev_hidden)
      
    elif self.cell_type == 'LSTM':
      output,(hidden,cell) = self.rnn(embedded,(prev_hidden,prev_cell))
    
    elif self.cell_type == 'GRU':
      output, hidden = self.rnn(embedded,prev_hidden)

    output = self.softmax(self.out(output))

    if self.cell_type == 'LSTM':
      return output,(hidden,cell)
    
    return output, hidden

# %%
def train(input_tensor,target_tensor,encoder,decoder,encoder_optimizer,decoder_optimizer,criterion,max_length = MAX_LENGTH,teacher_forcing_ratio = 0.5):
    
    if encoder.cell_type == 'LSTM':
      encoder_hidden,encoder_cell = encoder.initHidden()
    else :
      encoder_hidden = encoder.initHidden()
    
    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()
    
    input_length = input_tensor.size(0)
    target_length = target_tensor.size(0)
    
    encoder_outputs = torch.zeros(max_length, encoder.D*encoder.hidden_layer_size, device=device)
    
    loss = 0
    
    for ei in range(input_length):
      if encoder.cell_type == 'LSTM':
        encoder_output,(encoder_hidden,encoder_cell) = encoder(input_tensor = input_tensor[ei],prev_hidden = encoder_hidden,prev_cell = encoder_cell)
      else :
        encoder_output, encoder_hidden = encoder(input_tensor = input_tensor[ei], prev_hidden = encoder_hidden)
      # print(encoder_output.size())
      encoder_outputs[ei] = encoder_output[0]
      
    decoder_input = torch.tensor([[SOS_token]],device=device)
    # decoder_outputs = torch.zeros(target_length)
    decoder_hidden = encoder_hidden
    if decoder.cell_type == 'LSTM':
      decoder_cell = encoder_cell
    
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing :
      for di in range(target_length):
        if decoder.cell_type == 'LSTM':
          decoder_output,(decoder_hidden,decoder_cell) = decoder(input_tensor = decoder_input,prev_hidden = decoder_hidden,prev_cell = decoder_cell)
        else:
          decoder_output,decoder_hidden = decoder(decoder_input,decoder_hidden)
        loss += criterion(decoder_output, target_tensor[di])
        decoder_input = target_tensor[di]

    else :
      for di in range(target_length):
        if decoder.cell_type == 'LSTM':
          decoder_output,(decoder_hidden,decoder_cell) = decoder(input_tensor = decoder_input,prev_hidden = decoder_hidden,prev_cell = decoder_cell)
        else:
          decoder_output,decoder_hidden = decoder(decoder_input,decoder_hidden)
        topv, topi = decoder_output.topk(1)
        decoder_input = topi.squeeze().detach()
        loss += criterion(decoder_output, target_tensor[di])
        if decoder_input.item() == EOS_token:
          break
    
    loss.backward()
    
    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %%
training_pairs = [tensorsFromPair(pair) for pair in train_pairs]
def trainIters(encoder,decoder,encoder_optimizer,decoder_optimizer,criterion):
    
    training_loss = 0
    it = 0
    for pair in training_pairs:
        input_tensor = pair[0]
        target_tensor = pair[1]
        loss = train(input_tensor,target_tensor,encoder,decoder,encoder_optimizer,decoder_optimizer,criterion)
        training_loss += loss
        # if it % 500 == 0:
        #     print(it,"words done")
        it += 1
    return training_loss/len(training_pairs)

# %%
def evaluate(encoder,decoder,word,target = None,criterion = None,max_length = MAX_LENGTH):
    with torch.no_grad():
        input_tensor = tensorFromWord(input_lang,word)
        input_length = input_tensor.size()[0]
        target_length = 0
        if target != None:
            target_tensor = tensorFromWord(output_lang,target)
            target_length = target_tensor.size(0)
        
        loss = 0
        
        if encoder.cell_type == 'LSTM':
            encoder_hidden,encoder_cell = encoder.initHidden()
        else :
            encoder_hidden = encoder.initHidden()
            
        encoder_outputs = torch.zeros(max_length,encoder.D*encoder.hidden_layer_size,device=device)
        
        for ei in range(input_length):
            if encoder.cell_type == 'LSTM':
                encoder_output,(encoder_hidden,encoder_cell) = encoder(input_tensor = input_tensor[ei],prev_hidden = encoder_hidden,prev_cell = encoder_cell)
            else :
                encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]
        
        decoder_input = torch.tensor([[SOS_token]],device=device)
        decoder_hidden = encoder_hidden
        if decoder.cell_type == 'LSTM':
            decoder_cell = encoder_cell
            
        decoded_word = ''
        

        for di in range(max_length):
            if decoder.cell_type == 'LSTM':
                decoder_output,(decoder_hidden,decoder_cell) = decoder(input_tensor = decoder_input,prev_hidden = decoder_hidden,prev_cell = decoder_cell)
            else:
                decoder_output,decoder_hidden = decoder(decoder_input,decoder_hidden)
            topv, topi = decoder_output.topk(1)
            
            if di<target_length:
                loss += criterion(decoder_output,target_tensor[di])
                
            if topi.item() == EOS_token:
                decoded_word += '#'
                break
            else :
                decoded_word += output_lang.index2chr[topi.item()]
                
            decoder_input = topi.squeeze().detach()
        
        return decoded_word,loss
    
def eval_acc_test(encoder,decoder,pairs,criterion = None):
    count = 0
    tot_loss = 0
    for pair in pairs:
        pred_word,loss = evaluate(encoder,decoder,pair[0],target=pair[1],criterion=criterion)
        tot_loss += loss
        print('>', pair[0])
        print('=', pair[1])
        print('<',pred_word)
        if pred_word[:-1] == pair[1] : count += 1
    return float(count/len(pairs)),float(tot_loss/(len(pairs)))
            
def evaluateRandomly(encoder,decoder,n=10):
    for i in range(n):
        pair = random.choice(train_pairs[:10])
        print('>', pair[0])
        print('=', pair[1])
        output_word = evaluate(encoder, decoder, pair[0])
        print('<', output_word)
        print('')

def eval_acc(encoder,decoder,pairs,criterion = None):
    count = 0
    tot_loss = 0
    for pair in pairs:
        pred_word,loss = evaluate(encoder,decoder,pair[0],target=pair[1],criterion=criterion)
        tot_loss += loss
        if pred_word[:-1] == pair[1] : count += 1
    return float(count/len(pairs)),tot_loss

def run(encoder,decoder,encoder_optimizer,decoder_optimizer,criterion,epochs):
    for epoch in range(epochs): 
        train_loss = trainIters(encoder=encoder,decoder=decoder,encoder_optimizer=encoder_optimizer,decoder_optimizer=decoder_optimizer,criterion = criterion)
        train_acc,_ = eval_acc(encoder,decoder,random.sample(train_pairs,1000),criterion)
        valid_acc,valid_loss = eval_acc(encoder,decoder,valid_pairs,criterion)
        print("Epoch : %d, Training Loss : %f, Training Accuracy : %f, Validation Loss = %f, Validation Accuracy : %f" % (epoch+1,train_loss,train_acc,valid_loss,valid_acc))

# %% [markdown]
# ## Training

# %%
'''
input_size = input_lang.n_chrs
output_size = output_lang.n_chrs
embedding_size = 128
hidden_layer_size = 128
num_layers = 3
cell_type = 'GRU'
dropout_prob = 0.2
learning_rate = 0.001
bidirectional = False
epochs = 10

encoder = EncoderRNN(input_size=input_size,embedding_size=embedding_size,hidden_layer_size=hidden_layer_size,num_encoder_layers=num_layers,cell_type=cell_type,dropout_prob=dropout_prob,bidirectional=bidirectional).to(device)
decoder = DecoderRNN(output_size=output_size,embedding_size=embedding_size,hidden_layer_size=hidden_layer_size,num_decoder_layers=num_layers,cell_type=cell_type,dropout_prob=dropout_prob,bidirectional=bidirectional).to(device)
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
criterion = nn.NLLLoss()
run(encoder,decoder,encoder_optimizer,decoder_optimizer,criterion,epochs)
'''

# %% [markdown]
# ## Best Hyperparamters

# %%
input_size = input_lang.n_chrs
output_size = output_lang.n_chrs
embedding_size = 128
hidden_layer_size = 128
num_layers = 3
cell_type = 'GRU'
dropout_prob = 0.2
learning_rate = 0.001
bidirectional = False
epochs = 10

encoder = EncoderRNN(input_size=input_size,embedding_size=embedding_size,hidden_layer_size=hidden_layer_size,num_encoder_layers=num_layers,cell_type=cell_type,dropout_prob=dropout_prob,bidirectional=bidirectional).to(device)
decoder = DecoderRNN(output_size=output_size,embedding_size=embedding_size,hidden_layer_size=hidden_layer_size,num_decoder_layers=num_layers,cell_type=cell_type,dropout_prob=dropout_prob,bidirectional=bidirectional).to(device)
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
criterion = nn.NLLLoss()
run(encoder,decoder,encoder_optimizer,decoder_optimizer,criterion,epochs)
# Out:
# Epoch : 1, Training Loss : 1.362635, Training Accuracy : 0.281000, Validation Loss = 26800.619141, Validation Accuracy : 0.288344
# Epoch : 2, Training Loss : 0.772756, Training Accuracy : 0.373000, Validation Loss = 20970.072266, Validation Accuracy : 0.381902
# Epoch : 3, Training Loss : 0.667147, Training Accuracy : 0.420000, Validation Loss = 21635.722656, Validation Accuracy : 0.405215
# Epoch : 4, Training Loss : 0.628885, Training Accuracy : 0.396000, Validation Loss = 21198.619141, Validation Accuracy : 0.408589
# Epoch : 5, Training Loss : 0.610030, Training Accuracy : 0.451000, Validation Loss = 20661.283203, Validation Accuracy : 0.447546
# Epoch : 6, Training Loss : 0.611814, Training Accuracy : 0.474000, Validation Loss = 19410.439453, Validation Accuracy : 0.446319
# Epoch : 7, Training Loss : 0.605052, Training Accuracy : 0.469000, Validation Loss = 20435.736328, Validation Accuracy : 0.424540
# Epoch : 8, Training Loss : 0.604192, Training Accuracy : 0.440000, Validation Loss = 20448.294922, Validation Accuracy : 0.434663
# Epoch : 9, Training Loss : 0.601070, Training Accuracy : 0.442000, Validation Loss = 20363.525391, Validation Accuracy : 0.446012
# Epoch : 10, Training Loss : 0.611343, Training Accuracy : 0.439000, Validation Loss = 19858.363281, Validation Accuracy : 0.430061

# %%
test_accuracy,test_loss = eval_acc_test(encoder,decoder,test_pairs,criterion)
print("Test Accuracy : %f" % (test_accuracy))
# Out:
# > heidelbergceat
# = ꯍꯥꯢꯗꯜꯕꯔꯒꯁꯤꯠ
# < ꯍꯩꯗꯦꯛꯇꯦꯔꯦꯡꯁ#
# > pakhangpana
# = ꯄꯥꯈꯪꯄꯅ
# < ꯄꯥꯈꯪꯄꯅ#
# > likla
# = ꯂꯤꯛꯂꯥ
# < ꯂꯤꯛꯂ#
# > famdengba
# = ꯐꯝꯗꯦꯡꯕ
# < ꯐꯝꯗꯦꯡꯕ#
# > primavera
# = ꯄ꯭ꯔꯤꯃꯥꯚꯦꯔꯥ
# < ꯄ꯭ꯃꯥꯃꯥꯔꯔ#
# > reading
# = ꯔꯤꯗꯤꯡ
# < ꯔꯦꯗꯤꯡ#
# > vista
# = ꯕꯤꯁꯇꯥ
# < ꯚꯤꯁꯇ#
# > shamjetshabam
# = ꯁꯝꯖꯦꯠꯁꯥꯕꯝ
# < ꯁꯝꯖꯤꯖꯥꯕꯥ#
# > watts
# = ꯋꯥꯠꯁ
# < ꯋꯠꯠ#
# > financiers
# = ꯐꯥꯢꯅꯥꯟꯁꯤꯑꯔꯁ
# < ꯐꯤꯅꯥꯟꯇꯔꯁꯁ#
# > ngangkhaleima
# = ꯉꯥꯡꯈꯂꯩꯃ
# < ꯉꯥꯡꯈꯩꯃꯩ#
# > waterbury
# = ꯋꯥꯇꯔꯕꯔꯤ
# < ꯋꯥꯇꯦꯔꯔꯤ#
# > ray
# = ꯔꯦ
# < ꯔꯥꯌꯥ#
# > phampalda
# = ꯐꯝꯄꯥꯜꯗ
# < ꯐꯝꯄꯥꯜꯗ#
# > pollabatungdana
# = ꯄꯣꯜꯂꯕꯇꯨꯡꯗꯅ
# < ꯄꯣꯜꯂꯕꯥꯇꯥꯡꯗꯅ#
# > tumukhong
# = ꯇꯨꯃꯨꯈꯣꯡ
# < ꯇꯨꯃꯆꯣꯡ#
# > shillong
# = ꯁꯤꯂꯣꯡ
# < ꯁꯤꯜꯂꯣꯡ#
# > hillsboro
# = ꯍꯤꯜꯁꯕꯣꯔꯣ
# < ꯍꯤꯜꯁꯣꯔꯣ#
# > londada
# = ꯂꯣꯟꯗꯥꯗ
# < ꯂꯣꯟꯗꯥꯗ#
# > dubey
# = ꯗꯨꯕꯦ
# < ꯗꯨꯌꯦꯌꯥ#
# > dikshit
# = ꯗꯤꯛꯁꯤꯠ
# < ꯗꯤꯛꯁꯤꯇ#
# > mut
# = ꯃꯨꯠ
# < ꯃꯨꯠ#
# > hengatlakpa
# = ꯍꯦꯟꯒꯠꯂꯛꯄ
# < ꯍꯦꯡꯒꯠꯂꯛꯄ#
# > collins
# = ꯀꯣꯂꯤꯟꯁ
# < ꯀꯣꯜꯁꯤꯟꯁ#
# > sanpa
# = ꯁꯥꯟꯄ
# < ꯁꯥꯟꯄ#
# > zehra
# = ꯖꯦꯍꯔꯥ
# < ꯍꯦꯚꯔꯥ#
# > chahichaadadi
# = ꯆꯍꯤꯆꯥꯗꯗꯤ
# < ꯆꯍꯤꯆꯥꯗꯤꯗ#
# > quraishi
# = ꯀꯨꯔꯥꯢꯁꯤ
# < ꯀꯧꯔꯁꯤ#
# > challi
# = ꯆꯜꯂꯤ
# < ꯆꯜꯂꯤ#
# > arvada
# = ꯑꯔꯚꯥꯗꯥ
# < ꯑꯔꯚꯗ#
# > kumari
# = ꯀꯨꯃꯥꯔꯤ
# < ꯀꯨꯃꯔꯤ#
# > pambei
# = ꯄꯥꯝꯕꯩ
# < ꯄꯥꯝꯕꯩ#
# > sakkhangdaba
# = ꯁꯛꯈꯪꯗꯕ
# < ꯁꯛꯈꯪꯕ#
# > adumak
# = ꯑꯗꯨꯃꯛ
# < ꯑꯗꯨꯛꯛ#
# > waters
# = ꯋꯥꯇꯔꯁ
# < ꯋꯥꯇꯦꯁ#
# > bhattacharya
# = ꯚꯠꯇꯆꯥꯔꯌ
# < ꯚꯠꯠꯅꯔꯥ#
# > shivamogga
# = ꯁꯤꯕꯃꯣꯒꯥ
# < ꯁꯤꯕꯃꯣꯒ#
# > dimasa
# = ꯗꯤꯃꯥꯁꯥ
# < ꯗꯤꯔꯥꯁꯥ#
# > firaal
# = ꯐꯤꯔꯥꯜ
# < ꯐꯤꯔꯜ#
# > laanngamduna
# = ꯂꯥꯟꯉꯝꯗꯨꯅ
# < ꯂꯥꯟꯉꯝꯗꯨꯅ#
# > pumnamakki
# = ꯄꯨꯝꯅꯃꯛꯀꯤ
# < ꯄꯨꯝꯅꯛꯈꯤ#
# > medina
# = ꯃꯦꯗꯤꯅꯥ
# < ꯃꯦꯗꯤꯅ#
# > mangpa
# = ꯃꯥꯡꯄ
# < ꯃꯥꯄꯥ#
# > burleson
# = ꯕꯔꯜꯁꯟ
# < ꯕꯨꯔꯦꯜꯁꯟ#
# > ngaareima
# = ꯉꯥꯔꯩꯃ
# < ꯉꯥꯔꯩꯃ#
# > salka
# = ꯁꯜꯀ
# < ꯁꯥꯂꯀ#
# > mirolgi
# = ꯃꯤꯔꯣꯜꯒꯤ
# < ꯃꯤꯔꯣꯜꯒꯤ#
# > dahlan
# = ꯗꯥꯍꯂꯥꯟ
# < ꯗꯥꯍꯟ#
# > expleo
# = ꯑꯦꯛꯁꯄ꯭ꯂꯤꯑꯣ
# < ꯑꯦꯀꯣꯀꯦ#
# > aibani
# = ꯑꯏꯕꯅꯤ
# < ꯑꯥꯕꯅꯤ#
# > guduri
# = ꯒꯨꯗꯨꯔꯤ
# < ꯗꯨꯗꯥꯔꯤꯔꯤ#
# > seirangbani
# = ꯁꯩꯔꯥꯡꯕꯅꯤ
# < ꯁꯩꯔꯥꯟꯕꯤꯅꯤ#
# > manna
# = ꯃꯥꯟꯅ
# < ꯃꯥꯟꯅ#
# > pravesh
# = ꯄ꯭ꯔꯚꯦꯁ
# < ꯄ꯭ꯚꯥꯁꯦ#
# > wave
# = ꯋꯦꯕ
# < ꯋꯥꯚꯦ#
# > sengar
# = ꯁꯦꯟꯒꯔ
# < ꯁꯦꯉꯔ#
# > rishiraj
# = ꯔꯤꯁꯤꯔꯥꯖ
# < ꯔꯤꯁꯔꯔ#
# > laana
# = ꯂꯥꯅ
# < ꯂꯥꯎꯅ#
# > telelinks
# = ꯇꯦꯂꯦꯂꯤꯡꯛꯁ
# < ꯇꯦꯂꯦꯜꯦꯦꯌꯦꯟꯁ#
# > americada
# = ꯑꯃꯦꯔꯤꯀꯥꯗ
# < ꯑꯃꯦꯀꯤꯗ#
# > manungsida
# = ꯃꯅꯨꯡꯁꯤꯗ
# < ꯃꯅꯨꯡꯁꯤꯡꯗ#
# > fanglakkhi
# = ꯐꯪꯂꯛꯈꯤ
# < ꯐꯪꯂꯛꯈꯤ#
# > plainfield
# = ꯄ꯭ꯂꯦꯟꯐꯤꯜꯗ
# < ꯄ꯭ꯂꯦꯟꯤꯦꯟꯗꯥꯜ#
# > yambada
# = ꯌꯥꯝꯕꯗ
# < ꯌꯥꯝꯕꯗ#
# > ima
# = ꯏꯃꯥ
# < ꯏꯃꯥ#
# > sterlite
# = ꯁ꯭ꯇꯔꯂꯥꯢꯠ
# < ꯁꯦꯇꯦꯦꯦꯦ#
# > bauer
# = ꯕꯥꯎꯑꯔ
# < ꯕꯥꯔꯔ#
# > shankdhar
# = ꯁꯪꯛꯙꯔ
# < ꯁꯟꯟꯔꯔ#
# > hugli
# = ꯍꯨꯒ꯭ꯂꯤ
# < ꯍꯨꯒꯂꯤ#
# > nemba
# = ꯅꯦꯝꯕ
# < ꯅꯦꯝꯕ#
# > rizvi
# = ꯔꯤꯖꯕꯤ
# < ꯔꯤꯕꯤ#
# > rafael
# = ꯔꯥꯐꯥꯑꯦꯜ
# < ꯔꯥꯐꯐꯦꯜ#
# > niphumapan
# = ꯅꯤꯐꯨꯃꯥꯄꯟ
# < ꯅꯤꯐꯨꯃꯥꯟ#
# > enggadabadagi
# = ꯏꯪꯒꯗꯕꯗꯒꯤ
# < ꯏꯪꯒꯥꯗꯕꯒꯤ#
# > sasaram
# = ꯁꯥꯁꯔꯥꯝ
# < ꯁꯥꯁꯝ#
# > lara
# = ꯂꯥꯔꯥ
# < ꯂꯥꯔꯥ#
# > ten
# = ꯇꯦꯟ
# < ꯇꯦꯟ#
# > saruk
# = ꯁꯔꯨꯛ
# < ꯁꯔꯨꯛ#
# > czech
# = ꯓꯦꯛ
# < ꯁꯦꯆꯆ#
# > nag
# = ꯅꯦꯒ
# < ꯅꯥ#
# > saada
# = ꯁꯥꯗ
# < ꯁꯥꯗ#
# > leiphamna
# = ꯂꯩꯐꯝꯅ
# < ꯂꯩꯐꯝꯅ#
# > waareng
# = ꯋꯥꯔꯦꯡ
# < ꯋꯥꯔꯦꯡ#
# > mannaramde
# = ꯃꯥꯟꯅꯔꯝꯗꯦ
# < ꯃꯥꯟꯅꯔꯃꯥ#
# > asuppa
# = ꯑꯁꯨꯞꯄ
# < ꯑꯁꯨꯞꯄ#
# > kakinada
# = ꯀꯥꯀꯤꯅꯥꯗꯥ
# < ꯀꯥꯀꯤꯗꯗ#
# > mityeng
# = ꯃꯤꯠꯌꯦꯡ
# < ꯃꯤꯇꯦꯡ#
# > moleculesinggi
# = ꯃꯣꯂꯦꯀꯨꯜꯁꯤꯡꯒꯤ
# < ꯃꯣꯄꯦꯀꯦꯜꯁꯤꯡ#
# > hathor
# = ꯍꯊꯣꯔ
# < ꯍꯥꯊꯣꯔꯔꯤ#
# > kanagumba
# = ꯀꯅꯥꯒꯨꯝꯕ
# < ꯀꯅꯨꯝꯕ#
# > kangbagi
# = ꯀꯪꯕꯒꯤ
# < ꯀꯪꯕꯒꯤ#
# > semnanaba
# = ꯁꯦꯝꯅꯅꯕ
# < ꯁꯦꯝꯅꯕ#
# > milk
# = ꯃꯤꯜꯛ
# < ꯃꯤꯛꯀ#
# > humfutaraataret
# = ꯍꯨꯝꯐꯨꯇꯔꯥꯇꯔꯦꯠ
# < ꯍꯨꯝꯐꯨꯇꯔꯦꯇꯇꯥ#
# > tolli
# = ꯇꯣꯜꯂꯤ
# < ꯇꯣꯜꯂꯤ#
# > chingsinfam
# = ꯆꯤꯡꯁꯤꯟꯐꯝ
# < ꯆꯤꯡꯁꯤꯟꯐꯝ#
# > thamphamni
# = ꯊꯝꯐꯝꯅꯤ
# < ꯊꯝꯐꯝꯅꯤ#
# > hammond
# = ꯍꯦꯝꯃꯟ꯭ꯗ
# < ꯍꯥꯃꯣꯟꯗ#
# > espinoza
# = ꯑꯦꯁꯄꯤꯅꯣꯖꯥ
# < ꯏꯁꯤꯌꯥꯒꯤ#
# > stein
# = ꯁ꯭ꯇꯥꯢꯟ
# < ꯁ꯭ꯇꯦꯟ#
# > chingsang
# = ꯆꯤꯡꯁꯥꯡ
# < ꯆꯤꯡꯁꯪ#
# > parag
# = ꯄꯔꯥꯒ
# < ꯄꯔꯥꯒ#
# > telheipagi
# = ꯇꯦꯜꯍꯩꯄꯒꯤ
# < ꯇꯦꯜꯍꯩꯄꯒꯤ#
# > ayangpa
# = ꯑꯌꯥꯡꯄ
# < ꯑꯌꯥꯡꯄ#
# > charei
# = ꯆꯔꯩ
# < ꯆꯥꯔꯩ#
# > lampaakta
# = ꯂꯝꯄꯥꯛꯇ
# < ꯂꯝꯄꯥꯛꯇ#
# > bhatpara
# = ꯚꯠꯄꯔꯥ
# < ꯚꯥꯠꯄꯔ#
# > paotaak
# = ꯄꯥꯎꯇꯥꯛ
# < ꯄꯥꯎꯇꯥꯛ#
# > laanjaonachingba
# = ꯂꯥꯟꯖꯥꯎꯅꯆꯤꯡꯕ
# < ꯂꯥꯟꯖꯥꯟꯍꯣꯟꯕꯤꯡ#
# > sayreville
# = ꯁꯦꯌꯔꯕꯤꯜ
# < ꯁꯥꯔꯦꯛꯕꯦꯂꯦ#
# > duar
# = ꯗꯨꯑꯥꯔ
# < ꯗꯨꯔ#
# > malhotra
# = ꯃꯜꯍꯣꯇ꯭ꯔꯥ
# < ꯃꯥꯍꯣꯠꯇꯔ#
# > phukpa
# = ꯐꯨꯛꯄ
# < ꯐꯨꯛꯄ#
# > greenwood
# = ꯒ꯭ꯔꯤꯟꯋꯨꯗ
# < ꯒ꯭ꯔꯦꯟꯋꯣꯣ#
# > saakei
# = ꯁꯥꯀꯩ
# < ꯁꯥꯀꯩ#
# > makhada
# = ꯃꯈꯥꯗ
# < ꯃꯈꯥꯗ#
# > siliconegi
# = ꯁꯤꯂꯤꯀꯣꯟꯒꯤ
# < ꯁꯤꯂꯤꯄꯣꯟꯒꯤ#
# > gail
# = ꯒꯦꯜ
# < ꯒꯥꯜꯂꯦ#
# > shaada
# = ꯁꯥꯗ
# < ꯁꯥꯗꯥ#
# > ingraji
# = ꯏꯪꯔꯥꯖꯤ
# < ꯏꯪꯔꯔꯤ#
# > nerolac
# = ꯅꯦꯔꯣꯂꯦꯛ
# < ꯅꯦꯔꯣꯜꯀ#
# > atingkokna
# = ꯑꯇꯤꯡꯀꯣꯛꯅ
# < ꯑꯇꯤꯡꯀꯣꯟꯅ#
# > hannagi
# = ꯍꯥꯟꯅꯒꯤ
# < ꯍꯥꯟꯅꯒꯤ#
# > montes
# = ꯃꯣꯟꯇꯦꯁ
# < ꯃꯣꯟꯇꯦꯁꯁ#
# > keisi
# = ꯀꯩꯁꯤ
# < ꯀꯩꯁꯤ#
# > mahadewi
# = ꯃꯍꯥꯗꯦꯋꯤ
# < ꯃꯍꯥꯗꯦꯤ#
# > thadok
# = ꯊꯥꯗꯣꯛ
# < ꯊꯥꯗꯣꯛ#
# > housing
# = ꯍꯥꯎꯖꯤꯡ
# < ꯍꯧꯁꯤꯡ#
# > liklaa
# = ꯂꯤꯛꯂꯥ
# < ꯂꯤꯛꯀꯥ#
# > gomashe
# = ꯒꯣꯃꯥꯁꯦ
# < ꯒꯣꯃꯁꯤ#
# > kaangpa
# = ꯀꯥꯡꯄ
# < ꯀꯥꯡꯄ#
# > seisak
# = ꯁꯩꯁꯛ
# < ꯁꯩꯁꯥꯛ#
# > pamnakhiba
# = ꯄꯥꯝꯅꯈꯤꯕ
# < ꯄꯥꯝꯅꯈꯤ#
# > kiran
# = ꯀꯤꯔꯟ
# < ꯀꯤꯔꯥꯟ#
# > thakhraba
# = ꯊꯥꯈ꯭ꯔꯕ
# < ꯊꯥꯈ꯭ꯔꯕ#
# > heilom
# = ꯍꯩꯂꯣꯝ
# < ꯍꯩꯂꯣꯝ#
# > mahaakka
# = ꯃꯍꯥꯛꯀ
# < ꯃꯍꯥꯛꯀ#
# > woonsocket
# = ꯋꯨꯟꯁꯣꯀꯦꯠ
# < ꯋꯣꯑꯦꯟꯁꯦꯠꯠ#
# > chadana
# = ꯆꯥꯗꯅ
# < ꯆꯗꯗꯅꯥ#
# > naoda
# = ꯅꯥꯎꯗ
# < ꯅꯥꯎꯗ#
# > meeoiba
# = ꯃꯤꯑꯣꯢꯕ
# < ꯃꯤꯑꯣꯢꯕ#
# > mapaapu
# = ꯃꯄꯥꯄꯨ
# < ꯃꯄꯥꯄꯨ#
# > thoudam
# = ꯊꯧꯗꯥꯝ
# < ꯊꯧꯗ#
# > sithou
# = ꯁꯤꯠꯍꯧ
# < ꯁꯤꯊꯧ#
# > shoaib
# = ꯁꯣꯑꯥꯢꯕ
# < ꯁꯣꯑꯕ#
# > kamputarna
# = ꯀꯝꯄꯨꯇꯔꯅ
# < ꯀꯝꯄꯨꯔꯥꯅ#
# > everett
# = ꯑꯦꯚꯔꯦꯠ
# < ꯏꯔꯦꯠ#
# > tezpur
# = ꯇꯦꯖꯄꯨꯔ
# < ꯇꯦꯄꯨ#
# > laion
# = ꯂꯥꯢꯑꯣꯟ
# < ꯂꯥꯢꯅꯣꯟ#
# > panthoipi
# = ꯄꯥꯟꯊꯣꯢꯄꯤ
# < ꯄꯥꯟꯊꯣꯢꯄꯤ#
# > nupaada
# = ꯅꯨꯄꯥꯗ
# < ꯅꯨꯄꯥꯗ#
# > humphunipan
# = ꯍꯨꯝꯐꯨꯅꯤꯄꯥꯟ
# < ꯍꯨꯝꯐꯨꯅꯅꯄꯥꯟ#
# > rana
# = ꯔꯥꯅꯥ
# < ꯔꯥꯅ#
# > design
# = ꯗꯤꯖꯥꯢꯟ
# < ꯗꯦꯁꯤꯡꯅꯤ#
# > ganore
# = ꯒꯅꯣꯔ
# < ꯒꯥꯅꯔꯦ#
# > hasni
# = ꯍꯁꯅꯤ
# < ꯍꯥꯁꯅꯤ#
# > koubagi
# = ꯀꯧꯕꯒꯤ
# < ꯀꯧꯕꯒꯤ#
# > lina
# = ꯂꯤꯅ
# < ꯂꯤꯅꯥ#
# > tenawaa
# = ꯇꯦꯅꯋꯥ
# < ꯇꯦꯅꯥꯥ#
# > washington
# = ꯋꯥꯁꯤꯡꯇꯟ
# < ꯋꯥꯁꯤꯡꯇꯣꯡ#
# > tankhibana
# = ꯇꯥꯟꯈꯤꯕꯅ
# < ꯇꯥꯟꯈꯤꯕꯅ#
# > amroha
# = ꯑꯝꯔꯣꯍꯥ
# < ꯑꯦꯃꯣꯔꯣ#
# > nifu
# = ꯅꯤꯐꯨ
# < ꯅꯤꯐꯨ#
# > kayatsingna
# = ꯀꯌꯥꯠꯁꯤꯡꯅ
# < ꯀꯌꯥꯠꯁꯤꯡꯅ#
# > yengluba
# = ꯌꯦꯡꯂꯨꯕ
# < ꯌꯦꯡꯂꯧꯕ#
# > tokpam
# = ꯇꯣꯛꯄꯝ
# < ꯇꯣꯛꯄꯝ#
# > kanglupsigi
# = ꯀꯥꯡꯂꯨꯞꯁꯤꯒꯤ
# < ꯀꯪꯂꯥꯞꯁꯤꯒꯤ#
# > khongthaang
# = ꯈꯣꯡꯊꯥꯡ
# < ꯈꯣꯡꯊꯪ#
# > til
# = ꯇꯤꯜ
# < ꯇꯤꯜ#
# > yumshaalon
# = ꯌꯨꯝꯁꯥꯂꯣꯟ
# < ꯌꯨꯝꯁꯥꯂꯣꯟ#
# > bombay
# = ꯕꯣꯝꯕꯦ
# < ꯕꯣꯝꯕꯥ#
# > chaadaa
# = ꯆꯥꯗꯥ
# < ꯆꯥꯗꯥ#
# > phani
# = ꯐꯅꯤ
# < ꯐꯅꯤ#
# > hangdokkhi
# = ꯍꯥꯡꯗꯣꯛꯈꯤ
# < ꯍꯥꯡꯗꯣꯛꯈꯤ#
# > bokaro
# = ꯕꯣꯀꯥꯔꯣ
# < ꯕꯣꯀꯀꯥꯔꯣ#
# > apakma
# = ꯑꯄꯛꯃꯥ
# < ꯑꯄꯥꯃꯃꯥ#
# > mangan
# = ꯃꯥꯡꯒꯟ
# < ꯃꯉꯥꯟ#
# > elangbam
# = ꯑꯦꯂꯥꯡꯕꯝ
# < ꯏꯂꯪꯕꯝ#
# > odisha
# = ꯑꯣꯗꯤꯁꯥ
# < ꯑꯣꯗꯤꯁꯥ#
# > plaines
# = ꯄ꯭ꯂꯦꯟꯁ
# < ꯄꯂꯂꯦꯅꯦꯁꯦ#
# > khunthoklam
# = ꯈꯨꯟꯊꯣꯛꯂꯝ
# < ꯈꯨꯟꯊꯣꯛꯂꯝ#
# > nyx
# = ꯅꯤꯛ꯭ꯁ
# < ꯅꯤꯛꯀ#
# > leitaaba
# = ꯂꯩꯇꯥꯕ
# < ꯂꯩꯇꯕ#
# > takpani
# = ꯇꯥꯛꯄꯅꯤ
# < ꯇꯥꯛꯄꯅꯤ#
# > singhaa
# = ꯁꯤꯡꯍꯥ
# < ꯁꯤꯡꯍꯥ#
# > anigi
# = ꯑꯅꯤꯒꯤ
# < ꯑꯅꯤꯒꯤ#
# > khaspur
# = ꯈꯥꯁꯄꯨꯔ
# < ꯈꯥꯄꯨꯔ#
# > hemet
# = ꯍꯦꯃꯦꯠ
# < ꯍꯦꯃꯦꯠ#
# > cruces
# = ꯀ꯭ꯔꯨꯁꯦꯁ
# < ꯀ꯭ꯀꯁꯁꯁ#
# > langdai
# = ꯂꯪꯗꯥꯢ
# < ꯂꯥꯡꯗꯤ#
# > repro
# = ꯔꯤꯄ꯭ꯔꯣ
# < ꯔꯦꯞꯔ#
# > safagadaba
# = ꯁꯥꯐꯒꯗꯕ
# < ꯁꯥꯐꯥꯕꯗꯕ#
# > communications
# = ꯀꯝꯃ꯭ꯌꯨꯅꯤꯀꯦꯁꯟ
# < ꯀꯣꯃꯨꯅꯤꯌꯦꯁꯁꯦꯟ#
# > yokkhatpa
# = ꯌꯣꯛꯈꯠꯄ
# < ꯌꯣꯈꯠꯈ#
# > ketharaga
# = ꯀꯦꯊꯔꯒ
# < ꯀꯦꯊꯔꯥꯒ#
# > sangleichaa
# = ꯁꯪꯂꯩꯆꯥ
# < ꯁꯪꯂꯩꯐꯥ#
# > miyengkhada
# = ꯃꯤꯌꯦꯡꯈꯥꯗ
# < ꯃꯤꯌꯦꯡꯈꯥꯗ#
# > vincent
# = ꯚꯤꯟꯁꯦꯟꯠ
# < ꯚꯤꯟꯆꯦꯟ#
# > godhra
# = ꯒꯣꯙ꯭ꯔ
# < ꯒꯣꯚꯔꯔ#
# > heblikar
# = ꯍꯦꯕ꯭ꯂꯤꯀꯥꯔ
# < ꯍꯦꯚꯤꯀꯔꯁ#
# > carbogen
# = ꯀꯥꯔꯕꯣꯖꯦꯟ
# < ꯀꯔꯔꯦꯦ#
# > charlottesville
# = ꯆꯥꯔꯂꯣꯠꯁꯚꯤꯜ
# < ꯆꯔꯣꯂꯦꯁꯦꯇ#
# > marlborough
# = ꯃꯥꯔꯜꯕꯣꯔꯣ
# < ꯃꯔꯔꯆꯧꯕ#
# > hurallaga
# = ꯍꯨꯔꯥꯜꯂꯒ
# < ꯍꯨꯔꯥꯜꯥꯒ#
# > chaoi
# = ꯆꯥꯎꯏ
# < ꯆꯥꯎꯣꯢ#
# > ungduna
# = ꯎꯪꯗꯨꯅ
# < ꯎꯨꯡꯗꯨꯅ#
# > moupwada
# = ꯃꯧꯄ꯭ꯋꯥꯗ
# < ꯃꯧꯞꯗ#
# > junagadh
# = ꯖꯨꯅꯥꯒꯔ
# < ꯖꯨꯅꯒꯗ#
# > theinaba
# = ꯊꯩꯅꯕ
# < ꯊꯩꯅꯕ#
# > fouba
# = ꯐꯧꯕ
# < ꯐꯧꯕ#
# > shaktakkhi
# = ꯁꯛꯇꯥꯛꯈꯤ
# < ꯁꯛꯇꯥꯛꯈꯤ#
# > shennong
# = ꯁꯦꯟꯅꯣꯡ
# < ꯁꯦꯟꯅꯣꯡ#
# > idukki
# = ꯏꯗꯨꯛꯀꯤ
# < ꯏꯗꯨꯛꯀꯤ#
# > chaahao
# = ꯆꯥꯍꯥꯎ
# < ꯆꯥꯍꯥ#
# > malda
# = ꯃꯥꯜꯗꯥ
# < ꯃꯜꯗꯥ#
# > mapangi
# = ꯃꯥꯄꯟꯒꯤ
# < ꯃꯄꯥꯟꯒꯤ#
# > ochoa
# = ꯑꯣꯀꯣꯑꯥ
# < ꯑꯣꯁꯥꯥꯥ#
# > wiliam
# = ꯋꯤꯂꯤꯌꯝ
# < ꯂꯤꯂꯥꯃꯝ#
# > accelya
# = ꯑꯦꯛꯁꯤꯂ꯭ꯌꯥ
# < ꯑꯦꯀꯦꯁꯤꯌꯥ#
# > mitra
# = ꯃꯤꯇ꯭ꯔ
# < ꯃꯤꯇ꯭ꯔꯥ#
# > bidar
# = ꯕꯤꯗꯔ
# < ꯕꯤꯗꯗꯔ#
# > ikhi
# = ꯏꯈꯤ
# < ꯏꯈꯤ#
# > ras
# = ꯔꯥꯁ
# < ꯔꯁꯁ#
# > protist
# = ꯄ꯭ꯔꯣꯇꯤꯁꯠ
# < ꯄ꯭ꯇꯣꯇꯤꯇꯁꯁ#
# > wareng
# = ꯋꯥꯔꯦꯡ
# < ꯋꯥꯔꯦꯡ#
# > bite
# = ꯕꯥꯢꯠ
# < ꯕꯤꯇꯦ#
# > sharif
# = ꯁꯥꯔꯤꯐ
# < ꯁꯔꯤꯐ#
# > enterprise
# = ꯑꯦꯟꯇꯔꯄ꯭ꯔꯥꯢꯁ
# < ꯏꯟꯀ꯭ꯔꯦꯁꯦ#
# > burmese
# = ꯕꯔꯃꯤꯖ
# < ꯕꯨꯔꯤꯁꯦ#
# > reilly
# = ꯔꯩꯂꯤ
# < ꯔꯦꯜꯂꯤ#
# > ateidi
# = ꯑꯇꯩꯗꯤ
# < ꯑꯇꯩꯗꯤ#
# > zuari
# = ꯖꯨꯑꯥꯔꯤ
# < ꯚꯨꯔꯔꯤ#
# > kanglupsingbu
# = ꯀꯥꯡꯂꯨꯞꯁꯤꯡꯕꯨ
# < ꯀꯪꯡꯂꯞꯞꯁꯤꯕ#
# > nalla
# = ꯅꯥꯜꯂꯥ
# < ꯅꯥꯂꯥ#
# > ahoubada
# = ꯑꯍꯧꯕꯗ
# < ꯑꯍꯧꯕꯗ#
# > azhar
# = ꯑꯓꯔ
# < ꯑꯚꯥꯔ#
# > mohandas
# = ꯃꯣꯍꯟꯗꯥꯁ
# < ꯃꯣꯍꯟꯁ#
# > koilaang
# = ꯀꯣꯢꯂꯥꯡ
# < ꯀꯣꯂꯤꯡ#
# > grande
# = ꯒ꯭ꯔꯥꯟꯗꯦ
# < ꯒ꯭ꯔꯦꯗꯦ#
# > kathoktuna
# = ꯀꯥꯊꯣꯛꯇꯨꯅ
# < ꯀꯠꯊꯣꯛꯇꯨꯅ#
# > sonnei
# = ꯁꯣꯟꯅꯩ
# < ꯁꯣꯟꯅꯩ#
# > sakhenba
# = ꯁꯛꯍꯦꯟꯕ
# < ꯁꯛꯈꯦꯟꯕ#
# > evanston
# = ꯑꯦꯚꯟꯁꯇꯟ
# < ꯏꯊꯟꯁꯦꯟ#
# > taanbagi
# = ꯇꯥꯟꯕꯒꯤ
# < ꯇꯥꯟꯕꯒꯤ#
# > waheibu
# = ꯋꯥꯍꯩꯕꯨ
# < ꯋꯥꯍꯩꯕꯕ#
# > baker
# = ꯕꯦꯀꯔ
# < ꯕꯥꯛꯔ#
# > uhalli
# = ꯎꯍꯜꯂꯤ
# < ꯎꯙꯜꯂꯤ#
# > churu
# = ꯆꯨꯔꯨ
# < ꯆꯨꯔꯨ#
# > kulal
# = ꯀꯨꯂꯥꯜ
# < ꯀꯨꯂꯜ#
# > kidwai
# = ꯀꯤꯗ꯭ꯋꯥꯢ
# < ꯀꯤꯗꯤ#
# > yangkheinipan
# = ꯌꯥꯡꯈꯩꯅꯤꯄꯥꯟ
# < ꯌꯥꯡꯈꯩꯅꯅꯥ#
# > dodson
# = ꯗꯣꯗꯁꯟ
# < ꯗꯣꯁꯣꯟ#
# > antioch
# = ꯑꯦꯟꯇꯤꯑꯣꯛ
# < ꯑꯦꯟꯇꯤꯡꯆꯣ#
# > phanglakkhi
# = ꯐꯪꯂꯛꯈꯤ
# < ꯐꯪꯛꯈꯈꯤ#
# > italydadi
# = ꯏꯇꯥꯂꯤꯗꯗꯤ
# < ꯏꯇꯥꯂꯤꯗꯦꯗꯤ#
# > bhramari
# = ꯚ꯭ꯔꯥꯃꯔꯤ
# < ꯚꯔꯔꯝꯃꯤ#
# > july
# = ꯖꯨꯂꯥꯢ
# < ꯖꯨꯜ#
# > springdale
# = ꯁ꯭ꯄ꯭ꯔꯤꯡꯗꯦꯜ
# < ꯁ꯭ꯄ꯭ꯄꯦꯟꯂ꯭ꯦꯦꯗ#
# > niphumaapan
# = ꯅꯤꯐꯨꯃꯥꯄꯟ
# < ꯅꯤꯐꯨꯃꯅꯥ#
# > pittsburg
# = ꯄꯤꯠꯁꯕꯔꯒ
# < ꯄꯤꯠꯔ꯭ꯔꯒ#
# > delhi
# = ꯗꯦꯜꯍꯤ
# < ꯗꯦꯜꯤꯤ#
# > kamduna
# = ꯀꯥꯝꯗꯨꯅ
# < ꯀꯝꯗꯨꯅ#
# > carlson
# = ꯀꯥꯔꯜꯁꯟ
# < ꯀꯥꯔꯣꯟꯁ#
# > kongsang
# = ꯀꯣꯡꯁꯥꯡ
# < ꯀꯣꯡꯁꯪ#
# > sayaangsinggi
# = ꯁꯌꯥꯡꯁꯤꯡꯒꯤ
# < ꯁꯥꯌꯥꯡꯁꯤꯡꯒꯤ#
# > machaak
# = ꯃꯆꯥꯛ
# < ꯃꯆꯥꯛ#
# > gurjar
# = ꯒꯨꯔꯖꯥꯔ
# < ꯖꯨꯔꯔ#
# > meelolna
# = ꯃꯤꯂꯣꯜꯅ
# < ꯃꯤꯂꯣꯂꯅ#
# > omar
# = ꯑꯣꯃꯥꯔ
# < ꯑꯣꯃꯔꯔ#
# > kougadabani
# = ꯀꯧꯒꯗꯕꯅꯤ
# < ꯀꯧꯒꯗꯕꯅꯤ#
# > fortis
# = ꯐꯣꯔꯇꯤꯁ
# < ꯐꯣꯔꯇꯁꯤꯁ#
# > herman
# = ꯍꯔꯃꯦꯟ
# < ꯍꯦꯔꯃꯅ#
# > lim
# = ꯂꯤꯝ
# < ꯂꯤꯝ#
# > manju
# = ꯃꯟꯖꯨ
# < ꯃꯟꯖꯨ#
# > casey
# = ꯀꯦꯁꯤ
# < ꯁꯥꯁꯦꯌ#
# > jews
# = ꯖ꯭ꯌꯨꯁ
# < ꯖꯦꯁꯁ#
# > roanoke
# = ꯔꯣꯑꯅꯣꯛ
# < ꯔꯣꯅꯥꯛ#
# > rallis
# = ꯔꯦꯂꯤꯁ
# < ꯔꯜꯂꯤꯁ#
# > tropical
# = ꯇ꯭ꯔꯣꯄꯤꯀꯦꯜ
# < ꯇ꯭ꯔꯤꯀꯣꯜ#
# > tokhaihallaga
# = ꯇꯣꯈꯥꯢꯍꯜꯂꯒ
# < ꯇꯣꯈꯥꯂꯣꯒ#
# > shivpuri
# = ꯁꯤꯕꯄꯨꯔꯤ
# < ꯁꯤꯔꯨꯨꯔꯔꯤ#
# > surat
# = ꯁꯨꯔꯠ
# < ꯁꯨꯔꯠ#
# > quick
# = ꯀꯨꯢꯛ
# < ꯀꯨꯢꯀꯨꯛ#
# > yonthokkhi
# = ꯌꯣꯟꯊꯣꯛꯈꯤ
# < ꯌꯣꯟꯊꯣꯈꯈꯤ#
# > loipi
# = ꯂꯣꯢꯄꯤ
# < ꯂꯣꯢꯄꯤ#
# > wylie
# = ꯋꯥꯢꯂꯤ
# < ꯋꯤꯂꯩ#
# > daha
# = ꯗꯍꯥ
# < ꯗꯥꯌꯥ#
# > mioisinggi
# = ꯃꯤꯑꯣꯢꯁꯤꯡꯒꯤ
# < ꯃꯤꯑꯣꯢꯁꯥꯁꯁꯤ#
# > waheini
# = ꯋꯥꯍꯩꯅꯤ
# < ꯋꯥꯍꯩꯅꯤ#
# > columbia
# = ꯀꯣꯂꯝꯕꯤꯑꯥ
# < ꯀ꯭ꯂꯝꯕꯝꯝꯝꯁꯤ#
# > thengnakhi
# = ꯊꯦꯡꯅꯈꯤ
# < ꯊꯦꯡꯅꯈꯈꯤ#
# > phaogatlaklibi
# = ꯐꯥꯎꯒꯠꯂꯛꯂꯤꯕꯤ
# < ꯐꯥꯎꯒꯠꯂꯤꯕꯤ#
# > osiris
# = ꯑꯣꯁꯤꯔꯤꯁ
# < ꯑꯣꯁꯤꯁꯔꯤ#
# > tidke
# = ꯇꯤꯔꯀꯦ
# < ꯇꯤꯗꯦ#
# > mipokpa
# = ꯃꯤꯄꯣꯛꯄ
# < ꯃꯤꯄꯣꯛꯄ#
# > barker
# = ꯕꯥꯔꯀꯔ
# < ꯕꯔꯔꯔ#
# > yemenda
# = ꯌꯦꯃꯦꯟꯗ
# < ꯌꯦꯃꯦꯟꯗ#
# > sonwani
# = ꯁꯣꯟꯋꯥꯅꯤ
# < ꯁꯣꯟꯅꯅꯤ#
# > pandam
# = ꯄꯥꯟꯗꯝ
# < ꯄꯥꯟꯗꯝ#
# > chandra
# = ꯆꯟꯗ꯭ꯔ
# < ꯆꯥꯟꯗ꯭ꯔꯦ#
# > adugiraane
# = ꯑꯗꯨꯒꯤꯔꯥꯅꯦ
# < ꯑꯗꯨꯔꯤꯌꯔꯦꯟꯅ#
# > tweets
# = ꯇ꯭ꯋꯤꯠꯁ
# < ꯇ꯭ꯊꯦꯁꯤꯟꯁ#
# > mayeksingbu
# = ꯃꯌꯦꯛꯁꯤꯡꯕꯨ
# < ꯃꯌꯦꯛꯁꯤꯡꯕꯨ#
# > thangyikum
# = ꯊꯥꯡꯌꯤꯀꯨꯝ
# < ꯊꯥꯌꯤꯃꯄꯌꯝ#
# > chellani
# = ꯆꯦꯂꯥꯅꯤ
# < ꯆꯦꯜꯂꯅꯤ#
# > lifestyle
# = ꯂꯥꯢꯐꯁ꯭ꯇꯥꯢꯜ
# < ꯂꯤꯐꯦꯠꯁꯦ#
# > laanli
# = ꯂꯥꯟꯂꯤ
# < ꯂꯥꯟꯂꯤ#
# > mamingda
# = ꯃꯃꯤꯡꯗ
# < ꯃꯃꯤꯡꯗ#
# > neemuch
# = ꯅꯤꯃꯆ
# < ꯅꯤꯃꯨꯆꯣ#
# > shulung
# = ꯁꯨꯂꯨꯡ
# < ꯁꯨꯂꯨꯡ#
# > pace
# = ꯄꯦꯁ
# < ꯄꯥꯇꯦ#
# > cheitharol
# = ꯆꯩꯊꯥꯔꯣꯜ
# < ꯆꯩꯊꯥꯔꯣꯜ#
# > reno
# = ꯔꯦꯅꯣ
# < ꯔꯦꯅꯣ#
# > durgavansh
# = ꯗꯨꯔꯒꯥꯚꯟꯁ
# < ꯗꯨꯔꯥꯡꯁꯁꯁꯁ#
# > taraamna
# = ꯇꯔꯥꯝꯅ
# < ꯇꯔꯦꯝꯅ#
# > infibeam
# = ꯏꯟꯐꯕꯤꯝ
# < ꯏꯟꯐꯤꯖꯝꯝꯕ#
# > smartspaces
# = ꯁ꯭ꯃꯥꯔꯠꯁ꯭ꯄꯦꯁꯁ
# < ꯁ꯭ꯔꯦꯠꯁꯦꯁ#
# > ayambada
# = ꯑꯌꯥꯝꯕꯗ
# < ꯑꯌꯥꯝꯕꯗ#
# > lothankhi
# = ꯂꯣꯠꯍꯟꯈꯤ
# < ꯂꯣꯠꯍꯟꯈꯤ#
# > awapham
# = ꯑꯋꯥꯐꯝ
# < ꯑꯋꯥꯐꯝ#
# > citysing
# = ꯁꯤꯇꯤꯁꯤꯡ
# < ꯁꯤꯠꯁꯤꯡ#
# > furit
# = ꯐꯨꯔꯤꯠ
# < ꯐꯨꯔꯤꯠ#
# > lakhmani
# = ꯂꯈꯃꯅꯤ
# < ꯂꯥꯈꯃꯅꯤ#
# > johari
# = ꯖꯣꯍꯥꯔꯤ
# < ꯖꯣꯍꯔꯤ#
# > kapole
# = ꯀꯄꯣꯂꯦ
# < ꯀꯥꯂꯂꯂꯦ#
# > nuwa
# = ꯅꯨꯋꯥ
# < ꯅꯨꯋꯥ#
# > rollins
# = ꯔꯣꯂꯤꯟꯁ
# < ꯔꯣꯜꯂꯤꯟꯁ#
# > sangba
# = ꯁꯥꯡꯕ
# < ꯁꯪꯕ#
# > asaagi
# = ꯑꯁꯥꯒꯤ
# < ꯑꯁꯥꯒꯤ#
# > sarasota
# = ꯁꯥꯔꯥꯁꯣꯇꯥ
# < ꯁꯔꯥꯁꯇ#
# > chanugi
# = ꯆꯅꯨꯒꯤ
# < ꯆꯅꯤꯒꯤ#
# > ataangba
# = ꯑꯇꯥꯡꯕ
# < ꯑꯇꯥꯡꯕ#
# > numitkhudinggi
# = ꯅꯨꯃꯤꯠꯈꯨꯗꯤꯡꯒꯤ
# < ꯅꯨꯃꯤꯡꯖꯤꯡꯒꯤ#
# > cementation
# = ꯁꯤꯃꯦꯟꯇꯦꯁꯟ
# < ꯁꯦꯃꯦꯟꯅꯣꯅꯤ#
# > sagatli
# = ꯁꯥꯒꯠꯂꯤ
# < ꯁꯥꯒꯠꯂꯤ#
# > nectar
# = ꯅꯦꯛꯇꯔ
# < ꯅꯦꯁꯔ#
# > ubada
# = ꯎꯕꯗ
# < ꯎꯕꯗ#
# > mamal
# = ꯃꯃꯜ
# < ꯃꯃꯥꯜ#
# > missoula
# = ꯃꯤꯖꯨꯂ
# < ꯃꯤꯁꯧꯀꯥꯂ#
# > sari
# = ꯁꯔꯤ
# < ꯁꯔꯤ#
# > mafamdubu
# = ꯃꯐꯝꯗꯨꯕꯨ
# < ꯃꯐꯝꯗꯕ#
# > khaanongpokta
# = ꯈꯥꯅꯣꯡꯄꯣꯛꯇ
# < ꯈꯥꯅꯣꯛꯇꯣꯇ#
# > disasterni
# = ꯗꯤꯖꯥꯁꯇꯔꯅꯤ
# < ꯗꯤꯁꯇꯔꯔꯅꯤ#
# > alkem
# = ꯑꯜꯀꯦꯝ
# < ꯑꯂꯦꯝꯁꯦꯝ#
# > ankeny
# = ꯑꯪꯀꯤꯅꯤ
# < ꯑꯦꯟꯅꯦꯅꯤ#
# > shailaputri
# = ꯁꯩꯂꯄꯨꯇ꯭ꯔꯤ
# < ꯁꯥꯂꯔꯦꯇꯔꯔꯔꯤ#
# > yumshalon
# = ꯌꯨꯝꯁꯥꯂꯣꯟ
# < ꯌꯨꯝꯁꯥꯂꯣꯟ#
# > cambodiagi
# = ꯀꯦꯝꯕꯣꯗꯤꯌꯥꯒꯤ
# < ꯀꯝꯝꯗꯕꯒꯤ#
# > akolkar
# = ꯑꯀꯣꯜꯀꯔ
# < ꯑꯀꯣꯛꯀꯔ#
# > plantation
# = ꯄ꯭ꯂꯥꯟꯇꯦꯁꯟ
# < ꯄ꯭ꯂꯥꯟꯇꯤꯟꯟ#
# > miller
# = ꯃꯤꯜꯂꯔ
# < ꯃꯤꯜꯂꯦꯔ#
# > touramba
# = ꯇꯧꯔꯝꯕ
# < ꯇꯧꯔꯝꯕ#
# > dixon
# = ꯗꯤꯛꯁꯟ
# < ꯗꯤꯑꯣꯟꯣꯟ#
# > loveland
# = ꯂꯕꯂꯦꯟꯗ
# < ꯂꯣꯚꯦꯦꯦꯟꯁ#
# > khamnung
# = ꯈꯝꯅꯨꯡ
# < ꯈꯝꯅꯨꯡ#
# > machak
# = ꯃꯆꯥꯛ
# < ꯃꯆꯥꯛ#
# > puducherry
# = ꯄꯨꯗꯨꯆꯦꯔꯤ
# < ꯄꯨꯗꯨꯆꯨꯔꯦ#
# > indianapolis
# = ꯏꯟꯗ꯭ꯌꯅꯥꯄꯂꯤꯁ
# < ꯏꯟꯗꯤꯔꯣꯢꯅꯤꯁꯁ#
# > kalratri
# = ꯀꯥꯜꯔꯥꯇ꯭ꯔꯤ
# < ꯀꯜꯕꯔꯇꯇꯇꯔꯇꯤ#
# > mattancheri
# = ꯃꯇꯥꯟꯆꯦꯔꯤ
# < ꯃꯇꯥꯟꯅꯔꯤ#
# > arambai
# = ꯑꯔꯥꯝꯕꯥꯢ
# < ꯑꯔꯥꯝꯕꯤ#
# > karaikal
# = ꯀꯔꯥꯢꯀꯥꯜ
# < ꯀꯔꯥꯀꯥꯂꯤꯜ#
# > cheithaarol
# = ꯆꯩꯊꯥꯔꯣꯜ
# < ꯆꯩꯊꯥꯔꯣꯜ#
# > ipakachouba
# = ꯏꯄꯥꯛꯑꯆꯧꯕ
# < ꯏꯄꯥꯎꯆꯕꯨꯕ#
# > kurukshetra
# = ꯀꯨꯔꯨꯛꯁꯦꯠꯇ꯭ꯔ
# < ꯀꯨꯔꯤꯁ꯭ꯔꯥ#
# > famba
# = ꯐꯝꯕ
# < ꯐꯝꯕ#
# > sagatlakpa
# = ꯁꯥꯒꯠꯂꯛꯄ
# < ꯁꯥꯒꯠꯠꯠꯄ#
# > koknaba
# = ꯀꯣꯛꯅꯕ
# < ꯀꯣꯛꯅꯕ#
# > vance
# = ꯚꯦꯟꯁ
# < ꯚꯥꯟꯦꯦ#
# > bhagabat
# = ꯚꯥꯒꯕꯠ
# < ꯕꯥꯖꯥꯠ#
# > valdosta
# = ꯕꯥꯜꯗꯣꯁꯇꯥ
# < ꯚꯦꯜꯗꯣꯁꯇꯇꯇ#
# > pearland
# = ꯄꯤꯌꯔꯂꯦꯟꯗ
# < ꯄꯦꯔꯥꯟꯟꯗ#
# > dindigul
# = ꯗꯤꯟꯗꯒꯜ
# < ꯗꯤꯟꯗꯤꯜ#
# > dutta
# = ꯗꯠꯇꯥ
# < ꯗꯨꯇꯇ#
# > hainasu
# = ꯍꯥꯢꯅꯁꯨ
# < ꯍꯥꯢꯅꯁꯨ#
# > pangthoklamba
# = ꯄꯥꯡꯊꯣꯛꯂꯝꯕ
# < ꯄꯥꯡꯊꯣꯛꯈꯝꯂꯕ#
# > saanakhi
# = ꯁꯥꯅꯈꯤ
# < ꯁꯥꯅꯈꯤ#
# > jajoo
# = ꯖꯖꯨ
# < ꯖꯥꯖꯣꯣ#
# > arthropoda
# = ꯑꯔꯊ꯭ꯔꯣꯄꯣꯗꯥ
# < ꯑꯥꯔꯔꯣꯔꯣ#
# > aiba
# = ꯑꯏꯕꯤ
# < ꯑꯏꯕꯅ#
# > commerce
# = ꯀꯣꯃꯔꯁ
# < ꯀꯣꯝꯃꯔꯦ#
# > imalonbu
# = ꯏꯃꯥꯂꯣꯟꯕꯨ
# < ꯏꯃꯥꯂꯟꯕ#
# > chajibu
# = ꯆꯥꯖꯤꯕꯨ
# < ꯆꯥꯕꯤꯕꯨ#
# > sasan
# = ꯁꯥꯥꯥꯥꯁꯟ
# < ꯁꯥꯁꯟ#
# > ventura
# = ꯚꯦꯟꯇꯨꯔꯥ
# < ꯚꯦꯟꯔꯤꯇꯥ#
# > whirlpool
# = ꯋꯔꯄꯨꯜ
# < ꯋꯤꯍꯤꯔꯣꯔꯣꯜ#
# > awaapham
# = ꯑꯋꯥꯐꯝ
# < ꯑꯋꯥꯐꯝ#
# > yadav
# = ꯌꯥꯗꯕ
# < ꯌꯥꯗꯥ#
# > wausau
# = ꯋꯥꯎꯁꯥꯎ
# < ꯋꯥꯁꯁꯨ#
# > torrent
# = ꯇꯣꯔꯦꯟꯠ
# < ꯇꯣꯔꯦꯠ#
# > samiti
# = ꯁꯃꯤꯇꯤ
# < ꯁꯥꯤꯇꯇꯤ#
# > punch
# = ꯄꯟꯆ
# < ꯄꯨꯟꯆ#
# > paisalo
# = ꯄꯥꯢꯁꯥꯂꯣ
# < ꯄꯥꯢꯁꯥꯂꯣ#
# > nadu
# = ꯅꯥꯗꯨ
# < ꯅꯗꯨ#
# > bernard
# = ꯕꯔꯅꯥꯔꯗ
# < ꯕꯦꯔꯥꯔꯗ#
# > rathore
# = ꯔꯥꯊꯣꯔ
# < ꯔꯥꯊꯣꯔꯦ#
# > lainingthouni
# = ꯂꯥꯢꯅꯤꯡꯊꯧꯅꯤ
# < ꯂꯥꯢꯅꯤꯡꯆꯤ#
# > pheijom
# = ꯐꯩꯖꯣꯝ
# < ꯐꯩꯑꯣꯝ#
# > mangaa
# = ꯃꯉꯥ
# < ꯃꯉꯥ#
# > yenakha
# = ꯌꯦꯅꯈꯥ
# < ꯌꯦꯅꯈ#
# > carson
# = ꯀꯥꯔꯁꯟ
# < ꯀꯔꯔꯣꯟ#
# > callahan
# = ꯀꯦꯂꯍꯦꯟ
# < ꯀꯦꯂꯍꯍꯟ#
# > jajoo
# = ꯖꯥꯖꯨ
# < ꯖꯖꯖꯣꯣꯣ#
# > erie
# = ꯏꯑꯔꯤ
# < ꯏꯔꯤ#
# > broadcast
# = ꯕ꯭ꯔꯣꯗꯀꯥꯁꯠ
# < ꯕ꯭ꯔꯦꯂꯗꯥꯇꯣꯛꯁ#
# > bhuj
# = ꯚꯨꯖ
# < ꯚꯨꯖ#
# > cheihisi
# = ꯆꯩꯍꯤꯁꯤ
# < ꯆꯩꯁꯤ#
# > education
# = ꯑꯦꯖꯨꯀꯦꯁꯟ
# < ꯏꯗꯨꯀꯣꯢꯗꯣꯟ#
# > magi
# = ꯃꯥꯒꯤ
# < ꯃꯔꯤꯒꯤ#
# > sarukti
# = ꯁꯔꯨꯛꯇꯤ
# < ꯁꯔꯨꯛꯇꯇꯤ#
# > laini
# = ꯂꯥꯢꯅꯤ
# < ꯂꯥꯢꯅꯤ#
# > bhardwaj
# = ꯚꯔꯗ꯭ꯋꯥꯖ
# < ꯚꯔꯔꯋꯥ#
# > colorado
# = ꯀꯣꯂꯣꯔꯦꯗꯣ
# < ꯀꯣꯂꯔꯣꯔꯣ#
# > hardoi
# = ꯍꯔꯗꯣꯢ
# < ꯍꯥꯔꯣꯢ#
# > sajibu
# = ꯁꯖꯤꯕꯨ
# < ꯁꯥꯕꯕꯨ#
# > atlantic
# = ꯑꯦꯠꯂꯥꯟꯇꯤꯛ
# < ꯑꯠꯇꯛꯇꯀꯇꯇꯤꯇ#
# > kongshang
# = ꯀꯣꯡꯁꯥꯡ
# < ꯀꯣꯡꯁꯥꯡ#
# > meira
# = ꯃꯩꯔꯥ
# < ꯃꯩꯔꯥ#
# > kaahenna
# = ꯀꯥꯍꯦꯟꯅ
# < ꯀꯥꯍꯦꯟꯅ#
# > landa
# = ꯂꯥꯟꯗ
# < ꯂꯥꯟꯗ#
# > ahmadabad
# = ꯑꯦꯍꯃꯗꯥꯕꯥꯗ
# < ꯑꯍꯤꯗꯕ#
# > leisinaduna
# = ꯂꯩꯁꯤꯅꯗꯨꯅ
# < ꯂꯩꯁꯤꯟꯗꯨꯅ#
# > pasadena
# = ꯄꯥꯁꯥꯗꯦꯅꯥ
# < ꯁꯁꯥꯗꯅ#
# > mamaani
# = ꯃꯃꯥꯅꯤ
# < ꯃꯃꯅꯤ#
# > kheda
# = ꯈꯦꯗꯥ
# < ꯈꯦꯗꯗ#
# > awaangbagi
# = ꯑꯋꯥꯡꯕꯒꯤ
# < ꯑꯋꯥꯡꯕꯒꯤ#
# > morales
# = ꯃꯣꯔꯥꯂꯦꯁ
# < ꯃꯣꯔꯦꯂꯦ#
# > machakhaiba
# = ꯃꯆꯥꯈꯥꯢꯕ
# < ꯃꯆꯥꯈꯥꯢꯕ#
# > wilkinson
# = ꯋꯤꯜꯀꯤꯟꯁꯟ
# < ꯂꯤꯜꯀꯤꯟꯁꯣꯟ#
# > onduna
# = ꯑꯣꯟꯗꯨꯅ
# < ꯑꯣꯟꯗꯨꯅ#
# > langja
# = ꯂꯪꯖꯥ
# < ꯂꯥꯡꯖ#
# > fangde
# = ꯐꯪꯗꯦ
# < ꯐꯪꯗꯦ#
# > lavudya
# = ꯂꯚꯨꯗ꯭ꯌ
# < ꯂꯥꯚꯨꯗꯥ#
# > vizianagaram
# = ꯚꯤꯖꯤꯑꯥꯅꯒꯔꯝ
# < ꯚꯤꯔꯤꯖꯔꯝꯝꯒ#
# > navas
# = ꯅꯥꯕꯥꯁ
# < ꯅꯥꯁꯁ#
# > masaaga
# = ꯃꯁꯥꯒ
# < ꯃꯁꯥꯒ#
# > parengsingna
# = ꯄꯔꯦꯡꯁꯤꯡꯅ
# < ꯄꯔꯦꯡꯁꯤꯡꯅ#
# > magdum
# = ꯃꯦꯒꯗꯝ
# < ꯃꯥꯗꯨꯝ#
# > rudragi
# = ꯔꯨꯗ꯭ꯔꯒꯤ
# < ꯔꯨꯗꯔꯔꯥꯒꯤ#
# > dallas
# = ꯗꯜꯂꯁ
# < ꯗꯥꯜꯂꯁ#
# > sanaleipak
# = ꯁꯅꯥꯂꯩꯄꯥꯛ
# < ꯁꯅꯥꯂꯩꯄꯛꯛ#
# > banks
# = ꯕꯦꯡꯛꯁ
# < ꯕꯟꯟꯁ#
# > reeves
# = ꯔꯤꯕꯁ
# < ꯔꯤꯚꯦꯁ#
# > aschelminthes
# = ꯑꯁꯆꯦꯜꯃꯤꯟꯊꯤꯁ
# < ꯑꯁꯤꯁꯦꯦꯦꯦ꯭ꯦꯁꯁꯁ#
# > buchanan
# = ꯕ꯭ꯌꯨꯀꯥꯅꯟ
# < ꯕꯨꯆꯅꯤ#
# > hyderabad
# = ꯍꯥꯢꯗ꯭ꯔꯥꯕꯥꯗ
# < ꯍꯤꯗ꯭ꯔꯕ#
# > anisuba
# = ꯑꯅꯤꯁꯨꯕ
# < ꯑꯅꯤꯀꯨꯕ#
# > shijagi
# = ꯁꯤꯖꯒꯤ
# < ꯁꯤꯖꯥꯒꯤ#
# > portillo
# = ꯄꯣꯔꯇꯤꯂꯣ
# < ꯄꯣꯔꯤꯂꯂꯣ#
# > afghanistan
# = ꯑꯐꯘꯥꯅꯤꯁ꯭ꯇꯥꯟ
# < ꯑꯐꯖꯁꯤꯁꯇꯥꯇꯅ#
# > ipao
# = ꯏꯄꯥꯎ
# < ꯏꯄꯥꯎ#
# > humphutarataret
# = ꯍꯨꯝꯐꯨꯇꯔꯥꯇꯔꯦꯠ
# < ꯍꯨꯝꯨꯐꯨꯇꯇꯇꯇꯇꯇꯇꯔꯦꯠ#
# > shipping
# = ꯁꯤꯞꯄꯤꯡ
# < ꯁꯤꯄꯤꯡꯒꯤ#
# > misingni
# = ꯃꯤꯁꯤꯡꯅꯤ
# < ꯃꯤꯁꯤꯡꯅꯤ#
# > chingsangsingna
# = ꯆꯤꯡꯁꯥꯡꯁꯤꯡꯅ
# < ꯆꯤꯡꯁꯪꯡꯅꯪ#
# > visakhapatnam
# = ꯚꯤꯁꯥꯈꯥꯄꯠꯅꯝ
# < ꯁꯤꯖꯥꯛꯊꯦꯡꯝꯝ#
# > racine
# = ꯔꯦꯁꯤꯟ
# < ꯔꯦꯁꯤꯅꯦ#
# > kota
# = ꯀꯣꯇꯥ
# < ꯀꯣꯠꯇ#
# > church
# = ꯆꯔꯆ
# < ꯆꯨꯔꯦ#
# > lishing
# = ꯂꯤꯁꯤꯡ
# < ꯂꯤꯁꯤꯡ#
# > lalonetikki
# = ꯂꯂꯣꯟꯏꯇꯤꯛꯀꯤ
# < ꯂꯂꯣꯟꯅꯣꯛꯀꯤꯅꯤ#
# > enaak
# = ꯏꯅꯥꯛ
# < ꯏꯅꯥꯛ#
# > lampaakka
# = ꯂꯝꯄꯥꯛꯀ
# < ꯂꯝꯄꯥꯛꯂꯆ#
# > meisaa
# = ꯃꯩꯁꯥ
# < ꯃꯩꯁꯥ#
# > spandana
# = ꯁ꯭ꯄꯟꯗꯅ
# < ꯁ꯭ꯄꯦꯅꯅꯥ#
# > hoba
# = ꯍꯣꯕ
# < ꯍꯣꯕ#
# > yumthakta
# = ꯌꯨꯝꯊꯛꯇ
# < ꯌꯨꯝꯊꯛꯇꯇ#
# > australiada
# = ꯑꯣꯁꯇ꯭ꯔꯦꯂꯤꯌꯥꯗ
# < ꯑꯥꯁꯇ꯭ꯔꯦꯃꯤꯗ#
# > beck
# = ꯕꯦꯛ
# < ꯕꯦꯛ#
# > fayetteville
# = ꯐꯦꯌꯦꯠꯕꯤꯜ
# < ꯐꯌꯌꯦꯠꯂꯦꯂꯦ#
# > taakpagi
# = ꯇꯥꯛꯄꯒꯤ
# < ꯇꯥꯛꯄꯒꯤ#
# > haapchinle
# = ꯍꯥꯞꯆꯤꯟꯂꯦ
# < ꯍꯥꯞꯆꯤꯟꯂꯦꯂ#
# > laphu
# = ꯂꯐꯨ
# < ꯂꯥꯄꯨ#
# > bacteria
# = ꯕꯦꯛꯇꯤꯔꯤꯌꯥ
# < ꯕꯥꯇ꯭ꯔꯩ#
# > machine
# = ꯃꯁꯤꯟ
# < ꯃꯆꯤꯅꯦ#
# > saabi
# = ꯁꯥꯕꯤ
# < ꯁꯥꯕꯤ#
# > pass
# = ꯄꯥꯁ
# < ꯄꯁꯁꯁ#
# > buenaventura
# = ꯕꯣꯅꯥꯕꯦꯟꯇꯨꯔꯥ
# < ꯕꯨꯅꯅꯦꯥꯋꯨꯔ#
# > chatnarammi
# = ꯆꯠꯅꯔꯝꯃꯤ
# < ꯆꯠꯅꯔꯃꯃꯤ#
# > pravesh
# = ꯄ꯭ꯔꯕꯦꯁ
# < ꯄ꯭ꯔꯦꯚꯦ#
# > swain
# = ꯁ꯭ꯋꯦꯟ
# < ꯁ꯭ꯋꯦꯟꯟ#
# > taakpiramba
# = ꯇꯥꯛꯄꯤꯔꯝꯕ
# < ꯇꯥꯛꯄꯤꯔꯔꯝꯕ#
# > shingsu
# = ꯁꯤꯡꯁꯨ
# < ꯁꯤꯡꯁꯨ#
# > mitana
# = ꯃꯤꯇꯅ
# < ꯃꯤꯇꯅ#
# > phampaalda
# = ꯐꯝꯄꯥꯜꯗ
# < ꯐꯝꯄꯥꯜꯗ#
# > ichang
# = ꯏꯆꯪ
# < ꯏꯆꯪ#
# > asagi
# = ꯑꯁꯥꯒꯤ
# < ꯑꯁꯥꯒꯤ#
# > puthorakkhi
# = ꯄꯨꯊꯣꯔꯛꯈꯤ
# < ꯄꯨꯊꯣꯛꯈꯔꯤꯛꯤ#
# > saphaba
# = ꯁꯥꯐꯕ
# < ꯁꯥꯕꯕ#
# > nalwa
# = ꯅꯜꯋꯥ
# < ꯅꯜꯋꯥ#
# > barrett
# = ꯕꯦꯔꯦꯠ
# < ꯕꯔꯦꯠꯇꯦ#
# > ewaanglon
# = ꯏꯋꯥꯡꯂꯣꯟ
# < ꯏꯋꯥꯡꯂꯣꯟ#
# > bhavnagar
# = ꯚꯥꯋꯅꯒꯔ
# < ꯚꯥꯠꯅꯔꯒ#
# > ahmad
# = ꯑꯍꯃꯗ
# < ꯑꯍꯤꯗ#
# > hindustan
# = ꯍꯤꯟꯗꯨꯁꯇꯥꯟ
# < ꯍꯤꯟꯗ꯭ꯌꯥꯔꯁꯟ#
# > atangba
# = ꯑꯇꯥꯡꯕ
# < ꯑꯇꯥꯡꯕ#
# > puraktuna
# = ꯄꯨꯔꯛꯇꯨꯅ
# < ꯄꯨꯔꯨꯛꯇꯨꯅ#
# > puwaarida
# = ꯄꯨꯋꯥꯔꯤꯗ
# < ꯄꯨꯋꯥꯀꯗꯤꯗꯔ#
# > tha
# = ꯊꯥ
# < ꯊꯥ#
# > ponce
# = ꯄꯣꯟꯁ
# < ꯄꯣꯟꯀꯦ#
# > bisht
# = ꯕꯤꯁꯠ
# < ꯕꯤꯁꯇꯠ#
# > pak
# = ꯄꯥꯛ
# < ꯄꯥꯛ#
# > kushalappa
# = ꯀꯨꯁꯂꯞꯄꯥ
# < ꯀꯨꯁꯥꯄꯥ#
# > melinda
# = ꯃꯦꯂꯤꯟꯗꯥ
# < ꯃꯦꯂꯤꯟꯗ#
# > pompano
# = ꯄꯣꯝꯄꯥꯅꯣ
# < ꯄꯣꯝꯅꯅꯣ#
# > yatpa
# = ꯌꯥꯠꯄ
# < ꯌꯥꯠꯄ#
# > ataa
# = ꯑꯇꯥ
# < ꯑꯇꯥ#
# > karkhele
# = ꯀꯔꯈꯦꯂꯦ
# < ꯀꯔꯔꯦꯂꯦ#
# > kanchhal
# = ꯀꯟꯆꯜ
# < ꯀꯟꯟꯈꯜ#
# > taylorsville
# = ꯇꯦꯂꯔꯁꯕꯤꯜ
# < ꯇꯥꯂꯣꯔꯦꯂꯦ#
# > houdoklakpa
# = ꯍꯧꯗꯣꯛꯂꯛꯄ
# < ꯍꯧꯗꯣꯛꯛꯛꯄ#
# > nakul
# = ꯅꯀꯨꯜ
# < ꯅꯥꯑꯨꯜ#
# > phaoduna
# = ꯐꯥꯎꯗꯨꯅ
# < ꯐꯥꯎꯗꯨꯅ#
# > pacheco
# = ꯄꯆꯦꯀꯣ
# < ꯄꯦꯆꯔꯑꯣ#
# > paagani
# = ꯄꯥꯒꯅꯤ
# < ꯄꯥꯒꯅꯤ#
# > surendranagar
# = ꯁꯨꯔꯦꯟꯗ꯭ꯔꯅꯒꯔ
# < ꯁꯨꯔꯦꯟꯅ꯭ꯔꯒ#
# > slovakia
# = ꯁ꯭ꯂꯣꯚꯥꯀꯤꯌꯥ
# < ꯁ꯭ꯂꯣꯂꯣꯚꯤꯌ#
# > laurus
# = ꯂꯣꯔꯁ
# < ꯂꯥꯔꯨꯁ#
# > centre
# = ꯁꯦꯟꯇꯔ
# < ꯀꯦꯟꯇ꯭ꯔꯦ#
# > hotnajaramba
# = ꯍꯣꯠꯅꯖꯔꯝꯕ
# < ꯍꯣꯠꯅꯔꯝꯕ#
# > nungshiruba
# = ꯅꯨꯡꯁꯤꯔꯨꯕ
# < ꯅꯨꯡꯁꯤꯔꯨ#
# > puriklai
# = ꯄꯨꯔꯤꯛꯂꯥꯢ
# < ꯄꯨꯔꯤꯛꯂꯣꯢ#
# > ngaore
# = ꯉꯥꯎꯔꯦ
# < ꯉꯥꯑꯦꯔꯦ#
# > tapia
# = ꯇꯥꯄꯤꯑꯥ
# < ꯇꯥꯄꯤꯌꯥ#
# > awafam
# = ꯑꯋꯥꯐꯝ
# < ꯑꯋꯥꯐꯝ#
# > thapham
# = ꯊꯥꯐꯝ
# < ꯊꯐꯐꯝ#
# > uningthou
# = ꯎꯅꯤꯡꯊꯧ
# < ꯌꯨꯅꯤꯡꯊꯨ#
# > sutton
# = ꯁꯨꯠꯇꯟ
# < ꯁꯨꯇꯇꯣꯟ#
# > kayaam
# = ꯀꯌꯥꯝ
# < ꯀꯌꯥꯝ#
# > makhaada
# = ꯃꯈꯥꯗ
# < ꯃꯈꯥꯗ#
# > leigong
# = ꯂꯩꯒꯣꯡ
# < ꯂꯩꯒꯣꯡ#
# > composites
# = ꯀꯝꯄꯣꯖꯤꯠꯁ
# < ꯀꯣꯝꯄꯣꯁꯇꯤꯌꯥ#
# > barmer
# = ꯕꯥꯔꯃꯔ
# < ꯕꯔꯔꯦꯔ#
# > halisahar
# = ꯍꯥꯂꯤꯁꯍꯔ
# < ꯍꯥꯂꯤꯃꯔꯔꯁꯥ#
# > kaithal
# = ꯀꯦꯊꯜ
# < ꯀꯥꯢꯊꯜ#
# > muthappan
# = ꯃꯨꯊꯥꯞꯄꯟ
# < ꯃꯨꯠꯐꯥꯠ#
# > mioi
# = ꯃꯤꯑꯣꯢ
# < ꯃꯤꯑꯣꯢ#
# > sulochana
# = ꯁꯨꯂꯣꯆꯅꯥ
# < ꯁꯨꯂꯨꯟꯆꯣ#
# > chingsu
# = ꯆꯤꯡꯁꯨ
# < ꯆꯤꯡꯁꯨ#
# > lady
# = ꯂꯦꯗꯤ
# < ꯂꯥꯟ#
# > nilkamal
# = ꯅꯤꯜꯀꯃꯜ
# < ꯅꯤꯜꯀꯜ#
# > khumnaba
# = ꯈꯨꯝꯅꯕ
# < ꯈꯨꯝꯅꯕ#
# > mahanagar
# = ꯃꯍꯥꯅꯒꯔ
# < ꯃꯍꯥꯅꯔꯔ#
# > gates
# = ꯒꯦꯠꯁ
# < ꯒꯦꯠꯁꯁ#
# > eidi
# = ꯑꯩꯗꯤ
# < ꯑꯩꯗꯤ#
# > thongalel
# = ꯊꯣꯉꯥꯂꯦꯜ
# < ꯊꯣꯡꯍꯂꯦꯜ#
# > novi
# = ꯅꯣꯕꯤ
# < ꯅꯣꯕꯤ#
# > allcargo
# = ꯑꯣꯜꯀꯥꯔꯒꯣ
# < ꯑꯦꯜꯔꯥ#
# > chicago
# = ꯁꯤꯀꯥꯒꯣ
# < ꯆꯤꯆꯥꯒꯣ#
# > teinabadugi
# = ꯇꯩꯅꯕꯗꯨꯒꯤ
# < ꯇꯩꯅꯕꯕꯒꯤꯗ#
# > dunwoody
# = ꯗꯟꯋꯨꯗꯤ
# < ꯗꯨꯗꯣꯗꯤ#
# > sonawane
# = ꯁꯣꯅꯥꯋꯦꯟ
# < ꯁꯣꯅꯋꯋꯦꯅ#
# > mabukta
# = ꯃꯕꯨꯛꯇ
# < ꯃꯕꯨꯛꯇ#
# > phaobagidi
# = ꯐꯥꯎꯕꯒꯤꯗꯤ
# < ꯐꯥꯎꯕꯗꯒꯤ#
# > eribasingsidagi
# = ꯏꯔꯤꯕꯁꯤꯡꯁꯤꯗꯒꯤ
# < ꯏꯔꯤꯕꯁꯤꯁꯤꯡꯗꯤ#
# > lailempigi
# = ꯂꯥꯢꯂꯦꯝꯄꯤꯒꯤ
# < ꯂꯥꯢꯃꯦꯝꯐꯤꯒꯤ#
# > edit
# = ꯏꯗꯤꯠ
# < ꯏꯗꯤꯠ#
# > aurora
# = ꯑꯧꯔꯣꯔꯥ
# < ꯑꯌꯨꯔꯥ#
# > morena
# = ꯃꯣꯔꯦꯅꯥ
# < ꯃꯣꯔꯦꯅ#
# > yaubara
# = ꯌꯥꯎꯕꯔꯥ
# < ꯌꯥꯕꯔꯔ#
# > chandernagore
# = ꯆꯟꯗꯔꯅꯒꯣꯔ
# < ꯆꯟꯗ꯭ꯔꯦꯉꯦ#
# > avondale
# = ꯑꯥꯚꯣꯟꯗꯦꯜ
# < ꯑꯣꯗꯦꯅꯦ#
# > shiromani
# = ꯁꯤꯔꯣꯃꯅꯤ
# < ꯁꯤꯔꯝꯝꯅꯤ#
# > leikhribasi
# = ꯂꯩꯈ꯭ꯔꯤꯕꯁꯤ
# < ꯂꯩꯈ꯭ꯔꯤꯕꯁꯤ#
# > mendez
# = ꯃꯦꯟꯗꯦꯖ
# < ꯃꯦꯟꯗꯦꯁ#
# > yaanakhi
# = ꯌꯥꯅꯈꯤ
# < ꯌꯥꯅꯈꯤ#
# > wangkhatlakkhi
# = ꯋꯥꯡꯈꯠꯂꯛꯈꯤ
# < ꯋꯥꯡꯈꯠꯈꯈꯤ#
# > hazaribag
# = ꯍꯖꯥꯔꯤꯕꯥꯒ
# < ꯍꯥꯖꯥꯔꯤꯕ#
# > pontiac
# = ꯄꯣꯟꯇꯤꯌꯥꯛ
# < ꯄꯣꯟꯇꯤꯤ#
# > bhogeshor
# = ꯚꯣꯒꯦꯁꯣꯔ
# < ꯚꯣꯓꯦꯔꯁ#
# > pakee
# = ꯄꯥꯛꯏ
# < ꯄꯥꯇꯦ#
# > virani
# = ꯚꯤꯔꯥꯅꯤ
# < ꯚꯤꯔꯥꯅꯤ#
# > foam
# = ꯐꯣꯝ
# < ꯐꯣꯝ#
# > loushing
# = ꯂꯧꯁꯤꯡ
# < ꯂꯧꯁꯤꯡ#
# > erbium
# = ꯑꯦꯔꯕꯤꯌꯝ
# < ꯑꯔꯤꯔꯨꯝ#
# > saran
# = ꯁꯔꯟ
# < ꯁꯔꯥꯟ#
# > chamunda
# = ꯆꯥꯃꯨꯟꯗꯥ
# < ꯆꯃꯨꯟꯗ#
# > caplin
# = ꯀꯦꯄ꯭ꯂꯤꯟ
# < ꯀꯦꯜꯂꯅꯤ#
# > childagi
# = ꯆꯤꯜꯗꯒꯤ
# < ꯆꯤꯜꯗꯒꯤ#
# > sipike
# = ꯁꯤꯄꯤꯀꯦ
# < ꯁꯤꯄꯤꯀꯦ#
# > senyekni
# = ꯁꯦꯟꯌꯦꯛꯅꯤ
# < ꯁꯦꯅꯦꯛꯅꯤ#
# > rowe
# = ꯔꯣ
# < ꯔꯣꯋꯦ#
# > pakhanba
# = ꯄꯛꯍꯟꯕ
# < ꯄꯥꯈꯟꯕ#
# > chaorakpa
# = ꯆꯥꯎꯔꯥꯛꯄ
# < ꯆꯥꯎꯔꯛꯄ#
# > ibada
# = ꯏꯕꯗ
# < ꯏꯕꯥꯗ#
# > lakminnaraga
# = ꯂꯥꯛꯃꯤꯟꯅꯔꯒ
# < ꯂꯥꯛꯃꯤꯅꯔꯒꯤ#
# > oibadi
# = ꯑꯣꯢꯕꯗꯤ
# < ꯑꯣꯢꯕꯗꯤ#
# > phiset
# = ꯐꯤꯁꯦꯠ
# < ꯐꯤꯖꯦꯠ#
# > ekhi
# = ꯏꯈꯤ
# < ꯏꯈꯤ#
# > yaallaga
# = ꯌꯥꯜꯂꯒ
# < ꯌꯥꯜꯂꯒ#
# > maangda
# = ꯃꯥꯡꯗ
# < ꯃꯥꯡꯗ#
# > ngaakpa
# = ꯉꯥꯛꯄ
# < ꯉꯥꯛꯄ#
# > matik
# = ꯃꯇꯤꯛ
# < ꯃꯇꯤꯛ#
# > karambano
# = ꯀꯔꯝꯕꯅꯣ
# < ꯀꯔꯝꯝꯕꯨꯅ#
# > paangthokkhiba
# = ꯄꯥꯡꯊꯣꯛꯈꯤꯕ
# < ꯄꯥꯡꯊꯣꯛꯈꯤ#
# > ningkham
# = ꯅꯤꯡꯈꯝ
# < ꯅꯤꯡꯈꯝ#
# > avenues
# = ꯑꯦꯚꯦꯅ꯭ꯌꯨꯁ
# < ꯑꯦꯦꯦꯅꯁꯁ#
# > kewal
# = ꯀꯦꯋꯜ
# < ꯀꯦꯋꯥꯂꯜ#
# > maningtamba
# = ꯃꯅꯤꯡꯇꯝꯕ
# < ꯃꯅꯤꯡꯐꯝꯕ#
# > mayaiwairap
# = ꯃꯌꯥꯢꯋꯥꯢꯔꯞ
# < ꯃꯌꯥꯢꯥꯔꯥꯄ#
# > akonba
# = ꯑꯀꯣꯟꯕ
# < ꯑꯀꯣꯟꯕ#
# > chatnabisisu
# = ꯆꯠꯅꯕꯤꯁꯤꯁꯨ
# < ꯆꯠꯅꯕꯁꯨ#
# > canton
# = ꯀꯦꯟꯇꯟ
# < ꯀꯦꯟꯇꯣꯟ#
# > ballia
# = ꯕꯜꯂꯤꯑꯥ
# < ꯕꯥꯜꯂꯤ#
# > pereddy
# = ꯄꯦꯔꯦꯗꯤ
# < ꯄꯦꯔꯦꯗꯤꯌ#
# > uniphos
# = ꯌꯨꯅꯤꯐꯣꯁ
# < ꯌꯨꯅꯤꯛꯆꯁ#
# > khundaariba
# = ꯈꯨꯟꯗꯥꯔꯤꯕ
# < ꯈꯨꯟꯗꯔꯤꯔꯕ#
# > vineland
# = ꯚꯥꯢꯟꯂꯦꯟꯗ
# < ꯚꯤꯅꯦꯗꯗ#
# > gokaldas
# = ꯒꯣꯀꯥꯜꯗꯥꯁ
# < ꯒꯣꯑꯥꯜꯁꯥꯁ#
# > moirang
# = ꯃꯣꯢꯔꯥꯡ
# < ꯃꯣꯢꯔꯪ#
# > sanskrit
# = ꯁꯟꯁ꯭ꯀ꯭ꯔꯤꯠ
# < ꯁꯟꯁ꯭ꯔꯇꯇꯇ#
# > naaz
# = ꯅꯥꯖ
# < ꯅꯥꯓ#
# > kananasu
# = ꯀꯅꯥꯅꯁꯨ
# < ꯀꯅꯅꯁꯁꯨ#
# > conley
# = ꯀꯣꯟꯂꯤ
# < ꯀꯣꯟꯌꯥ#
# > uthakta
# = ꯎꯊꯛꯇ
# < ꯎꯊꯛꯇ#
# > lancaster
# = ꯂꯦꯟꯀꯦꯁꯇꯔ
# < ꯂꯥꯟꯁꯁꯇ꯭ꯔ#
# > imungni
# = ꯏꯃꯨꯡꯅꯤ
# < ꯏꯃꯨꯅꯤꯤ#
# > patna
# = ꯄꯠꯅꯥ
# < ꯄꯠꯅ#
# > fongba
# = ꯐꯣꯡꯕ
# < ꯐꯣꯡꯕ#
# > hosur
# = ꯍꯣꯁꯨꯔ
# < ꯍꯣꯔꯔ#
# > ichada
# = ꯏꯆꯥꯗ
# < ꯏꯆꯥꯗ#
# > phamjinli
# = ꯐꯝꯖꯤꯟꯂꯤ
# < ꯐꯝꯖꯤꯟꯂꯤ#
# > tustin
# = ꯇꯁꯇꯤꯟ
# < ꯇꯨꯠꯁꯤꯡꯅ#
# > thoujaaldagi
# = ꯊꯧꯖꯥꯜꯗꯒꯤ
# < ꯊꯧꯖꯥꯕꯒꯤ#
# > cheisingkaanglon
# = ꯆꯩꯁꯤꯡꯀꯥꯡꯂꯣꯟ
# < ꯆꯩꯁꯤꯛꯀꯥꯡꯂꯣꯟ#
# > aenugu
# = ꯑꯦꯅꯨꯒꯨ
# < ꯑꯌꯤꯅꯨꯒ#
# > lamb
# = ꯂꯦꯝ
# < ꯂꯝꯝꯕ#
# > yei
# = ꯌꯩ
# < ꯩꯩ#
# > conditioning
# = ꯀꯟꯗꯤꯁꯅꯤꯡ
# < ꯀꯣꯟꯤꯇꯣꯁꯤꯡ#
# > yumnaksing
# = ꯌꯨꯝꯅꯥꯛꯁꯤꯡ
# < ꯌꯨꯝꯅꯛꯛꯁꯤꯡ#
# > wasudewa
# = ꯋꯁꯨꯗꯦꯋ
# < ꯋꯁꯨꯗꯋꯋ#
# > chowdhury
# = ꯆꯧꯙꯨꯔꯤ
# < ꯆꯣꯔꯗꯔꯤ#
# > ilenpung
# = ꯏꯂꯦꯟꯄꯨꯡ
# < ꯏꯂꯦꯟꯄꯨꯡ#
# > rajendra
# = ꯔꯥꯖꯦꯟꯗ꯭ꯔ
# < ꯔꯥꯖꯦꯟꯗ꯭ꯔꯦ#
# > thermax
# = ꯊꯔꯃꯦꯛꯁ
# < ꯊꯦꯃꯛꯔꯛ#
# > hempstead
# = ꯍꯦꯝꯞꯁ꯭ꯇꯤꯗ
# < ꯍꯦꯝꯄꯤꯁꯗꯗꯥꯗ#
# > dhamane
# = ꯙꯥꯃꯦꯟ
# < ꯙꯃꯅꯦ#
# > changkhraga
# = ꯆꯪꯈ꯭ꯔꯒ
# < ꯆꯪꯈ꯭ꯔꯦꯉꯒ#
# > chaoraki
# = ꯆꯥꯎꯔꯛꯏ
# < ꯆꯥꯎꯔꯛꯏ#
# > harbour
# = ꯍꯥꯔꯕꯔ
# < ꯍꯔꯔꯨꯔ#
# > acevedo
# = ꯑꯁꯤꯕꯦꯗꯣ
# < ꯑꯦꯦꯗꯗꯑꯣ#
# > lannaduna
# = ꯂꯥꯟꯅꯗꯨꯅ
# < ꯂꯥꯟꯅꯗꯨꯅ#
# > orange
# = ꯑꯣꯔꯦꯟꯖ
# < ꯑꯣꯔꯦꯦꯦꯦ#
# > siemens
# = ꯁꯤꯃꯟꯁ
# < ꯁꯤꯃꯦꯟꯁꯁꯁ#
# > research
# = ꯔꯤꯁꯔꯁ
# < ꯔꯦꯔꯦꯟ#
# > poschima
# = ꯄꯣꯁ꯭ꯆꯤꯃ
# < ꯄꯣꯁꯤꯌꯥ#
# > kg
# = ꯀꯦꯖꯤ
# < ꯀꯤꯒ#
# > chaoshangba
# = ꯆꯥꯎꯁꯥꯡꯕ
# < ꯆꯥꯎꯁꯪꯕ#
# > mamaasigi
# = ꯃꯃꯥꯥꯥꯥꯥꯥꯁꯤꯒꯤ
# < ꯃꯌꯥꯒꯤꯒꯤ#
# > mandalaygi
# = ꯃꯟꯗꯂꯦꯒꯤ
# < ꯃꯟꯗꯥꯟꯇꯤꯒꯤ#
# > queens
# = ꯀ꯭ꯋꯤꯟꯁ
# < ꯀꯨꯌꯦꯟꯁ#
# > ilaat
# = ꯏꯂꯥꯠ
# < ꯏꯂꯥꯠ#
# > laothokkhre
# = ꯂꯥꯎꯊꯣꯛꯈ꯭ꯔꯦ
# < ꯂꯥꯎꯈꯣꯛꯈ꯭ꯔꯦ#
# > infosys
# = ꯏꯟꯐꯣꯁꯤꯁ
# < ꯏꯟꯐꯣꯢꯇꯦ#
# > chhatarpur
# = ꯁꯠꯇꯔꯄꯨꯔ
# < ꯆꯇꯥꯄꯔꯨ#
# > takhelambam
# = ꯇꯈꯦꯜꯂꯝꯕꯝ
# < ꯇꯥꯈꯣꯜꯕꯝ#
# > sanglaba
# = ꯁꯥꯡꯂꯕ
# < ꯁꯪꯕꯕ#
# > kangphaalgi
# = ꯀꯪꯐꯥꯜꯒꯤ
# < ꯀꯪꯐꯥꯜꯒꯤ#
# > makhoi
# = ꯃꯈꯣꯢ
# < ꯃꯈꯣꯢ#
# > channa
# = ꯆꯟꯅ
# < ꯆꯟꯅ#
# > algerian
# = ꯑꯜꯖꯦꯔꯤꯌꯥꯟ
# < ꯑꯦꯖꯦꯔꯦꯟꯥꯤꯟꯟꯟ#
# > leena
# = ꯂꯤꯅ
# < ꯂꯦꯅ#
# > engraaji
# = ꯏꯪꯔꯥꯖꯤ
# < ꯏꯪꯔꯔꯤꯖꯤ#
# > loubuk
# = ꯂꯧꯕꯨꯛ
# < ꯂꯧꯕꯛꯛꯨ#
# > dumka
# = ꯗꯝꯀꯥ
# < ꯗꯨꯝꯋꯥ#
# > glaxosmithkline
# = ꯒ꯭ꯂꯦꯛꯁꯣꯁ꯭ꯃꯤꯊꯀ꯭ꯂꯥꯢꯟ
# < ꯒ꯭ꯂꯦꯔꯔꯂꯦꯃꯤꯟꯦꯦꯁꯅ#
# > bossier
# = ꯕꯣꯁꯤꯑꯦꯔ
# < ꯕꯣꯁꯤꯔꯤ#
# > television
# = ꯇꯦꯂꯤꯚꯤꯖꯟ
# < ꯇꯦꯂꯦꯔꯤꯁꯤ#
# > solomon
# = ꯁꯣꯂꯣꯃꯣꯟ
# < ꯁꯣꯂꯣꯝ#
# > manassas
# = ꯃꯅꯥꯁꯁ
# < ꯃꯌꯥꯁꯁ#
# > mayanglambamna
# = ꯃꯌꯥꯡꯂꯝꯕꯝꯅ
# < ꯃꯌꯥꯡꯂꯝꯅ#
# > surabhi
# = ꯁꯨꯔꯥꯚꯤ
# < ꯁꯨꯔꯕꯥꯤ#
# > nicobar
# = ꯅꯤꯀꯣꯕꯔ
# < ꯅꯤꯀꯣꯅ꯭ꯕ#
# > ama
# = ꯑꯃ
# < ꯑꯃꯥ#
# > bhutan
# = ꯚꯨꯇꯥꯟ
# < ꯚꯨꯇꯥꯟ#
# > cross
# = ꯀ꯭ꯔꯣꯁ
# < ꯀ꯭ꯁꯁꯁ#
# > kumar
# = ꯀꯨꯃꯥꯔ
# < ꯀꯨꯃꯔꯔ#
# > ashuppa
# = ꯑꯁꯨꯞꯄ
# < ꯑꯁꯨꯞꯄ#
# > tampa
# = ꯇꯝꯄ
# < ꯇꯝꯄꯥ#
# > hinao
# = ꯍꯤꯅꯥꯎ
# < ꯍꯤꯅꯥ#
# > yambem
# = ꯌꯥꯝꯕꯦꯝ
# < ꯌꯝꯕꯝ#
# > bhiwani
# = ꯚꯤꯋꯥꯅꯤ
# < ꯚꯤꯋꯅꯤ#
# > bilaspur
# = ꯕꯤꯂꯥꯁꯄꯨꯔ
# < ꯕꯤꯄꯔꯥꯔꯁꯨ#
# > thui
# = ꯊꯨꯢ
# < ꯊꯨꯢ#
# > kaathoktuna
# = ꯀꯥꯊꯣꯛꯇꯨꯅ
# < ꯀꯥꯊꯣꯛꯇꯨꯅ#
# > bhatia
# = ꯚꯥꯇꯤꯑꯥ
# < ꯕꯥꯇꯤꯌꯥ#
# > lompoc
# = ꯂꯣꯝꯄꯣꯛ
# < ꯂꯣꯝꯄꯣ#
# > vidhi
# = ꯚꯤꯙꯤ
# < ꯚꯤꯗꯤ#
# > yetnaba
# = ꯌꯦꯠꯅꯕ
# < ꯌꯦꯠꯅꯕ#
# > electricals
# = ꯏꯂꯦꯛꯇ꯭ꯔꯤꯀꯜꯁ
# < ꯏꯦꯦꯛꯀꯁꯁꯤꯌꯁꯁ#
# > radha
# = ꯔꯥꯙꯥ
# < ꯔꯥꯗ#
# > hexaware
# = ꯍꯦꯛꯁꯥꯋꯦꯔ
# < ꯍꯦꯀꯥꯋꯦꯔꯦ#
# > panacea
# = ꯄꯦꯅꯁꯤꯑ
# < ꯄꯅꯥꯔꯦ#
# > sanitaryware
# = ꯁꯦꯅꯤꯇꯔꯤꯋꯦꯔ
# < ꯁꯅꯥꯢꯗ꯭ꯔꯦ#
# > yonkhi
# = ꯌꯣꯟꯈꯤ
# < ꯌꯣꯈꯈꯤ#
# > koppula
# = ꯀꯣꯞꯄꯨꯂꯥ
# < ꯀꯣꯞꯄꯨꯂ#
# > irvine
# = ꯏꯔꯚꯤꯟ
# < ꯏꯔꯤꯅꯦ#
# > erickson
# = ꯏꯔꯤꯛꯁꯟ
# < ꯑꯦꯀꯤꯌꯣꯟꯁ#
# > mangla
# = ꯃꯡꯒ꯭ꯂꯥ
# < ꯃꯥꯡꯂ#
# > shampubi
# = ꯁꯝꯄꯨꯕꯤ
# < ꯁꯝꯄꯨꯕꯤ#
# > moroccogi
# = ꯃꯣꯔꯣꯀꯣꯒꯤ
# < ꯃꯣꯔꯣꯣꯣꯣꯣꯣꯒꯒꯤ#
# > mahagauri
# = ꯃꯍꯥꯒꯧꯔꯤ
# < ꯃꯍꯥꯒꯔꯤꯔꯤ#
# > sapiknu
# = ꯁꯥꯆꯤꯛꯅꯨ
# < ꯁꯥꯄꯤꯄꯅꯨ#
# > ngaak
# = ꯉꯥꯛ
# < ꯉꯥꯛ#
# > houraklaba
# = ꯍꯧꯔꯛꯂꯕ
# < ꯍꯧꯔꯛꯂꯕ#
# > nifumaapan
# = ꯅꯤꯐꯨꯃꯥꯄꯟ
# < ꯅꯤꯐꯨꯝꯌꯥꯟꯄꯥ#
# > pheejam
# = ꯐꯤꯖꯝ
# < ꯐꯦꯖꯝ#
# > henson
# = ꯍꯦꯟꯁꯟ
# < ꯍꯦꯟꯁꯣꯟ#
# > chandel
# = ꯆꯥꯟꯗꯦꯜ
# < ꯆꯥꯟꯗꯦꯜ#
# > inter
# = ꯏꯟꯇꯔ
# < ꯏꯟꯇ꯭ꯔ#
# > balkoty
# = ꯕꯥꯜꯀꯣꯇꯤ
# < ꯕꯦꯂꯇꯀꯇ#
# > yavatmal
# = ꯌꯕꯠꯃꯥꯜ
# < ꯌꯥꯕꯠꯂꯝꯂ#
# > pullapsi
# = ꯄꯨꯜꯂꯞꯁꯤ
# < ꯄꯨꯜꯂꯥꯁꯤꯤ#
# > ansari
# = ꯑꯟꯁꯥꯔꯤ
# < ꯑꯟꯁꯔꯔꯤ#
# > semkhi
# = ꯁꯦꯝꯈꯤ
# < ꯁꯦꯝꯈꯤ#
# > mandla
# = ꯃꯟꯗꯂꯥ
# < ꯃꯟꯗ#
# > ibungngo
# = ꯏꯕꯨꯡꯉꯣ
# < ꯏꯕꯨꯡꯉꯣ#
# > andaman
# = ꯑꯟꯗꯃꯥꯟ
# < ꯑꯟꯟꯗꯥꯟ#
# > adugirane
# = ꯑꯗꯨꯒꯤꯔꯥꯅꯦ
# < ꯑꯗ꯭ꯔꯤꯖꯦ#
# > arappada
# = ꯑꯔꯥꯞꯄꯗ
# < ꯑꯔꯥꯞꯄꯗ#
# > wellington
# = ꯋꯦꯜꯂꯤꯡꯇꯟ
# < ꯂꯦꯜꯂꯤꯡꯡꯟ#
# > porbandar
# = ꯄꯣꯔꯕꯟꯗꯔ
# < ꯄꯣꯔꯥꯟꯗ꯭ꯔ#
# > thajajaba
# = ꯊꯥꯖꯖꯕ
# < ꯊꯥꯖꯖꯕ#
# > apiba
# = ꯑꯄꯤꯕ
# < ꯑꯄꯤꯕ#
# > shivastava
# = ꯁꯤꯚꯥꯁꯇꯚ
# < ꯁꯤꯚꯥꯚꯇ#
# > longview
# = ꯂꯣꯡꯚ꯭ꯌꯨ
# < ꯂꯣꯡꯚꯤꯚ#
# > oiraga
# = ꯑꯣꯢꯔꯒ
# < ꯑꯣꯢꯔꯒ#
# > sanakhi
# = ꯁꯥꯅꯈꯤ
# < ꯁꯅꯥꯈꯤ#
# > bowling
# = ꯕꯣꯂꯤꯡ
# < ꯕꯣꯇꯦꯂꯤꯡ#
# > yanakhi
# = ꯌꯥꯅꯈꯤ
# < ꯌꯥꯈꯈꯤ#
# > azusa
# = ꯑꯖꯨꯁꯥ
# < ꯑꯌꯨꯁꯥ#
# > livermore
# = ꯂꯤꯚꯔꯃꯣꯔ
# < ꯂꯤꯚꯣꯔꯦ#
# > pabunggi
# = ꯄꯥꯕꯨꯡꯒꯤ
# < ꯄꯥꯕꯕꯤꯡꯒꯤ#
# > vysya
# = ꯚꯤꯁ꯭ꯋ
# < ꯚꯤꯁꯤꯌꯥ#
# > platoga
# = ꯄ꯭ꯂꯦꯇꯣꯒ
# < ꯄꯥꯇꯥꯣꯒ#
# > matonda
# = ꯃꯇꯣꯟꯗ
# < ꯃꯇꯣꯟꯗ#
# > balcony
# = ꯕꯦꯜꯀꯣꯅꯤ
# < ꯕꯦꯂꯣꯟꯅꯤ#
# > ortega
# = ꯑꯣꯔꯇꯦꯒꯥ
# < ꯑꯣꯔꯦꯇꯥꯒ#
# > heket
# = ꯍꯦꯀꯦꯠ
# < ꯍꯦꯀꯦꯠ#
# > yumnaaksing
# = ꯌꯨꯝꯅꯥꯛꯁꯤꯡ
# < ꯌꯨꯝꯅꯛꯛꯁꯤꯡ#
# > bhriguvanshi
# = ꯚ꯭ꯔꯤꯒꯨꯋꯟꯁꯤ
# < ꯚꯤꯔꯤꯒꯨꯔꯤꯁꯤꯁ#
# > lampakta
# = ꯂꯝꯄꯥꯛꯇ
# < ꯂꯝꯄꯥꯛꯇ#
# > rajahmundry
# = ꯔꯥꯖꯥꯃꯟꯗ꯭ꯔꯤ
# < ꯔꯥꯖꯥꯝꯕꯔꯔꯗꯁ#
# > kamarhati
# = ꯀꯃꯥꯔꯍꯥꯇꯤ
# < ꯀꯃꯔꯠꯇꯤ#
# > dayton
# = ꯗꯦꯇꯟ
# < ꯗꯥꯇꯣꯟ#
# > shaamu
# = ꯁꯥꯃꯨ
# < ꯁꯥꯃꯨ#
# > alto
# = ꯑꯜꯇꯣ
# < ꯑꯦꯜꯕꯣ#
# > automation
# = ꯑꯣꯇꯣꯃꯦꯁꯟ
# < ꯑꯌꯣꯇꯝꯝꯅꯤ#
# > uchaan
# = ꯎꯆꯥꯟ
# < ꯎꯆꯥꯟ#
# > thouraangsingda
# = ꯊꯧꯔꯥꯡꯁꯤꯡꯗ
# < ꯊꯧꯔꯥꯁꯤꯡꯡꯗ#
# > linni
# = ꯂꯤꯟꯅꯤ
# < ꯂꯤꯟꯅꯤ#
# > infra
# = ꯏꯟꯐ꯭ꯔꯥ
# < ꯏꯟꯟꯐꯔ#
# > pruitt
# = ꯄ꯭ꯔꯨꯢꯠ
# < ꯄ꯭ꯇꯇꯇꯇꯠ#
# > sirsa
# = ꯁꯤꯔꯁꯥ
# < ꯁꯤꯔꯥ#
# > alexandria
# = ꯑꯦꯂꯦꯛꯖꯦꯟꯗ꯭ꯔꯤꯑꯥ
# < ꯑꯦꯦꯦꯀꯟꯗꯔꯤꯌꯥ#
# > waarisingda
# = ꯋꯥꯔꯤꯁꯤꯡꯗ
# < ꯋꯥꯔꯤꯁꯤꯡꯗ#
# > sijinnanaba
# = ꯁꯤꯖꯤꯟꯅꯅꯕ
# < ꯁꯤꯖꯤꯟꯅꯕ#
# > media
# = ꯃꯤꯗꯤꯑꯥ
# < ꯃꯦꯗꯤꯌꯥ#
# > chhindwara
# = ꯆꯤꯟꯗ꯭ꯋꯥꯔꯥ
# < ꯆꯤꯟꯗ꯭ꯋꯥꯔ#
# > machaani
# = ꯃꯆꯥꯅꯤ
# < ꯃꯆꯥꯅꯤ#
# > laifamdagi
# = ꯂꯥꯢꯐꯝꯗꯒꯤ
# < ꯂꯥꯢꯐꯝꯗꯒꯤ#
# > ebirammi
# = ꯏꯕꯤꯔꯝꯃꯤ
# < ꯏꯕꯔꯦꯝꯤꯤ#
# > highland
# = ꯍꯥꯢꯂꯦꯟꯗ
# < ꯍꯤꯒꯣꯟꯗ#
# > theratipally
# = ꯊꯦꯔꯥꯇꯤꯄꯂꯤ
# < ꯊꯦꯔꯥꯇꯩꯇꯤꯤ#
# > yaithing
# = ꯌꯥꯢꯊꯤꯡ
# < ꯌꯥꯢꯊꯤꯡ#
# > poupi
# = ꯄꯧꯄꯤ
# < ꯄꯧꯄꯤ#
# > panggansinggi
# = ꯄꯥꯡꯒꯟꯁꯤꯡꯒꯤ
# < ꯄꯪꯡꯅꯁꯤꯡꯒꯤꯡꯤ#
# > thaa
# = ꯊꯥ
# < ꯊꯥ#
# > sen
# = ꯁꯦꯟ
# < ꯁꯦꯟ#
# > shoppers
# = ꯁꯣꯄꯔꯁ
# < ꯁꯣꯄꯦꯁꯔ#
# > jalaun
# = ꯖꯂꯣꯎꯟ
# < ꯖꯂꯥꯨꯟ#
# > nagraj
# = ꯅꯒꯔꯥꯖ
# < ꯅꯥꯔꯖꯖ#
# > waarisinggi
# = ꯋꯥꯔꯤꯁꯤꯡꯒꯤ
# < ꯋꯥꯔꯤꯡꯁꯤ#
# > governor
# = ꯒꯣꯚꯔꯅꯔ
# < ꯒꯣꯚꯦꯔꯔꯤ#
# > jamaica
# = ꯖꯃꯥꯢꯀꯥ
# < ꯖꯥꯃꯥꯀꯀꯥ#
# > irenpungni
# = ꯏꯔꯦꯟꯄꯨꯡꯅꯤ
# < ꯏꯔꯦꯟꯄꯅꯤ#
# > romeoville
# = ꯔꯣꯃꯤꯑꯣꯚꯤꯜ
# < ꯔꯣꯃꯣꯚꯂꯦ#
# > kwa
# = ꯀ꯭ꯋꯥ
# < ꯀ꯭ꯋꯥꯂ#
# > moses
# = ꯃꯣꯁꯦꯁ
# < ꯃ꯭ꯁꯦꯁ#
# > thajanabi
# = ꯊꯥꯖꯅꯕꯤ
# < ꯊꯥꯖꯅꯕꯤ#
# > haraobada
# = ꯍꯔꯥꯎꯕꯗ
# < ꯍꯔꯥꯎꯕꯗ#
# > elat
# = ꯏꯂꯥꯠ
# < ꯏꯕꯥꯠ#
# > poireitonna
# = ꯄꯣꯢꯔꯩꯇꯣꯟꯅ
# < ꯄꯣꯢꯔꯦꯟꯅꯅ#
# > lengba
# = ꯂꯦꯡꯕ
# < ꯂꯦꯡꯕ#
# > humputara
# = ꯍꯨꯝꯄꯨꯇꯔꯥ
# < ꯍꯨꯝꯨꯔꯨꯇꯥꯔ#
# > streamwood
# = ꯁꯇ꯭ꯔꯤꯝꯋꯨꯗ
# < ꯁꯦꯠꯔꯦꯃꯗ#
# > konchin
# = ꯀꯣꯟꯆꯤꯟ
# < ꯀꯣꯟꯆꯤꯟ#
# > renuka
# = ꯔꯦꯅꯨꯀꯥ
# < ꯔꯦꯅꯨꯀ#
# > panada
# = ꯄꯅꯥꯗ
# < ꯄꯅꯗ#
# > khutmaba
# = ꯈꯨꯠꯃꯥꯕ
# < ꯈꯨꯠꯃꯥꯝꯕ#
# > gehlot
# = ꯒꯦꯍꯂꯣꯠ
# < ꯖꯦꯍꯣꯂꯣꯠ#
# > maningda
# = ꯃꯅꯤꯡꯗ
# < ꯃꯅꯤꯡꯗ#
# > asaaba
# = ꯑꯁꯥꯕ
# < ꯑꯁꯥꯕ#
# > larsen
# = ꯂꯥꯔꯁꯦꯟ
# < ꯂꯥꯔꯁꯦꯟ#
# > sintaaknabi
# = ꯁꯤꯟꯇꯥꯛꯅꯕꯤ
# < ꯁꯤꯟꯇꯛꯛꯇꯤꯕꯅꯤ#
# > konark
# = ꯀꯣꯅꯥꯔꯛ
# < ꯀꯣꯅꯔꯛ#
# > manna
# = ꯃꯟꯅꯥ
# < ꯃꯥꯟꯅ#
# > johnson
# = ꯖꯣꯟꯁꯟ
# < ꯖꯣꯑ꯭ꯟꯟꯁ#
# > thoklakpani
# = ꯊꯣꯛꯂꯛꯄꯅꯤ
# < ꯊꯣꯛꯂꯛꯄꯅꯤ#
# > huraallaga
# = ꯍꯨꯔꯥꯜꯂꯒ
# < ꯍꯨꯔꯜꯂꯒ#
# > hidaakloisingsi
# = ꯍꯤꯗꯥꯛꯂꯣꯢꯁꯤꯡꯁꯤ
# < ꯍꯤꯗꯥꯛꯁꯣꯟꯁꯤꯤꯡ#
# > sinnakhre
# = ꯁꯤꯟꯅꯈ꯭ꯔꯦ
# < ꯁꯤꯟꯅꯛꯈ꯭ꯔꯦ#
# > kayadu
# = ꯀꯌꯥꯗꯨ
# < ꯀꯌꯥꯗꯨ#
# > milolna
# = ꯃꯤꯂꯣꯜꯅ
# < ꯃꯤꯂꯣꯜꯅ#
# > cypress
# = ꯁꯥꯢꯄ꯭ꯔꯦꯁ
# < ꯄꯤꯄꯔꯁ#
# > rajesh
# = ꯔꯥꯖꯦꯁ
# < ꯔꯥꯖꯦꯁ#
# > bhadouriya
# = ꯚꯥꯗꯧꯔꯤꯌꯥ
# < ꯚꯗꯗꯨꯌꯥ#
# > safu
# = ꯁꯥꯐꯨ
# < ꯁꯥꯨ#
# > dimapurgi
# = ꯗꯤꯃꯥꯄꯨꯔꯒꯤ
# < ꯗꯤꯃꯃꯥꯄꯔꯔꯒꯤ#
# > nifumapan
# = ꯅꯤꯐꯨꯃꯥꯄꯟ
# < ꯅꯤꯐꯃꯃꯥꯟ#
# > shamu
# = ꯁꯥꯃꯨ
# < ꯁꯃꯨ#
# > lanjaonachingba
# = ꯂꯥꯟꯖꯥꯎꯅꯆꯤꯡꯕ
# < ꯂꯥꯟꯖꯣꯟꯆꯆꯤꯕꯕ#
# > maannana
# = ꯃꯥꯟꯅꯅ
# < ꯃꯥꯟꯅ#
# > vernon
# = ꯚꯔꯅꯟ
# < ꯚꯦꯔꯣꯟ#
# > spanish
# = ꯁ꯭ꯄꯦꯅꯤꯁ
# < ꯁ꯭ꯁꯅꯤꯁ#
# > oiraki
# = ꯑꯣꯢꯔꯛꯏ
# < ꯑꯣꯢꯔꯛꯀꯤ#
# > srivastava
# = ꯁꯥꯔꯤꯕꯥꯁꯇꯕ
# < ꯁ꯭ꯇꯚꯁꯁꯚꯇꯇ#
# > yin
# = ꯌꯤꯟ
# < ꯌꯤꯟ#
# > bhatnagar
# = ꯚꯠꯅꯥꯒꯔ
# < ꯚꯥꯠꯅꯔꯒ#
# > sijinnafamsi
# = ꯁꯤꯖꯤꯟꯅꯐꯝꯁꯤ
# < ꯁꯤꯖꯤꯟꯅꯤꯁꯝꯁꯁꯤꯁꯤ#
# > ithatsingda
# = ꯏꯊꯠꯁꯤꯡꯗ
# < ꯏꯊꯠꯁꯤꯡꯗ#
# > vijayawada
# = ꯕꯤꯖꯦꯌꯋꯥꯗꯥ
# < ꯚꯤꯖꯥꯌꯥꯗ#
# > salas
# = ꯁꯥꯂꯥꯁ
# < ꯁꯥꯥꯂ#
# > durgavanshi
# = ꯗꯨꯔꯒꯥꯋꯟꯁꯤ
# < ꯗꯨꯔꯓꯁꯁꯤꯡꯅꯤ#
# > mani
# = ꯃꯅꯤ
# < ꯃꯅꯤ#
# > ikhaa
# = ꯏꯈꯥ
# < ꯏꯈꯥ#
# > raipur
# = ꯔꯥꯢꯄꯨꯔ
# < ꯔꯥꯢꯄꯨꯔ#
# > nula
# = ꯅꯨꯂꯥ
# < ꯅꯨꯂꯥ#
# > coast
# = ꯀꯣꯁꯠ
# < ꯀꯣꯁꯇ#
# > bara
# = ꯕꯥꯔꯥ
# < ꯕꯔꯥ#
# > siyaram
# = ꯁꯤꯌꯥꯔꯥꯝ
# < ꯁꯤꯌꯥꯝ#
# > godfrey
# = ꯒꯣꯗꯐ꯭ꯔꯦ
# < ꯒꯣꯔꯥꯖꯦ#
# > awangnongpokta
# = ꯑꯋꯥꯡꯅꯣꯡꯄꯣꯛꯇ
# < ꯑꯋꯥꯡꯅꯣꯛꯇ#
# > phungaawaarising
# = ꯐꯨꯡꯒꯥꯋꯥꯔꯤꯁꯤꯡ
# < ꯐꯨꯒꯔꯔꯤꯁꯤꯡ#
# > saogatpasida
# = ꯁꯥꯎꯒꯠꯄꯁꯤꯗ
# < ꯁꯥꯎꯒꯠꯁꯁꯤꯗ#
# > fatima
# = ꯐꯇꯤꯃꯥ
# < ꯐꯇꯤꯃꯥ#
# > kapoor
# = ꯀꯄꯨꯔ
# < ꯀꯄꯄꯔꯔꯣ#
# > cobalt
# = ꯀꯣꯕꯥꯜꯠ
# < ꯀꯕꯂꯦꯜ#
# > porterville
# = ꯄꯣꯔꯇꯔꯕꯤꯜ
# < ꯄꯣꯔꯦꯇꯦꯔꯤ#
# > melbourne
# = ꯃꯦꯜꯕꯣꯔꯟ
# < ꯃꯦꯜꯍꯨꯔꯦꯦ#
# > senbi
# = ꯁꯦꯟꯕꯤ
# < ꯁꯦꯟꯕꯤ#
# > liberty
# = ꯂꯤꯕꯔꯇꯤ
# < ꯂꯤꯕꯦꯔ#
# > chingshu
# = ꯆꯤꯡꯁꯨ
# < ꯆꯤꯡꯁꯨ#
# > tilli
# = ꯇꯤꯜꯂꯤ
# < ꯇꯤꯜꯂꯤ#
# > dibrugarh
# = ꯗꯤꯕ꯭ꯔꯨꯒꯔ
# < ꯗꯤꯕꯨꯔꯚꯊ#
# > fond
# = ꯐꯣꯟꯗ
# < ꯐꯣꯟꯗ#
# > sunteck
# = ꯁꯟꯇꯦꯛ
# < ꯁꯨꯟꯇꯦꯛ#
# > baramula
# = ꯕꯥꯔꯥꯃꯨꯂꯥ
# < ꯕꯔꯔꯥꯂꯂ#
# > tumlibi
# = ꯇꯨꯝꯂꯤꯕꯤ
# < ꯇꯨꯠꯂꯤꯕꯤ#
# > katta
# = ꯀꯠꯇꯥ
# < ꯀꯠꯇ#
# > theinabagi
# = ꯊꯩꯅꯕꯒꯤ
# < ꯊꯩꯅꯕꯒꯤ#
# > mesopotamiagi
# = ꯃꯦꯁꯣꯄꯣꯇꯥꯃꯤꯌꯥꯒꯤ
# < ꯃꯤꯄꯄꯄꯣꯄꯥꯁꯒꯒꯤ#
# > haibadi
# = ꯍꯥꯢꯕꯗꯤ
# < ꯍꯥꯢꯕꯗꯤ#
# > ngamkhidre
# = ꯉꯝꯈꯤꯗ꯭ꯔꯦ
# < ꯉꯝꯈꯤꯗꯔꯦ#
# > leikhidabadagi
# = ꯂꯩꯈꯤꯗꯕꯗꯒꯤ
# < ꯂꯩꯈꯤꯗꯕꯒꯤ#
# > avery
# = ꯑꯦꯕꯔꯤ
# < ꯑꯦꯔꯦꯔꯥꯔ#
# > krueger
# = ꯀ꯭ꯔꯨꯑꯦꯒꯔ
# < ꯀ꯭ꯔꯦꯔꯦ#
# > thousand
# = ꯊꯥꯎꯖꯟꯗ
# < ꯊꯧꯁꯥꯟꯗ#
# > robins
# = ꯔꯣꯕꯤꯟꯁ
# < ꯔꯣꯕꯤꯟꯁꯁ#
# > ithoi
# = ꯏꯊꯣꯢ
# < ꯏꯊꯤ#
# > procter
# = ꯄ꯭ꯔꯣꯛꯇꯔ
# < ꯄ꯭ꯄꯦꯁ꯭ꯔꯔꯤ#
# > karli
# = ꯀꯥꯔꯂꯤ
# < ꯀꯥꯔꯂꯤ#
# > samukol
# = ꯁꯃꯨꯀꯣꯜ
# < ꯁꯃꯀꯥꯀꯣ#
# > chico
# = ꯆꯤꯀꯣ
# < ꯆꯤꯀꯣ#
# > asansol
# = ꯑꯥꯁꯟꯁꯣꯜ
# < ꯑꯁꯥꯟꯁꯣꯜ#
# > waaheini
# = ꯋꯥꯍꯩꯅꯤ
# < ꯋꯥꯍꯤꯅꯤ#
# > tambiba
# = ꯇꯝꯕꯤꯕ
# < ꯇꯝꯕꯤꯕ#
# > goa
# = ꯒꯧꯋꯥ
# < ꯒꯣꯒꯥ#
# > rasheed
# = ꯔꯁꯤꯗ
# < ꯔꯥꯁꯦꯜ#
# > prudential
# = ꯄ꯭ꯔꯨꯗꯦꯟꯁꯤꯌꯜ
# < ꯄꯨꯔꯦꯟꯇꯤꯜ#
# > udhagamandalam
# = ꯎꯙꯒꯃꯟꯗꯂꯝ
# < ꯎꯗꯥꯃꯃꯃꯃꯃ#
# > anput
# = ꯑꯟꯄꯨꯠ
# < ꯑꯦꯟꯄꯁ#
# > tourangbam
# = ꯇꯧꯔꯥꯡꯕꯝ
# < ꯇꯧꯔꯪꯡꯕꯝ#
# > rungta
# = ꯔꯨꯡꯇꯥ
# < ꯔꯨꯡꯇ#
# > amara
# = ꯑꯃꯥꯔꯥ
# < ꯑꯃꯥꯔ#
# > lepnakhibagi
# = ꯂꯦꯞꯅꯈꯤꯕꯒꯤ
# < ꯂꯦꯞꯅꯍꯟꯤꯕꯒꯤ#
# > sakei
# = ꯁꯥꯀꯩ
# < ꯁꯥꯀꯩ#
# > shrivas
# = ꯁ꯭ꯔꯤꯚꯥꯁ
# < ꯁ꯭ꯔꯤꯑꯥꯁ#
# > thoubalna
# = ꯊꯧꯕꯥꯜꯅ
# < ꯊꯧꯕꯥꯟꯗ#
# > chahichadadi
# = ꯆꯍꯤꯆꯥꯗꯗꯤ
# < ꯆꯍꯤꯆꯗꯤꯤꯗ#
# > shakkhangbidriba
# = ꯁꯛꯈꯪꯕꯤꯗ꯭ꯔꯤꯕ
# < ꯁꯥꯈꯪꯈꯈꯤꯗꯔꯕ#
# > phek
# = ꯐꯦꯛ
# < ꯐꯦꯛ#
# > lon
# = ꯅꯣꯟ
# < ꯂꯣꯟ#
# > yaanaba
# = ꯌꯥꯅꯕ
# < ꯌꯥꯅꯕ#
# > chaosangba
# = ꯆꯥꯎꯁꯥꯡꯕ
# < ꯆꯥꯎꯁꯥꯡꯕ#
# > chinagi
# = ꯆꯤꯅꯥꯒꯤ
# < ꯆꯤꯅꯥꯒꯤ#
# > agdistis
# = ꯑꯒꯗꯤꯁꯇꯤꯁ
# < ꯑꯦꯗꯤꯁꯤꯁ#
# > khumangi
# = ꯈꯨꯃꯟꯒꯤ
# < ꯈꯨꯃꯥꯡꯒꯤ#
# > teamlease
# = ꯇꯤꯝꯂꯤꯁ
# < ꯇꯦꯝꯂꯦꯁꯁ#
# > chakrabortty
# = ꯆꯀ꯭ꯔꯕꯣꯔꯇꯤ
# < ꯆꯥꯛꯕꯔꯥꯇꯔ#
# > srinagar
# = ꯁ꯭ꯔꯤꯅꯒꯔ
# < ꯁ꯭ꯔꯦꯅꯤꯅꯔꯔ#
# > yaarani
# = ꯌꯥꯔꯅꯤ
# < ꯌꯥꯔꯅꯤ#
# > suchi
# = ꯁꯨꯆꯤ
# < ꯁꯨꯆꯤ#
# > humfutarataret
# = ꯍꯨꯝꯐꯨꯇꯔꯥꯇꯔꯦꯠ
# < ꯍꯨꯝꯐꯨꯇꯔꯦꯇꯦ#
# > attraa
# = ꯑꯠꯇ꯭ꯔꯥ
# < ꯑꯇꯇ꯭ꯔꯥ#
# > union
# = ꯌꯨꯅꯤꯑꯟ
# < ꯎꯅꯣꯟ#
# > khumnaribi
# = ꯈꯨꯝꯅꯔꯤꯕꯤ
# < ꯈꯨꯝꯅꯔꯤꯔꯤꯕꯤ#
# > potfam
# = ꯄꯣꯠꯐꯝ
# < ꯄꯣꯐꯝꯐꯝ#
# > nakpada
# = ꯅꯛꯄꯗ
# < ꯅꯥꯛꯄꯗ#
# > meeoi
# = ꯃꯤꯑꯣꯢ
# < ꯃꯤꯑꯣꯢ#
# > fischer
# = ꯐꯤꯁꯆꯔ
# < ꯐꯤꯁꯔꯔ#
# > maran
# = ꯃꯔꯟ
# < ꯃꯔꯥꯟ#
# > thindoraki
# = ꯊꯤꯟꯗꯣꯔꯛꯏ
# < ꯊꯤꯟꯗꯣꯔꯤꯛꯤ#
# > shaakei
# = ꯁꯥꯀꯩ
# < ꯁꯥꯀꯩ#
# > thinli
# = ꯊꯤꯟꯂꯤ
# < ꯊꯤꯟꯂꯤ#
# > chingburoisinggi
# = ꯆꯤꯡꯕꯨꯔꯣꯢꯁꯤꯡꯒꯤ
# < ꯆꯤꯡꯕꯥꯁꯥꯗꯒꯤ#
# > ibadubu
# = ꯏꯕꯗꯨꯕꯨ
# < ꯏꯕꯥꯗꯨ#
# > meeteisingna
# = ꯃꯤꯇꯩꯁꯤꯡꯅ
# < ꯃꯤꯇꯩꯇꯤꯡꯅ#
# > sajina
# = ꯁꯖꯤꯅ
# < ꯁꯥꯖꯤꯅ#
# > yennei
# = ꯌꯦꯟꯅꯩ
# < ꯌꯦꯟꯅꯩ#
# > laangbi
# = ꯂꯥꯡꯕꯤ
# < ꯂꯥꯡꯕꯤ#
# > jalpaiguri
# = ꯖꯜꯄꯥꯢꯒꯨꯔꯤ
# < ꯖꯄꯄꯄꯔꯤꯤꯒꯤ#
# > thongdagi
# = ꯊꯣꯡꯗꯒꯤ
# < ꯊꯣꯡꯒꯒꯤ#
# > phaktoklaga
# = ꯐꯥꯛꯇꯣꯛꯂꯒ
# < ꯐꯥꯛꯇꯣꯛꯂꯒ#
# > wilkerson
# = ꯋꯤꯜꯀꯔꯁꯟ
# < ꯂꯤꯜꯂꯦꯔꯛꯟꯁꯣ#
# > solotkhaipam
# = ꯁꯣꯂꯣꯠꯈꯥꯢꯄꯝ
# < ꯁꯣꯂꯤꯆꯣꯐꯝꯝꯝꯝ#
# > papers
# = ꯄꯦꯄꯔꯁ
# < ꯄꯥꯄꯦꯁꯦꯔ#
# > nakshatra
# = ꯅꯛꯁꯇ꯭ꯔ
# < ꯅꯛꯁꯔ꯭ꯔ#
# > paanpaki
# = ꯄꯥꯟꯄꯀꯤ
# < ꯄꯥꯟꯅꯛꯛꯤ#
# > saraswatigi
# = ꯁꯔꯁ꯭ꯋꯇꯤꯒꯤ
# < ꯁꯔꯥꯁꯇꯇꯔꯤꯒꯤ#
# > chenningpaki
# = ꯆꯦꯟꯅꯤꯡꯄꯀꯤ
# < ꯆꯦꯟꯅꯤꯟꯄꯥꯛꯒꯤ#
# > kheer
# = ꯈꯤꯔ
# < ꯈꯩꯔꯔ#
# > chattaba
# = ꯆꯠꯇꯕ
# < ꯆꯠꯇꯕ#
# > khotnabagi
# = ꯈꯣꯠꯅꯕꯒꯤ
# < ꯈꯣꯠꯅꯅꯕꯒꯤ#
# > chavez
# = ꯆꯥꯕꯦꯖ
# < ꯆꯥꯚꯦ#
# > cutler
# = ꯀꯠꯂꯔ
# < ꯀꯨꯠꯂꯔꯔ#
# > tripura
# = ꯇ꯭ꯔꯤꯄꯨꯔꯥ
# < ꯇ꯭ꯔꯨꯔꯥꯇ#
# > khanghannaba
# = ꯈꯪꯍꯟꯅꯕ
# < ꯈꯪꯍꯟꯅꯕ#
# > varma
# = ꯚꯔꯃ
# < ꯚꯥꯔꯃꯥ#
# > bugalia
# = ꯕꯨꯒꯥꯂꯤꯌꯥ
# < ꯕꯨꯒꯥꯂꯤ#
# > dwarikesh
# = ꯗ꯭ꯋꯥꯔꯤꯀꯦꯁ
# < ꯗ꯭ꯋꯥꯢꯅꯦꯁ#
# > jivani
# = ꯖꯤꯚꯥꯅꯤ
# < ꯖꯤꯔꯥꯅꯤ#
# > taylorsville
# = ꯇꯦꯂꯔꯁꯚꯤꯜ
# < ꯇꯥꯂꯣꯔꯦꯜꯦꯦ#
# > sheithai
# = ꯁꯩꯊꯥꯢ
# < ꯁꯩꯊꯥꯢ#
# > phaahoubagi
# = ꯐꯥꯍꯧꯕꯒꯤ
# < ꯐꯥꯍꯧꯕꯒꯤ#
# > lairikyenbamlol
# = ꯂꯥꯢꯔꯤꯛꯌꯦꯟꯕꯝꯂꯣꯜ
# < ꯂꯥꯢꯔꯤꯛꯂꯣꯝꯅ#
# > mukherjee
# = ꯃꯨꯈꯔꯖꯤ
# < ꯃꯨꯈ꯭ꯔꯦꯦ#
# > world
# = ꯋꯔꯜꯗ
# < ꯋꯣꯔꯦꯜ#
# > thunglure
# = ꯊꯨꯡꯂꯨꯔꯦ
# < ꯊꯨꯡꯂꯔꯦꯔ#
# > orissa
# = ꯑꯣꯔꯤꯁꯥ
# < ꯑꯣꯔꯤꯁꯀ#
# > khanthakho
# = ꯈꯟꯊꯈꯣ
# < ꯈꯟꯊꯊꯈꯣ#
# > boise
# = ꯕꯣꯢꯁ
# < ꯕꯣꯑꯦꯔꯦ#
# > palamba
# = ꯄꯥꯂꯝꯕ
# < ꯄꯥꯂꯝꯕ#
# > mahoney
# = ꯃꯍꯣꯅꯤ
# < ꯃꯍꯣꯅꯤ#
# > ngaksennanaba
# = ꯉꯥꯛꯁꯦꯟꯅꯅꯕ
# < ꯉꯥꯛꯁꯦꯅꯅ#
# > meeteilon
# = ꯃꯤꯇꯩꯂꯣꯟ
# < ꯃꯤꯇꯩꯂꯣꯟ#
# > khangbidraba
# = ꯈꯪꯕꯤꯗ꯭ꯔꯕ
# < ꯈꯪꯕꯤꯔ꯭ꯗꯗ#
# > international
# = ꯏꯟꯇꯔꯅꯦꯁꯅꯦꯜ
# < ꯏꯟꯇꯦꯟꯅꯦꯔꯤ#
# > pikhi
# = ꯄꯤꯈꯤ
# < ꯄꯤꯈꯤ#
# > potahallu
# = ꯄꯣꯊꯥꯍꯜꯂꯨ
# < ꯄꯣꯇꯥꯜꯂꯨ#
# > khundariba
# = ꯈꯨꯟꯗꯥꯔꯤꯕ
# < ꯈꯨꯟꯗꯔꯔꯤꯕ#
# > deo
# = ꯗꯤꯑꯣ
# < ꯗꯣ#
# > dungarpur
# = ꯗꯨꯡꯒꯔꯄꯨꯔ
# < ꯗꯨꯔꯔꯥꯄꯔ#
# > rehman
# = ꯔꯦꯍꯃꯟ
# < ꯔꯤꯃꯦꯟ#
# > yenthoklaba
# = ꯌꯦꯟꯊꯣꯛꯂꯕ
# < ꯌꯦꯟꯊꯣꯛꯂꯕ#
# > aditya
# = ꯑꯥꯗꯤꯠꯇ꯭ꯌ
# < ꯑꯗꯤꯇꯥ#
# > gillette
# = ꯖꯤꯂꯦꯠ
# < ꯒꯤꯂꯦꯠꯁꯦ#
# > arshad
# = ꯑꯔꯁꯗ
# < ꯑꯥꯔꯥꯗ#
# > dhabi
# = ꯙꯥꯕꯤ
# < ꯗꯥꯕꯤ#
# > azamgarh
# = ꯑꯥꯖꯝꯒꯔ
# < ꯑꯃꯥꯝꯒꯔ#
# > iraqta
# = ꯏꯔꯥꯛꯇ
# < ꯏꯔꯥꯛꯇ#
# > welding
# = ꯋꯦꯜꯗꯤꯡ
# < ꯋꯦꯜꯗꯤꯡ#
# > dhar
# = ꯙꯥꯔ
# < ꯙꯔꯔ#
# > bishnupur
# = ꯕꯤꯁꯅꯨꯄꯨꯔ
# < ꯕꯤꯅꯨꯛꯇꯨꯔ#
# > sunnyvale
# = ꯁꯅꯤꯋꯦꯜ
# < ꯁꯨꯟꯅꯤꯌꯂꯜ#
# > rajnandgaon
# = ꯔꯥꯖꯅꯟꯗꯒꯥꯎ
# < ꯔꯥꯖꯖꯗꯡꯅ#
# > marifumangaa
# = ꯃꯔꯤꯐꯨꯃꯉꯥ
# < ꯃꯔꯤꯐꯨꯃꯉꯥ#
# > leisangthem
# = ꯂꯩꯁꯥꯡꯊꯦꯝ
# < ꯂꯩꯁꯥꯡꯊꯦ#
# > benson
# = ꯕꯦꯟꯁꯟ
# < ꯕꯦꯟꯁꯣꯟ#
# > cherolna
# = ꯆꯦꯔꯣꯜꯅ
# < ꯆꯦꯔꯣꯜꯅ#
# > yokhatpagi
# = ꯌꯣꯈꯠꯄꯒꯤ
# < ꯌꯣꯈꯥꯠꯄꯒꯤ#
# > chamba
# = ꯆꯝꯕꯥ
# < ꯆꯝꯕ#
# > mediterranean
# = ꯃꯦꯗꯤꯇꯔꯔꯦꯅꯤꯌꯟ
# < ꯃꯦꯗ꯭ꯔꯤꯇꯦꯦꯟꯟ#
# > sangagi
# = ꯁꯥꯉꯥꯒꯤ
# < ꯁꯥꯒꯒꯤ#
# > round
# = ꯔꯥꯎꯟꯗ
# < ꯔꯧꯟꯗ#
# > nasreen
# = ꯅꯁ꯭ꯔꯤꯟ
# < ꯅꯁꯦꯔꯟ#
# > lingkhatlami
# = ꯂꯤꯡꯈꯠꯂꯝꯏ
# < ꯂꯤꯡꯈꯠꯂꯝꯃꯤ#
# > utilities
# = ꯌꯨꯇꯤꯂꯤꯇꯤꯁ
# < ꯌꯨꯠꯇꯤꯁꯤꯌꯦꯁ#
# > tehri
# = ꯇꯦꯍꯔꯤ
# < ꯇꯤꯚ꯭ꯔꯩ#
# > alhambra
# = ꯑꯜꯍꯝꯕ꯭ꯔꯥ
# < ꯑꯜꯍꯔꯦꯔꯔꯥ#
# > mcpherson
# = ꯃꯛꯐꯔꯁꯟ
# < ꯃꯦꯦꯦꯔꯣꯟ#
# > arellano
# = ꯑꯔꯦꯂꯥꯅꯣ
# < ꯑꯦꯦꯂꯂꯣꯟ#
# > database
# = ꯗꯥꯇꯥꯕꯦꯁ
# < ꯗꯥꯕꯚꯦꯁ#
# > fullerton
# = ꯐꯨꯂꯔꯇꯟ
# < ꯐꯦꯂꯦꯔ#
# > heisnam
# = ꯍꯩꯁꯅꯥꯝ
# < ꯍꯩꯁꯅꯝ#
# > lomle
# = ꯂꯣꯝꯂꯦ
# < ꯂꯣꯝꯂꯦ#
# > ocoee
# = ꯑꯣꯀꯣꯏ
# < ꯑꯣꯀꯦꯅꯤ#
# > baltimore
# = ꯕꯥꯜꯇꯤꯃꯣꯔ
# < ꯕꯦꯇꯇꯦꯅꯔꯦ#
# > haibadagi
# = ꯍꯥꯢꯕꯗꯒꯤ
# < ꯍꯥꯢꯕꯗꯒꯤ#
# > cochin
# = ꯀꯣꯆꯤꯟ
# < ꯀꯣꯢꯆꯤꯟ#
# > senthang
# = ꯁꯦꯟꯊꯪ
# < ꯁꯦꯟꯊꯪ#
# > phouba
# = ꯐꯧꯕ
# < ꯐꯧꯕ#
# > euro
# = ꯌꯨꯔꯣ
# < ꯏꯌꯨꯔ#
# > chanei
# = ꯆꯥꯅꯩ
# < ꯆꯥꯅꯩ#
# > thanjavur
# = ꯊꯟꯖꯥꯕꯨꯔ
# < ꯊꯥꯖꯗꯔꯔꯨꯔ#
# > orchha
# = ꯑꯣꯔꯆꯥ
# < ꯑꯣꯔꯥ#
# > mehendale
# = ꯃꯦꯍꯦꯟꯗꯦꯜ
# < ꯃꯦꯍꯦꯟꯗꯦ#
# > ikha
# = ꯏꯈꯥ
# < ꯏꯈꯥ#
# > danville
# = ꯗꯦꯟꯚꯤꯜ
# < ꯗꯥꯟꯕꯦꯂꯦ#
# > estates
# = ꯏꯁ꯭ꯇꯦꯠꯁ
# < ꯏꯁꯦꯇꯦꯁꯁ#
# > maraktasu
# = ꯃꯔꯛꯇꯁꯨ
# < ꯃꯔꯥꯇꯁꯁ#
# > loubukta
# = ꯂꯧꯕꯨꯛꯇ
# < ꯂꯧꯕꯤꯇꯇꯛ#
# > siel
# = ꯁꯤꯜ
# < ꯁꯤꯜ#
# > mahankmadaan
# = ꯃꯍꯡꯛꯃꯗꯥꯟ
# < ꯃꯍꯥꯃꯃꯥꯟꯗ#
# > michael
# = ꯃꯥꯢꯀꯦꯜ
# < ꯃꯥꯦꯦꯜ#
# > nodesna
# = ꯅꯣꯗꯁꯅ
# < ꯅꯣꯗꯦꯁꯅ#
# > kettering
# = ꯀꯦꯠꯇꯔꯤꯡ
# < ꯀꯦꯇꯦꯔꯦꯟꯒꯤ#
# > minungsi
# = ꯃꯤꯅꯨꯡꯁꯤ
# < ꯃꯤꯅꯨꯡꯁꯤꯁꯤ#
# > jones
# = ꯖꯣꯟꯁ
# < ꯖꯣꯅꯦꯁ#
# > humfunipaan
# = ꯍꯨꯝꯐꯨꯅꯤꯄꯥꯟ
# < ꯍꯨꯝꯅꯨꯅꯥꯄꯥꯟ#
# > leimaida
# = ꯂꯩꯃꯥꯢꯗ
# < ꯂꯩꯃꯥꯗꯗ#
# > estes
# = ꯏꯁꯇꯤꯁ
# < ꯏꯁꯦꯠꯁ#
# > colombiagi
# = ꯀꯣꯂꯣꯝꯕꯤꯌꯥꯒꯤ
# < ꯀꯣꯂꯣꯝꯕꯥꯒꯤ#
# > carey
# = ꯀꯦꯔꯤ
# < ꯀꯔꯦꯌ#
# > sweeney
# = ꯁ꯭ꯋꯤꯅꯤ
# < ꯁ꯭ꯦꯦꯌꯅꯩ#
# > faraba
# = ꯐꯥꯔꯕ
# < ꯐꯔꯕ#
# > pradesh
# = ꯄ꯭ꯔꯗꯦꯁ
# < ꯄ꯭ꯔꯤꯁꯁ#
# > manipur
# = ꯃꯅꯤꯄꯨꯔ
# < ꯃꯅꯤꯄꯔ#
# > khngnaraba
# = ꯈꯪꯅꯔꯕ
# < ꯈꯤꯡꯅꯔꯔꯕ#
# > lonsingdi
# = ꯂꯣꯟꯁꯤꯡꯗꯤ
# < ꯂꯣꯟꯁꯤꯡꯗꯤ#
# > yumlingngi
# = ꯌꯨꯝꯂꯤꯡꯉꯤ
# < ꯌꯨꯝꯂꯤꯟꯒꯒꯤ#
# > evanston
# = ꯑꯦꯕꯟꯁꯇꯟ
# < ꯏꯔꯥꯟꯇꯨꯟꯁ#
# > marifumaapan
# = ꯃꯔꯤꯐꯨꯃꯥꯄꯟ
# < ꯃꯔꯤꯐꯨꯃꯔꯥꯄꯥꯟ#
# > hanumangarh
# = ꯍꯅꯨꯃꯥꯟꯒꯔ
# < ꯍꯅꯨꯃꯃꯃꯨꯅꯔꯥ#
# > crest
# = ꯀ꯭ꯔꯦꯁꯠ
# < ꯁꯦꯁꯇ#
# > villa
# = ꯚꯤꯜꯂꯥ
# < ꯚꯤꯜꯂꯥ#
# > marcos
# = ꯃꯥꯔꯀꯣꯁ
# < ꯃꯔꯔꯁꯁꯁ#
# > ramkrishna
# = ꯔꯥꯝꯀ꯭ꯔꯤꯁꯅ
# < ꯔꯝꯔꯤꯟꯁ#
# > brahmapur
# = ꯕ꯭ꯔꯍꯃꯄꯨꯔ
# < ꯕ꯭ꯔꯔꯃꯤꯐꯃ#
# > utpani
# = ꯎꯠꯄꯅꯤ
# < ꯎꯠꯄꯅꯤ#
# > flint
# = ꯐ꯭ꯂꯤꯟꯠ
# < ꯐ꯭ꯂꯤꯟ#
# > majesco
# = ꯃꯖꯦꯁꯀꯣ
# < ꯃꯦꯁꯑꯑꯣ#
# > adusu
# = ꯑꯗꯨꯁꯨ
# < ꯑꯗꯨꯁ#
# > maangbaraa
# = ꯃꯥꯡꯕꯔꯥ
# < ꯃꯥꯡꯕꯔꯥ#
# > eaton
# = ꯏꯇꯟ
# < ꯑꯇꯣꯠꯅ#
# > and
# = ꯑꯦꯟꯗ
# < ꯑꯟꯟꯗ#
# > reese
# = ꯔꯤꯁ
# < ꯔꯤꯁꯦ#
# > shajik
# = ꯁꯖꯤꯛ
# < ꯁꯥꯖꯤꯛ#
# > natraga
# = ꯅꯇ꯭ꯔꯒ
# < ꯅꯠꯇꯔꯒ#
# > nungsiraba
# = ꯅꯨꯡꯁꯤꯔꯕ
# < ꯅꯨꯡꯁ꯭ꯔꯕ#
# > yinyangsi
# = ꯌꯤꯟꯌꯥꯡꯁꯤ
# < ꯌꯤꯟꯅꯤꯁꯁꯤꯡ#
# > leirese
# = ꯂꯩꯔꯦꯁꯦ
# < ꯂꯩꯔꯦꯦꯦ#
# > webb
# = ꯋꯦꯕ
# < ꯋꯦꯕꯦ#
# > chetan
# = ꯆꯦꯇꯟ
# < ꯆꯦꯇꯟ#
# > vista
# = ꯚꯤꯁꯇꯥ
# < ꯚꯤꯁꯇ#
# > naoshekpam
# = ꯅꯥꯎꯁꯦꯛꯄꯝ
# < ꯅꯥꯎꯁꯦꯛ#
# > polaang
# = ꯄꯣꯂꯥꯡ
# < ꯄꯣꯂꯥꯡ#
# > athak
# = ꯑꯊꯛ
# < ꯑꯊꯥꯛ#
# > maapangi
# = ꯃꯥꯄꯟꯒꯤ
# < ꯃꯥꯥꯢꯉꯥꯒꯤ#
# > thaagonnaba
# = ꯊꯥꯒꯣꯟꯅꯕ
# < ꯊꯥꯑꯣꯡꯅꯕ#
# > khaliq
# = ꯈꯥꯂꯤꯛ
# < ꯈꯕꯂꯤ#
# > heishnam
# = ꯍꯩꯁꯅꯥꯝ
# < ꯍꯩꯁꯤꯝꯅ#
# > dhindhwal
# = ꯙꯤꯟꯙꯋꯥꯜ
# < ꯈꯤꯟꯗꯥꯔꯜ#
# > lepkhiba
# = ꯂꯦꯞꯈꯤꯕ
# < ꯂꯦꯞꯈꯤꯕ#
# > loki
# = ꯂꯣꯀꯤ
# < ꯂꯣꯀꯤ#
# > davidson
# = ꯗꯦꯕꯤꯗꯁꯟ
# < ꯗꯥꯚꯁꯤꯌꯟꯁꯤ#
# > infobeans
# = ꯏꯟꯐꯣꯕꯤꯟꯁ
# < ꯏꯟꯖꯣꯔꯁꯦꯕꯟꯁ#
# > napa
# = ꯅꯥꯄꯥ
# < ꯅꯥꯄ#
# > chaasi
# = ꯆꯥꯁꯤ
# < ꯆꯥꯁꯤ#
# > newark
# = ꯅꯤꯎꯑꯔꯛ
# < ꯅꯦꯋꯥꯛ#
# > rivas
# = ꯔꯤꯚꯥꯁ
# < ꯔꯤꯕꯁꯥ#
# > combs
# = ꯀꯣꯝꯁ
# < ꯀꯣꯝꯕꯦꯁ#
# > furuki
# = ꯐꯨꯔꯨꯀꯤ
# < ꯐꯨꯔꯤꯛꯤ#
# > chingshaang
# = ꯆꯤꯡꯁꯥꯡ
# < ꯆꯤꯡꯁꯥꯡ#
# > kentwood
# = ꯀꯦꯟꯠꯋꯨꯗ
# < ꯀꯦꯟꯋꯣꯗꯣꯗ#
# > chaorammi
# = ꯆꯥꯎꯔꯝꯃꯤ
# < ꯆꯥꯎꯔꯝꯃꯤ#
# > houba
# = ꯍꯧꯕ
# < ꯍꯧꯕ#
# > navkar
# = ꯅꯚꯀꯥꯔ
# < ꯅꯥꯔꯔ#
# > houi
# = ꯍꯧꯏ
# < ꯍꯧꯏ#
# > yeithokkhi
# = ꯌꯩꯊꯣꯛꯈꯤ
# < ꯌꯩꯊꯣꯛꯈꯤ#
# > faahanli
# = ꯐꯥꯍꯟꯂꯤ
# < ꯐꯥꯍꯟꯂꯤ#
# > chathallakpa
# = ꯆꯠꯍꯜꯂꯛꯄ
# < ꯆꯠꯊꯥꯛꯂꯛꯄ#
# > gandharigi
# = ꯒꯥꯟꯙꯥꯔꯤꯒꯤ
# < ꯒꯥꯙꯃꯃꯔꯤꯒꯤ#
# > mermaidsinggi
# = ꯃꯔꯃꯦꯗꯁꯤꯡꯒꯤ
# < ꯃꯔꯃꯥꯔꯤꯁꯤꯡꯒꯤ#
# > cigniti
# = ꯁꯤꯒꯅꯤꯇꯤ
# < ꯁꯤꯁꯇꯤꯤꯇꯤ#
# > taipangpal
# = ꯇꯥꯢꯄꯪꯄꯥꯜ
# < ꯇꯥꯢꯄꯪꯄꯜ#
# > oracle
# = ꯑꯣꯔꯦꯀꯜ
# < ꯑꯣꯔꯥꯠ#
# > shaji
# = ꯁꯥꯖꯤ
# < ꯁꯖꯤ#
# > khanlaba
# = ꯈꯟꯂꯕ
# < ꯈꯟꯂꯕ#
# > nongchup
# = ꯅꯣꯡꯆꯨꯞ
# < ꯅꯣꯡꯆꯨꯞ#
# > famgi
# = ꯐꯝꯒꯤ
# < ꯐꯝꯒꯤ#
# > thamfamni
# = ꯊꯝꯐꯝꯅꯤ
# < ꯊꯝꯐꯝꯅꯤ#
# > singha
# = ꯁꯤꯡꯍꯥ
# < ꯁꯤꯡꯍ#
# > rosemead
# = ꯔꯣꯁꯃꯤꯗ
# < ꯔꯣꯁꯤꯌꯝꯗ#
# > yengkhatpa
# = ꯌꯦꯡꯈꯠꯄ
# < ꯌꯦꯡꯈꯠꯄ#
# > kakwa
# = ꯀꯛꯋꯥ
# < ꯀꯥꯛꯥ#
# > chada
# = ꯆꯥꯗꯥ
# < ꯆꯥꯗ#
# > winter
# = ꯋꯤꯟꯇꯔ
# < ꯋꯤꯟꯇ꯭ꯔꯤ#
# > waangkhi
# = ꯋꯥꯡꯈꯤ
# < ꯋꯥꯡꯈꯤ#
# > laihuida
# = ꯂꯥꯢꯍꯨꯢꯗ
# < ꯂꯥꯢꯈꯗ#
# > ayaambagi
# = ꯑꯌꯥꯝꯕꯒꯤ
# < ꯑꯌꯥꯝꯕꯒꯤ#
# > agrahari
# = ꯑꯒ꯭ꯔꯍꯔꯤ
# < ꯑꯥꯔꯥꯔꯥꯃꯤ#
# > saharan
# = ꯁꯍꯥꯔꯥꯟ
# < ꯁꯥꯍꯟꯔꯟ#
# > phenix
# = ꯐꯦꯅꯤꯛꯁ
# < ꯐꯦꯅꯤꯛ#
# > falls
# = ꯐꯣꯜꯁ
# < ꯐꯜꯂ#
# > amadani
# = ꯑꯃꯗꯅꯤ
# < ꯑꯃꯥꯅꯅꯤ#
# > pukhrambam
# = ꯄꯨꯈ꯭ꯔꯝꯕꯝ
# < ꯄꯨꯈ꯭ꯈꯔꯝꯕꯥ#
# > priyadarshini
# = ꯄ꯭ꯔꯤꯌꯥꯗꯔꯁꯤꯅꯤ
# < ꯄ꯭ꯔꯦꯥꯥꯔꯔꯁꯅꯁꯀꯤ#
# > vikram
# = ꯕꯤꯀ꯭ꯔꯝ
# < ꯚꯤꯛꯁꯔꯃ#
# > israel
# = ꯏꯖ꯭ꯔꯦꯜ
# < ꯏꯔꯦꯜ#
# > meesingni
# = ꯃꯤꯁꯤꯡꯅꯤ
# < ꯃꯤꯁꯤꯅꯅꯤ#
# > hdfc
# = ꯑꯩꯆꯗꯤꯑꯦꯐꯁꯤ
# < ꯍ꯭ꯗꯦ#
# > laibakki
# = ꯂꯥꯢꯕꯛꯀꯤ
# < ꯂꯥꯢꯕꯛꯀꯤ#
# > siyang
# = ꯁꯤꯌꯥꯡ
# < ꯁꯤꯌꯥꯡ#
# > nizamat
# = ꯅꯤꯓꯥꯃꯠ
# < ꯅꯤꯓꯥꯇꯇ#
# > gopal
# = ꯒꯣꯄꯥꯜ
# < ꯒꯣꯄꯜ#
# > klein
# = ꯀ꯭ꯂꯦꯟ
# < ꯀꯦꯂꯟ#
# > kanglupna
# = ꯀꯥꯡꯂꯨꯞꯅ
# < ꯀꯪꯂꯨꯞꯅ#
# > bismarck
# = ꯕꯤꯖꯃꯥꯔꯛ
# < ꯕꯤꯁꯃꯛ#
# > betul
# = ꯕꯦꯇꯨꯜ
# < ꯕꯦꯇꯦꯜ#
# > khong
# = ꯈꯣꯡ
# < ꯈꯣꯡ#
# > barman
# = ꯕꯔꯃꯟ
# < ꯕꯔꯔꯃꯟ#
# > fampaalda
# = ꯐꯝꯄꯥꯜꯗ
# < ꯐꯝꯄꯥꯜꯄ#
# > singtamni
# = ꯁꯤꯡꯇꯝꯅꯤ
# < ꯁꯤꯡꯅꯤꯅꯤ#
# > simulated
# = ꯁꯤꯃꯨꯂꯦꯇꯦꯗ
# < ꯁꯤꯃꯨꯠꯇꯦ#
# > eastvale
# = ꯏꯁꯠꯚꯦꯜ
# < ꯏꯥꯁꯇꯦꯂꯦ#
# > sovettagi
# = ꯁꯣꯚꯦꯠꯇꯒꯤ
# < ꯁꯣꯇꯦꯖꯒꯤ#
# > freeman
# = ꯐ꯭ꯔꯤꯃꯦꯟ
# < ꯐ꯭ꯃꯦꯟ#
# > shakhenba
# = ꯁꯛꯍꯦꯟꯕ
# < ꯁꯥꯈꯦꯟꯕ#
# > ningthijana
# = ꯅꯤꯡꯊꯤꯖꯅ
# < ꯅꯤꯡꯊꯤꯅ#
# > kenner
# = ꯀꯦꯟꯅꯔ
# < ꯀꯦꯟꯅꯔꯦ#
# > lake
# = ꯂꯦꯛ
# < ꯂꯥꯛ#
# > computerna
# = ꯀꯝꯄꯨꯇꯔꯅ
# < ꯀꯣꯝꯄꯔꯅ#
# > waaheisingsigi
# = ꯋꯥꯍꯩꯁꯤꯡꯁꯤꯒꯤ
# < ꯋꯥꯍꯩꯁꯁꯤꯡꯁꯤ#
# > turkey
# = ꯇꯔꯀꯤ
# < ꯇꯨꯔꯦꯌ#
# > ebada
# = ꯏꯕꯗ
# < ꯏꯕꯗ#
# > hourakkhare
# = ꯍꯧꯔꯛꯈꯔꯦ
# < ꯍꯧꯔꯔꯦꯛ#
# > chandler
# = ꯆꯦꯟꯗ꯭ꯂꯔ
# < ꯆꯟꯟꯦꯦꯔꯦ#
# > ratlam
# = ꯔꯠꯂꯥꯝ
# < ꯔꯥꯠꯂꯝ#
# > laiphamsing
# = ꯂꯥꯢꯐꯝꯁꯤꯡ
# < ꯂꯥꯢꯐꯝꯁꯤꯡꯁ#
# > jose
# = ꯍꯣꯁꯦ
# < ꯖꯣꯑꯦ#
# > ghaziabad
# = ꯘꯥꯖꯤꯑꯥꯕꯥꯗ
# < ꯒꯥꯒꯤꯕꯗ#
# > guwahati
# = ꯒꯨꯋꯥꯍꯥꯇꯤ
# < ꯖꯨꯋꯥꯇꯇꯤ#
# > aegis
# = ꯑꯦꯖꯤꯁ
# < ꯑꯦꯒꯤꯁꯁ#
# > ngakthoki
# = ꯉꯥꯛꯊꯣꯛꯏ
# < ꯉꯥꯛꯈꯣꯢꯏ#
# > galileo
# = ꯒꯦꯂꯤꯂꯤꯑꯣ
# < ꯒꯦꯂꯦꯂꯣ#
# > sinnakhi
# = ꯁꯤꯟꯅꯈꯤ
# < ꯁꯤꯟꯅꯈꯤ#
# > airtel
# = ꯑꯦꯔꯇꯦꯜ
# < ꯑꯦꯔꯦꯇꯣ#
# > dhuburi
# = ꯙꯨꯕꯔꯤ
# < ꯗꯨꯕꯨꯔꯔꯔꯤ#
# > laanna
# = ꯂꯥꯟꯅ
# < ꯂꯥꯟꯅ#
# > khungi
# = ꯈꯨꯟꯒꯤ
# < ꯈꯨꯡꯒꯤ#
# > mapapu
# = ꯃꯄꯥꯄꯨ
# < ꯃꯄꯥꯁ#
# > eningthou
# = ꯏꯅꯤꯡꯊꯧ
# < ꯏꯅꯤꯡꯊꯧ#
# > marry
# = ꯃꯦꯔꯤ
# < ꯃꯔꯔꯌꯤ#
# > burhanpur
# = ꯕꯨꯔꯍꯥꯟꯄꯨꯔ
# < ꯕꯨꯔꯥꯟꯅꯔꯊꯔꯦ#
# > khundaba
# = ꯈꯨꯟꯗꯕ
# < ꯈꯨꯟꯗꯕ#
# > pokhriyal
# = ꯄꯣꯈ꯭ꯔꯤꯌꯜ
# < ꯄꯣꯈꯤꯈ꯭ꯔꯤꯜ#
# > kohima
# = ꯀꯣꯍꯤꯃꯥ
# < ꯀꯣꯍꯤꯌꯥ#
# > thellon
# = ꯊꯦꯜꯂꯣꯟ
# < ꯊꯦꯂꯣꯟ#
# > purnia
# = ꯄꯨꯔꯅꯤꯑꯥ
# < ꯄꯨꯔꯤꯌꯥ#
# > apakngada
# = ꯑꯄꯛꯉꯥꯗ
# < ꯑꯄꯥꯛꯅꯗ#
# > arena
# = ꯑꯔꯤꯅ
# < ꯑꯔꯦꯅꯥ#
# > laipubam
# = ꯂꯥꯢꯄꯨꯕꯝ
# < ꯂꯥꯢꯄꯨꯕꯝ#
# > chirang
# = ꯆꯤꯔꯥꯡ
# < ꯆꯤꯔꯪ#
# > adutani
# = ꯑꯗꯨꯇꯅꯤ
# < ꯑꯗꯨꯅꯥ#
# > mariphumanga
# = ꯃꯔꯤꯐꯨꯃꯉꯥ
# < ꯃꯔꯤꯐꯃꯥ#
# > outage
# = ꯑꯥꯎꯇꯦꯖ
# < ꯑꯧꯇꯒꯦ#
# > tinplate
# = ꯇꯤꯟꯄ꯭ꯂꯦꯠ
# < ꯇꯤꯟꯇꯥꯠ#
# > chinggi
# = ꯆꯤꯡꯒꯤ
# < ꯆꯤꯡꯒꯤ#
# > lainupa
# = ꯂꯥꯢꯅꯨꯄꯥ
# < ꯂꯥꯢꯅꯄꯄ#
# > nucleus
# = ꯅ꯭ꯌꯨꯀ꯭ꯂꯤꯌꯁ
# < ꯅꯨꯌꯦꯁꯁꯨꯁ#
# > laanmeena
# = ꯂꯥꯟꯃꯤꯅ
# < ꯂꯥꯟꯃꯤꯅ#
# > asengbadi
# = ꯑꯁꯦꯡꯕꯗꯤ
# < ꯑꯁꯦꯡꯕꯗꯤ#
# > quintero
# = ꯀ꯭ꯋꯤꯟꯇꯦꯔꯣ
# < ꯀꯨꯢꯔꯔꯣꯃꯣ#
# > springfield
# = ꯁ꯭ꯄ꯭ꯔꯤꯡꯐꯤꯜꯗ
# < ꯁ꯭ꯄꯦꯟꯆ꯭ꯔꯦꯜꯜꯗ#
# > tayde
# = ꯇꯦꯗ
# < ꯇꯥꯗꯦ#
# > bass
# = ꯕꯦꯁ
# < ꯕꯁꯁꯁ#
# > sada
# = ꯁꯥꯗ
# < ꯁꯗꯥ#
# > wamang
# = ꯋꯥꯃꯪ
# < ꯋꯥꯃꯪ#
# > lakpham
# = ꯂꯥꯛꯐꯝ
# < ꯂꯥꯛꯞꯝ#
# > thaangbadi
# = ꯊꯥꯡꯕꯗꯤ
# < ꯊꯥꯡꯕꯗꯒꯤ#
# > montebello
# = ꯃꯣꯟꯇꯤꯕꯦꯂꯣ
# < ꯃꯣꯇꯇꯦꯕꯦꯅꯣ#
# > sathiraba
# = ꯁꯥꯊꯤꯔꯕ
# < ꯁꯥꯊꯤꯔꯕ#
# > mandadi
# = ꯃꯟꯗꯗꯤ
# < ꯃꯟꯗꯗꯤ#
# > jain
# = ꯖꯦꯟ
# < ꯖꯥꯟ#
# > warahi
# = ꯋꯥꯔꯥꯍꯤ
# < ꯋꯥꯔꯥꯢ#
# > dhanbad
# = ꯙꯟꯕꯥꯗ
# < ꯙꯟꯕꯗ#
# > paaba
# = ꯄꯥꯕ
# < ꯄꯥꯕ#
# > sadrisibo
# = ꯁꯥꯗ꯭ꯔꯤꯁꯤꯕꯣ
# < ꯁꯥꯗ꯭ꯁꯤꯕꯣ#
# > somany
# = ꯁꯣꯃꯥꯅꯤ
# < ꯁꯃꯃꯅꯥ#
# > oiringei
# = ꯑꯣꯢꯔꯤꯉꯩ
# < ꯑꯣꯢꯔꯤꯉꯩ#
# > sellers
# = ꯁꯦꯂꯔꯁ
# < ꯁꯦꯜꯂꯦꯔꯔꯁ#
# > luchingduna
# = ꯂꯨꯆꯤꯡꯗꯨꯅ
# < ꯂꯨꯢꯆꯤꯡꯗꯅꯅꯅ#
# > yangoijam
# = ꯌꯥꯡꯒꯣꯢꯖꯝ
# < ꯌꯥꯡꯖꯣꯐꯝ#
# > yotlina
# = ꯌꯣꯠꯂꯤꯅ
# < ꯌꯣꯠꯇꯤꯅ#
# > frederick
# = ꯐ꯭ꯔꯦꯗꯔꯤꯛ
# < ꯐ꯭ꯗꯦꯔꯤꯛꯛ#
# > funggawarising
# = ꯐꯨꯡꯒꯥꯋꯥꯔꯤꯁꯤꯡ
# < ꯐꯨꯡꯒꯥꯋꯋꯤꯡꯁꯤꯡ#
# > bhawaani
# = ꯚꯋꯥꯅꯤ
# < ꯚꯋꯥꯅꯤ#
# > khandelwal
# = ꯈꯟꯗꯦꯜꯋꯥꯜ
# < ꯈꯟꯗꯦꯜꯂ#
# > euro
# = ꯏꯎꯔꯣ
# < ꯏꯌꯨꯉꯣ#
# > potlamsinggi
# = ꯄꯣꯠꯂꯝꯁꯤꯡꯒꯤ
# < ꯄꯣꯠꯂꯝꯝꯤꯤꯁꯤ#
# > shaknari
# = ꯁꯛꯅꯔꯤ
# < ꯁꯥꯛꯔꯔꯤ#
# > maheshwar
# = ꯃꯍꯦꯁ꯭ꯋꯔ
# < ꯃꯍꯦꯁꯔꯔ#
# > foro
# = ꯐꯣꯔꯣ
# < ꯐꯣꯔꯣ#
# > kangleipakpu
# = ꯀꯪꯂꯩꯄꯥꯛꯄꯨ
# < ꯀꯪꯂꯩꯄꯥꯄ#
# > chase
# = ꯆꯦꯁ
# < ꯆꯥꯁꯦ#
# > kramer
# = ꯀ꯭ꯔꯦꯃꯔ
# < ꯀ꯭ꯔꯦꯔ#
# > nandinagari
# = ꯅꯟꯗꯤꯅꯥꯒꯔꯤ
# < ꯅꯟꯗ꯭꯭ꯔꯤꯅꯥꯒꯤ#
# > sheopur
# = ꯁꯤꯑꯣꯄꯨꯔ
# < ꯁꯦꯑꯨꯄꯨꯔ#
# > tamlibasing
# = ꯇꯝꯂꯤꯕꯁꯤꯡ
# < ꯇꯝꯂꯤꯕꯁꯤꯡ#
# > balrampur
# = ꯕꯜꯔꯥꯝꯄꯨꯔ
# < ꯕꯦꯄꯔꯦꯄꯥ#
# > skipper
# = ꯁ꯭ꯀꯤꯄꯔ
# < ꯁ꯭ꯄꯦꯔꯤꯄꯔꯔ#
# > dwevedi
# = ꯗ꯭ꯋꯤꯚꯦꯗꯤ
# < ꯗꯦꯚꯤꯌꯤ#
# > fou
# = ꯐꯧ
# < ꯐꯧ#
# > mariphumaapan
# = ꯃꯔꯤꯐꯨꯃꯥꯄꯟ
# < ꯃꯔꯤꯐꯔꯥꯥꯄꯥ#
# > thaapham
# = ꯊꯥꯐꯝ
# < ꯊꯥꯐꯝ#
# > taohuireng
# = ꯇꯥꯎꯍꯨꯢꯔꯦꯡ
# < ꯇꯥꯎꯍꯧꯔꯤꯡ#
# > howe
# = ꯍꯣꯋꯤ
# < ꯍꯣꯋꯦ#
# > shaaphu
# = ꯁꯥꯐꯨ
# < ꯁꯥꯐꯨ#
# > pamjaba
# = ꯄꯥꯝꯖꯕ
# < ꯄꯝꯖꯕ#
# > indiabulls
# = ꯏꯟꯗꯤꯑꯥꯕꯨꯜꯁ
# < ꯏꯟꯖꯤꯕꯦꯁꯁ#
# > honeywell
# = ꯍꯅꯤꯋꯦꯜ
# < ꯍꯣꯌꯦꯌꯦꯜ#
# > thaadoklamlaga
# = ꯊꯥꯗꯣꯛꯂꯝꯂꯒ
# < ꯊꯥꯗꯣꯛꯈꯜꯂꯒ#
# > sagatlammi
# = ꯁꯥꯒꯠꯂꯝꯃꯤ
# < ꯁꯥꯠꯇꯝꯂꯝꯃꯤ#
# > pong
# = ꯄꯣꯡ
# < ꯄꯣꯡ#
# > babur
# = ꯕꯥꯕꯔ
# < ꯕꯕꯔꯔ#
# > bareli
# = ꯕꯔꯦꯂꯤ
# < ꯕꯔꯦꯜꯂꯤ#
# > cheiraochingda
# = ꯆꯩꯔꯥꯎꯆꯤꯡꯗ
# < ꯆꯩꯔꯥꯢꯆꯤꯡꯗ#
# > ingraj
# = ꯏꯟꯒ꯭ꯔꯥꯖ
# < ꯏꯪꯔꯥꯔꯥ#
# > punge
# = ꯄꯨꯟꯒꯦ
# < ꯄꯨꯡ#
# > paanari
# = ꯄꯥꯅꯔꯤ
# < ꯄꯥꯅꯔꯤ#
# > neal
# = ꯅꯤꯜ
# < ꯅꯦꯜ#
# > yaangkheinipaan
# = ꯌꯥꯡꯈꯩꯅꯤꯄꯥꯟ
# < ꯌꯥꯡꯈꯩꯔꯥꯄ#
# > balaji
# = ꯕꯥꯂꯥꯖꯤ
# < ꯕꯥꯥꯥꯖꯤ#
# > chayetnagalli
# = ꯆꯌꯦꯠꯅꯒꯜꯂꯤ
# < ꯆꯥꯌꯦꯠꯂꯂꯤꯡ#
# > rancho
# = ꯔꯥꯟꯆꯣ
# < ꯔꯥꯟꯆꯣ#
# > tumbada
# = ꯇꯨꯝꯕꯗ
# < ꯇꯨꯝꯕꯗ#
# > waaheina
# = ꯋꯥꯍꯩꯅ
# < ꯋꯥꯍꯦꯅ#
# > ion
# = ꯑꯥꯌꯟ
# < ꯏꯑꯣꯟ#
# > emaalonbu
# = ꯏꯃꯥꯂꯣꯟꯕꯨ
# < ꯏꯃꯥꯎꯅꯕ#
# > waterloo
# = ꯋꯥꯇꯔꯂꯨ
# < ꯋꯥꯇꯣꯔꯣꯣꯣ#
# > uthokchaba
# = ꯎꯊꯣꯛꯆꯕ
# < ꯎꯨꯊꯣꯛꯆꯕ#
# > cerebra
# = ꯁꯦꯔꯦꯕ꯭ꯔꯥ
# < ꯁꯦꯔꯦꯖꯔ#
# > amar
# = ꯑꯃꯔ
# < ꯑꯃꯔꯔ#
# > angelo
# = ꯑꯦꯟꯖꯦꯂꯣ
# < ꯑꯉꯦꯂꯣꯣ#
# > mayekna
# = ꯃꯌꯦꯛꯅ
# < ꯃꯌꯦꯛꯅ#
# > tate
# = ꯇꯦꯠ
# < ꯇꯇꯦ#
# > paomi
# = ꯄꯥꯎꯃꯤ
# < ꯄꯥꯎꯃꯤ#
# > sangrur
# = ꯁꯪꯒ꯭ꯔꯨꯔ
# < ꯁꯪꯔꯨꯔ#
# > kaanglupsigi
# = ꯀꯥꯡꯂꯨꯞꯁꯤꯒꯤ
# < ꯀꯥꯡꯂꯨꯁꯒꯤ#
# > latpaki
# = ꯂꯥꯠꯄꯀꯤ
# < ꯂꯥꯠꯄꯛꯛꯤ#
# > khammam
# = ꯈꯝꯃꯝ
# < ꯈꯝꯝꯝ#
# > sikar
# = ꯁꯤꯀꯥꯔ
# < ꯁꯤꯀꯔ#
# > madina
# = ꯃꯗꯤꯅꯥ
# < ꯃꯗꯤꯅ#
# > darbhanga
# = ꯗꯔꯚꯪꯒꯥ
# < ꯗꯥꯔꯪꯅ#
# > pletoga
# = ꯄ꯭ꯂꯦꯇꯣꯒ
# < ꯄꯣꯂꯣꯒꯒ#
# > summerville
# = ꯁꯃꯔꯚꯤꯜ
# < ꯁꯨꯝꯔꯤꯀꯂꯜ#
# > waco
# = ꯋꯥꯀꯣ
# < ꯋꯥꯀꯣ#
# > waakat
# = ꯋꯥꯀꯠ
# < ꯋꯥꯀꯠꯠ#
# > khatri
# = ꯈꯇ꯭ꯔꯤ
# < ꯈꯠꯇꯔꯤ#
# > asamiya
# = ꯑꯁꯥꯃꯤꯌꯥ
# < ꯑꯁꯥꯃꯤꯌꯥ#
# > phahoubagi
# = ꯐꯥꯍꯧꯕꯒꯤ
# < ꯐꯦꯧꯧꯧꯕꯒꯤ#
# > semsaaba
# = ꯁꯦꯝꯁꯥꯕ
# < ꯁꯦꯝꯁꯥꯕ#
# > iribasingsidagi
# = ꯏꯔꯤꯕꯁꯤꯡꯁꯤꯗꯒꯤ
# < ꯏꯔꯤꯕꯁꯁꯤꯡꯗꯤ#
# > hollywood
# = ꯍꯣꯜꯂꯤꯋꯨꯗ
# < ꯍꯣꯜꯂꯤꯗꯣ#
# > pothaahallu
# = ꯄꯣꯊꯥꯍꯜꯂꯨ
# < ꯄꯣꯊꯥꯥꯍꯣꯂꯣ#
# > cheni
# = ꯆꯦꯅꯤ
# < ꯆꯦꯅꯤ#
# > adkins
# = ꯑꯦꯗꯀꯤꯟꯁ
# < ꯑꯗꯛꯅꯤꯁꯤꯟꯁ#
# > garcia
# = ꯒꯥꯔꯁꯤꯑꯥ
# < ꯒꯔꯤꯌꯥ#
# > lindsey
# = ꯂꯤꯟꯗꯁꯤ
# < ꯂꯤꯟꯁ꯭ꯔꯦ#
# > sumter
# = ꯁꯝꯇꯔ
# < ꯁꯨꯝꯇꯔꯦ#
# > makhel
# = ꯃꯈꯦꯜ
# < ꯃꯈꯦꯜ#
# > kampleks
# = ꯀꯝꯄ꯭ꯂꯦꯛꯁ
# < ꯀꯝꯄꯦꯛꯁꯦꯠꯁ#
# > leipakna
# = ꯂꯩꯄꯥꯛꯅ
# < ꯂꯩꯄꯥꯛꯅ#
# > koukhi
# = ꯀꯧꯈꯤ
# < ꯀꯧꯈꯤ#
# > styrolution
# = ꯁ꯭ꯇꯥꯢꯔꯣꯂꯨꯁꯟ
# < ꯁ꯭ꯇꯦꯔꯣꯂꯣꯟ#
# > samaddar
# = ꯁꯥꯃꯥꯗꯥꯔ
# < ꯁꯃꯥꯅꯔ#
# > ellison
# = ꯏꯂꯤꯁꯟ
# < ꯑꯜꯂꯤꯂꯣꯟꯁꯤ#
# > meetana
# = ꯃꯤꯇꯅ
# < ꯃꯤꯇꯥꯅ#
# > stafford
# = ꯁ꯭ꯇꯦꯐꯣꯔꯗ
# < ꯁ꯭ꯐꯐꯣꯔꯣꯔ#
# > kuantum
# = ꯀꯨꯑꯥꯟꯇꯝ
# < ꯀꯨꯇꯥꯟꯨꯝ#
# > raiganj
# = ꯔꯥꯢꯒꯟꯖ
# < ꯔꯥꯢꯒꯟꯟ#
# > huntsville
# = ꯍꯟꯠꯁꯚꯤꯜ
# < ꯍꯨꯟꯇ꯭ꯔꯦꯜꯂꯦ#
# > lup
# = ꯂꯨꯞ
# < ꯂꯨꯞ#
# > budge
# = ꯕꯗꯖ
# < ꯕꯨꯒꯦꯦ#
# > tekhao
# = ꯇꯦꯈꯥꯎ
# < ꯇꯦꯈꯈꯣ#
# > pharaba
# = ꯐꯥꯔꯕ
# < ꯐꯔꯔꯕ#
# > cambridge
# = ꯀꯦꯝꯕ꯭ꯔꯤꯖ
# < ꯀꯝꯝ꯭ꯔꯦꯒꯤ#
# > dearborn
# = ꯗꯤꯑꯔꯕꯣꯔꯟ
# < ꯗꯦꯔꯔꯣꯟ#
# > vijayapura
# = ꯚꯤꯖꯌꯥꯄꯨꯔꯥ
# < ꯚꯤꯖꯥꯃꯥꯔꯔꯥ#
# > sadu
# = ꯁꯗꯨ
# < ꯁꯥꯗꯨ#
# > faridabad
# = ꯐꯔꯤꯗꯥꯕꯥꯗ
# < ꯐꯔꯤꯗꯗꯗ#
# > kek
# = ꯀꯦꯛ
# < ꯀꯦꯛ#
# > tyres
# = ꯇꯥꯌꯔꯁ
# < ꯇꯤꯔꯦ#
# > silchar
# = ꯁꯤꯜꯆꯔ
# < ꯁꯤꯜꯆꯔ#
# > clarita
# = ꯀ꯭ꯂꯦꯔꯤꯇꯥ
# < ꯀꯦꯂꯇ꯭ꯔꯥ#
# > lishang
# = ꯂꯤꯁꯥꯡ
# < ꯂꯤꯁꯪ#
# > placentia
# = ꯄ꯭ꯂꯥꯁꯦꯟꯇꯤꯌꯥ
# < ꯄꯦꯂꯦꯟꯇꯤꯌꯥ#
# > ningonbu
# = ꯅꯤꯉꯣꯟꯕꯨ
# < ꯅꯤꯡꯉꯣꯟꯕ#
# > waa
# = ꯋꯥ
# < ꯋꯥ#
# > corona
# = ꯀꯣꯔꯣꯅꯥ
# < ꯀꯣꯔꯦꯅ#
# > mittranggi
# = ꯃꯤꯠꯇ꯭ꯔꯪꯒꯤ
# < ꯃꯤꯠꯇ꯭ꯔꯤꯡꯁꯤ#
# > telivijan
# = ꯇꯦꯂꯤꯚꯤꯖꯟ
# < ꯇꯦꯂꯤꯌꯕꯅ#
# > asokpa
# = ꯑꯁꯣꯛꯄ
# < ꯑꯁꯣꯛꯄ#
# > bellingham
# = ꯕꯦꯂꯤꯡꯍꯝ
# < ꯕꯦꯜꯂꯤꯡꯍꯝ#
# > koraput
# = ꯀꯣꯔꯥꯄꯨꯠ
# < ꯀꯣꯔꯥꯞꯇꯣ#
# > oricon
# = ꯑꯣꯔꯤꯀꯣꯟ
# < ꯑꯣꯔꯤꯔꯦꯁꯦꯟ#
# > changbabu
# = ꯆꯪꯕꯕꯨ
# < ꯆꯪꯕꯕꯨ#
# > bengaluru
# = ꯕꯦꯡꯒꯂꯨꯔꯨ
# < ꯕꯦꯉꯔꯥꯜꯁꯨ#
# > khullakpani
# = ꯈꯨꯜꯂꯥꯛꯄꯅꯤ
# < ꯈꯨꯜꯂꯛꯄꯅꯤꯅꯅ#
# > nupisingbu
# = ꯅꯨꯄꯤꯁꯤꯡꯕꯨ
# < ꯅꯨꯄꯤꯁꯁꯡꯕꯨ#
# > echu
# = ꯏꯆꯨ
# < ꯏꯆꯨ#
# > surfactants
# = ꯁꯔꯐꯦꯛꯇꯦꯟꯠꯁ
# < ꯁꯨꯔꯆꯥꯇꯁꯛꯁꯁꯁꯁ#
# > saabinaba
# = ꯁꯥꯕꯤꯅꯕ
# < ꯁꯥꯕꯤꯅꯕ#
# > prometheus
# = ꯄ꯭ꯔꯣꯃꯦꯊꯤꯌꯁ
# < ꯄ꯭ꯃꯦꯃꯦꯁꯤꯌ#
# > intarnesanel
# = ꯏꯟꯇꯔꯅꯦꯁꯅꯦꯜ
# < ꯏꯟꯅꯔꯔ#
# > nongthaktagi
# = ꯅꯣꯡꯊꯛꯇꯒꯤ
# < ꯅꯣꯡꯊꯥꯛꯇꯒꯤ#
# > saru
# = ꯁꯔꯨ
# < ꯁꯔꯨ#
# > mahawidya
# = ꯃꯍꯥꯋꯤꯗ꯭ꯌꯥ
# < ꯃꯍꯥꯤꯗꯤꯌꯥ#
# > titansinggidamak
# = ꯇꯥꯢꯇꯟꯁꯤꯡꯒꯤꯗꯃꯛ
# < ꯇꯤꯇꯅꯤꯟꯁꯤꯗꯃꯛ#
# > niphu
# = ꯅꯤꯐꯨ
# < ꯅꯤꯐꯨ#
# > malaysia
# = ꯃꯂꯦꯁꯤꯌꯥ
# < ꯃꯥꯥꯁꯁꯤ#
# > wiley
# = ꯋꯥꯢꯂꯤ
# < ꯂꯤꯂꯂꯌ#
# > nongcheng
# = ꯅꯣꯡꯆꯦꯡ
# < ꯅꯣꯡꯆꯤꯡ#
# > giridih
# = ꯒꯤꯔꯤꯗꯤ
# < ꯖꯤꯔꯤꯚꯤ#
# > huerta
# = ꯍꯨꯑꯦꯔꯇꯥ
# < ꯍꯨꯔꯇ#
# > huber
# = ꯍꯨꯕꯔ
# < ꯍꯨꯔꯦꯔ#
# > delhi
# = ꯗꯦꯜꯂꯤ
# < ꯗꯦꯜꯈꯤ#
# > braunfels
# = ꯕ꯭ꯔꯥꯎꯟꯐꯦꯜꯁ
# < ꯕ꯭ꯔꯥꯞꯅꯦꯁꯁ#
# > epaakachouba
# = ꯏꯄꯥꯛꯑꯆꯧꯕ
# < ꯏꯄꯥꯎꯆꯕ#
# > bharadwaj
# = ꯚꯥꯔꯗꯋꯥꯖ
# < ꯚꯔꯙꯔꯋꯥ#
# > singbulbu
# = ꯁꯤꯡꯕꯨꯜꯕꯨ
# < ꯁꯤꯡꯕꯨꯡꯂꯕ#
# > foureima
# = ꯐꯧꯔꯩꯃ
# < ꯐꯧꯔꯤꯃ#
# > oaks
# = ꯑꯣꯛꯁ
# < ꯑꯣꯛꯁ#
# > parma
# = ꯄꯔꯃ
# < ꯄꯔꯃꯃꯥ#
# > lanngamduna
# = ꯂꯥꯟꯉꯝꯗꯨꯅ
# < ꯂꯥꯟꯒꯝꯝꯗꯨꯅ#
# > kashyap
# = ꯀꯁ꯭ꯌꯞ
# < ꯀꯥꯁꯥꯄ#
# > vatakara
# = ꯕꯥꯇꯀꯥꯔꯥ
# < ꯚꯥꯇꯀꯔꯥꯁ#
# > ali
# = ꯑꯂꯤ
# < ꯑꯂꯤ#
# > cheisu
# = ꯆꯩꯁꯨ
# < ꯆꯩꯁꯨ#
# > aurangabad
# = ꯑꯣꯔꯪꯒꯕꯥꯗ
# < ꯑꯌꯨꯔꯥꯡꯕꯗ#
# > umang
# = ꯎꯃꯪ
# < ꯌꯨꯃꯥꯡ#
# > khaplamlaga
# = ꯈꯞꯂꯝꯂꯒ
# < ꯈꯞꯄꯝꯂꯒ#
# > mcdaniel
# = ꯃꯛꯗꯦꯅꯤꯌꯦꯜ
# < ꯃꯦꯗꯦꯅꯦꯦ#
# > itou
# = ꯏꯇꯧ
# < ꯏꯇꯧ#
# > sayongi
# = ꯁꯥꯌꯣꯟꯒꯤ
# < ꯁꯥꯌꯣꯟꯒꯤ#
# > vishwakarma
# = ꯚꯤꯁ꯭ꯋꯀꯔꯃ
# < ꯚꯤꯁ꯭ꯔꯥꯃꯃꯥ#
# > laiphao
# = ꯂꯥꯢꯐꯥꯎ
# < ꯂꯥꯢꯍꯐꯣ#
# > khambhat
# = ꯈꯝꯚꯥꯠ
# < ꯈꯝꯚꯠ#
# > fertilizers
# = ꯐꯔꯇꯤꯂꯥꯢꯖꯔꯁ
# < ꯐꯦꯔꯤꯇꯦꯁꯂꯁ#
# > saamu
# = ꯁꯥꯃꯨ
# < ꯁꯥꯃꯨ#
# > clifton
# = ꯀ꯭ꯂꯤꯐꯇꯟ
# < ꯀ꯭ꯐꯐꯅꯦ#
# > longsen
# = ꯂꯣꯡꯁꯦꯟ
# < ꯂꯣꯟꯁꯦꯟ#
# > mishak
# = ꯃꯤꯁꯛ
# < ꯃꯤꯁꯛ#
# > sanghvi
# = ꯁꯪꯒꯚꯤ
# < ꯁꯪꯕꯤ#
# > hanson
# = ꯍꯦꯟꯁꯟ
# < ꯍꯟꯟꯟꯟ#
# > tainu
# = ꯇꯥꯢꯅꯨ
# < ꯇꯥꯢꯅꯨ#
# > yelhoumisingbu
# = ꯌꯦꯜꯍꯧꯃꯤꯁꯤꯡꯕꯨ
# < ꯌꯦꯢꯍꯧꯔꯣꯝꯕꯁꯤꯡ#
# > yatra
# = ꯌꯥꯇ꯭ꯔꯥ
# < ꯌꯥꯇꯇꯔꯦ#
# > puraa
# = ꯄꯨꯔꯥ
# < ꯄꯨꯔꯥ#
# > jeffersonville
# = ꯖꯦꯐꯔꯁꯟꯕꯤꯜ
# < ꯖꯦꯖꯦꯔꯦꯕꯦꯅ#
# > tanbada
# = ꯇꯥꯟꯕꯗ
# < ꯇꯥꯟꯕꯗ#
# > piraku
# = ꯄꯤꯔꯛꯎ
# < ꯄꯤꯔꯥꯛ#
# > salangthem
# = ꯁꯂꯥꯡꯊꯦꯝ
# < ꯁꯥꯂꯪꯊꯦꯝ#
# > khak
# = ꯈꯛ
# < ꯈꯥꯛ#
# > nongshaamei
# = ꯅꯣꯡꯁꯥꯃꯩ
# < ꯅꯣꯡꯁꯥꯃꯩ#
# > taphamsang
# = ꯇꯝꯐꯝꯁꯪ
# < ꯇꯐꯝꯁꯤꯡ#
# > nongsamei
# = ꯅꯣꯡꯁꯥꯃꯩ
# < ꯅꯣꯡꯁꯥꯃꯩ#
# > nagalandna
# = ꯅꯒꯥꯂꯦꯟꯅ
# < ꯅꯥꯒꯜꯗꯅ#
# > osmanabad
# = ꯑꯣꯁꯃꯥꯅꯥꯕꯥꯗ
# < ꯑꯣꯁꯥꯃꯗ#
# > ircon
# = ꯏꯔꯀꯣꯟ
# < ꯏꯔꯤꯟꯣꯟ#
# > paambagi
# = ꯄꯥꯝꯕꯒꯤ
# < ꯄꯥꯝꯕꯒꯤ#
# > hackensack
# = ꯍꯦꯛꯀꯟꯁꯦꯛ
# < ꯍꯥꯁꯦꯟꯁ#
# > pradeshki
# = ꯄ꯭ꯔꯥꯗꯦꯁꯀꯤ
# < ꯄ꯭ꯗꯦꯗꯁꯀꯤ#
# > organik
# = ꯑꯣꯔꯒꯥꯅꯤꯛ
# < ꯑꯣꯔꯒꯅꯤꯤ#
# > jagtap
# = ꯖꯒꯇꯞ
# < ꯖꯥꯇꯥ#
# > konsillo
# = ꯀꯣꯟꯁꯤꯜꯂꯣ
# < ꯀꯣꯟꯁꯤꯜꯂꯣ#
# > chakmom
# = ꯆꯛꯃꯣꯝ
# < ꯆꯥꯃꯣꯝ#
# > rajouri
# = ꯔꯥꯖꯣꯔꯤ
# < ꯔꯥꯖꯨꯔꯤ#
# > hendricks
# = ꯍꯦꯟꯗ꯭ꯔꯤꯛꯁ
# < ꯍꯦꯟꯗ꯭ꯔꯛꯁꯁꯤ#
# > madudagi
# = ꯃꯗꯨꯗꯒꯤ
# < ꯃꯗꯥꯒꯤ#
# > calhoun
# = ꯀꯦꯜꯍꯣꯎꯟ
# < ꯀꯜꯂꯣꯟ#
# > shrivas
# = ꯁ꯭ꯔꯤꯕꯥꯁ
# < ꯁ꯭ꯔꯚꯁꯤꯁꯁ#
# > hantharakpadagi
# = ꯍꯟꯊꯔꯛꯄꯗꯒꯤ
# < ꯍꯟꯊꯥꯔꯔꯤꯗꯒ#
# > kaachin
# = ꯀꯥꯆꯤꯟ
# < ꯀꯥꯤꯤꯟ#
# > suzlon
# = ꯁꯨꯖꯂꯣꯟ
# < ꯁꯨꯔꯣꯟ#
# > monte
# = ꯃꯣꯟꯇꯦ
# < ꯃꯦꯟꯇꯦ#
# > placental
# = ꯄ꯭ꯂꯥꯁꯦꯟꯇꯦꯜ
# < ꯄ꯭ꯂꯦꯂꯦꯦꯠ#
# > mechanism
# = ꯃꯦꯀꯥꯅꯤꯖꯝ
# < ꯃꯤꯆꯅꯤꯁꯝꯁꯝ#
# > panari
# = ꯄꯥꯅꯔꯤ
# < ꯄꯅꯔꯥꯤ#
# > naakanlomda
# = ꯅꯥꯀꯟꯂꯣꯝꯗ
# < ꯅꯥꯀꯟꯂꯦꯝ#
# > herbaceous
# = ꯍꯔꯕꯦꯁ꯭ꯌꯁ
# < ꯍꯦꯔꯨꯕꯁꯦ#
# > yenglammi
# = ꯌꯦꯡꯂꯝꯃꯤ
# < ꯌꯦꯡꯂꯝꯃꯤ#
# > indianapolis
# = ꯏꯟꯗꯤꯌꯥꯅꯄꯂꯤꯁ
# < ꯏꯟꯗꯤꯖꯤꯂꯤꯌꯁꯁꯁ#
# > singam
# = ꯁꯤꯡꯒꯝ
# < ꯁꯤꯒꯝ#
# > nungshi
# = ꯅꯨꯡꯁꯤ
# < ꯅꯨꯡꯁꯤ#
# > sinloi
# = ꯁꯤꯟꯂꯣꯢ
# < ꯁꯤꯟꯂꯣꯢ#
# > pearson
# = ꯄꯤꯑꯔꯁꯟ
# < ꯀꯩꯔꯣꯟ#
# > otpi
# = ꯑꯣꯠꯄꯤ
# < ꯑꯣꯠꯇꯤ#
# > koilang
# = ꯀꯣꯢꯂꯥꯡ
# < ꯀꯣꯢꯂꯪ#
# > lembi
# = ꯂꯦꯝꯕꯤ
# < ꯂꯦꯝꯕꯤ#
# > zydus
# = ꯖꯥꯢꯗꯁ
# < ꯖꯤꯗꯁ#
# > esing
# = ꯏꯁꯤꯡ
# < ꯏꯁꯤꯡ#
# > surungni
# = ꯁꯨꯨꯔꯨꯡꯅꯤ
# < ꯁꯨꯔꯨꯡꯅꯤ#
# > atom
# = ꯑꯦꯇꯝ
# < ꯑꯇꯣꯝ#
# > gill
# = ꯒꯤꯜ
# < ꯒꯤꯜ#
# > sharuksing
# = ꯁꯔꯨꯛꯁꯤꯡ
# < ꯁꯔꯨꯛꯀꯣꯁꯤꯡ#
# > rajasthan
# = ꯔꯥꯖꯁꯊꯥꯟ
# < ꯔꯥꯥꯥꯥꯥꯥꯥꯥꯖꯥꯇꯥꯟ#
# > covina
# = ꯀꯣꯚꯤꯅꯥ
# < ꯀꯤꯕꯤꯅ#
# > alipore
# = ꯑꯂꯤꯄꯣꯔ
# < ꯑꯦꯄꯦꯔꯦꯔ#
# > mckenzie
# = ꯃꯀꯦꯟꯖꯤ
# < ꯃ꯭ꯀꯦꯆꯦꯟꯁ#
# > panesar
# = ꯄꯅꯦꯁꯔ
# < ꯄꯅꯦꯁꯔ#
# > taaklamba
# = ꯇꯥꯛꯂꯝꯕ
# < ꯇꯥꯛꯂꯝꯕ#
# > leijadaba
# = ꯂꯩꯖꯗꯕ
# < ꯂꯩꯖꯗꯕ#
# > textiles
# = ꯇꯦꯛꯁꯇꯥꯢꯜꯁ
# < ꯇꯦꯛꯇ꯭ꯤꯌꯦꯁꯅꯦ#
# > phamdengba
# = ꯐꯝꯗꯦꯡꯕ
# < ꯐꯝꯗꯦꯡꯕ#
# > mahiga
# = ꯃꯍꯤꯒ
# < ꯃꯍꯤꯒ#
# > apisaa
# = ꯑꯄꯤꯁꯥ
# < ꯑꯄꯤꯁꯥꯁ#
# > meditarreniyan
# = ꯃꯦꯗꯤꯇꯔꯔꯦꯅꯤꯌꯟ
# < ꯃꯤꯗꯤꯇꯇꯔꯤꯌꯥꯌꯟ#
# > faba
# = ꯐꯥꯕ
# < ꯐꯥꯕ#
# > logistics
# = ꯂꯣꯖꯤꯁꯇꯤꯛꯁ
# < ꯂꯣꯒꯤꯁꯤꯁꯁꯤ#
# > langbi
# = ꯂꯥꯡꯕꯤ
# < ꯂꯥꯡꯕꯤ#
# > spirits
# = ꯁ꯭ꯄꯤꯔꯤꯠꯁ
# < ꯁ꯭ꯔꯤꯄꯁꯁꯤ#
# > fahoubagi
# = ꯐꯥꯍꯧꯕꯒꯤ
# < ꯐꯥꯍꯧꯕꯒꯤ#
# > atkinson
# = ꯑꯦꯠꯀꯤꯟꯁꯟ
# < ꯑꯇꯣꯛꯁꯤꯟꯁꯅꯟ#
# > industries
# = ꯏꯟꯗꯁꯇ꯭ꯔꯤꯁ
# < ꯏꯟꯈ꯭ꯔꯦꯁꯤꯁ#
# > israni
# = ꯏꯁ꯭ꯔꯥꯅꯤ
# < ꯏꯁꯥꯅꯤ#
# > natureview
# = ꯅꯦꯆꯔꯚꯤꯎ
# < ꯅꯇ꯭ꯔꯤꯖꯚ#
# > senjeng
# = ꯁꯦꯟꯖꯦꯡ
# < ꯁꯦꯟꯖꯪ#
# > chatpagi
# = ꯆꯠꯄꯒꯤ
# < ꯆꯠꯄꯒꯤ#
# > jaunpur
# = ꯖꯣꯟꯄꯨꯔ
# < ꯌꯨꯞꯄꯔ#
# > taramna
# = ꯇꯔꯥꯝꯅ
# < ꯇꯔꯝꯅ#
# > chalei
# = ꯆꯂꯩ
# < ꯆꯥꯂꯩ#
# > ibirammi
# = ꯏꯕꯤꯔꯝꯃꯤ
# < ꯏꯕꯤꯃꯝꯤ#
# > haapchillaga
# = ꯍꯥꯞꯆꯤꯜꯂꯒ
# < ꯍꯥꯞꯆꯤꯡꯂꯒ#
# > grover
# = ꯒ꯭ꯔꯣꯚꯔ
# < ꯔ꯭ꯔꯦꯔꯒꯦ#
# > utthokpa
# = ꯎꯠꯊꯣꯛꯄ
# < ꯎꯠꯊꯣꯛꯄꯛ#
# > konnabadagi
# = ꯀꯣꯟꯅꯕꯗꯒꯤ
# < ꯀꯣꯟꯅꯕꯒꯤ#
# > riverside
# = ꯔꯤꯚꯔꯁꯥꯢꯗ
# < ꯔꯤꯔꯦꯚꯗꯦꯁ#
# > tinley
# = ꯇꯤꯟꯂꯤ
# < ꯇꯤꯟꯂꯦ#
# > meeyaamna
# = ꯃꯤꯌꯥꯝꯅ
# < ꯃꯤꯌꯥꯝ#
# > algeriagi
# = ꯑꯜꯖꯦꯔꯤꯌꯥꯒꯤ
# < ꯑꯦꯒ꯭ꯔꯦꯒꯤ#
# > park
# = ꯄꯥꯔꯛ
# < ꯄꯔꯛ#
# > vatakara
# = ꯚꯥꯇꯀꯥꯔꯥ
# < ꯇꯥꯇꯥꯛꯀꯔ#
# > khulda
# = ꯈꯨꯜꯗ
# < ꯈꯨꯜꯗ#
# > shamjetsabam
# = ꯁꯝꯖꯦꯠꯁꯥꯕꯝ
# < ꯁꯝꯖꯖꯦꯚꯕꯥꯝ#
# > jodha
# = ꯖꯣꯔꯍꯥ
# < ꯖꯣꯙꯥꯥ#
# > monsang
# = ꯃꯣꯟꯁꯥꯡ
# < ꯃꯣꯟꯁꯪ#
# > thana
# = ꯊꯥꯅꯥ
# < ꯊꯥꯅ#
# > macau
# = ꯃꯀꯥꯎ
# < ꯃꯄꯥ#
# > baliga
# = ꯕꯂꯤꯒꯥ
# < ꯕꯥꯤꯗꯑ#
# > latamni
# = ꯂꯥꯇꯝꯅꯤ
# < ꯂꯥꯇꯝꯅꯤ#
# > nakanlomda
# = ꯅꯥꯀꯟꯂꯣꯝꯗ
# < ꯅꯥꯀꯥꯂꯣꯟꯗ#
# > khetnei
# = ꯈꯦꯠꯅꯩ
# < ꯈꯦꯠꯅꯩ#
# > willis
# = ꯋꯤꯂꯤꯁ
# < ꯂꯤꯜꯂꯤꯁ#
# > nielsen
# = ꯅꯤꯌꯦꯜꯁꯟ
# < ꯅꯤꯜꯁꯦꯟ#
# > sipaigi
# = ꯁꯤꯄꯥꯢꯒꯤ
# < ꯁꯤꯄꯥꯢꯒꯤ#
# > englandgi
# = ꯏꯪꯂꯦꯟꯒꯤ
# < ꯏꯪꯂꯪꯒꯤ#
# > chingngu
# = ꯆꯤꯡꯉꯨ
# < ꯆꯤꯡꯅꯨ#
# > pheesa
# = ꯐꯤꯁꯥ
# < ꯐꯩꯁꯥ#
# > paso
# = ꯄꯥꯁꯣ
# < ꯁꯥꯌꯣꯣ#
# > tatenen
# = ꯇꯇꯦꯅꯦꯟ
# < ꯇꯦꯅꯦꯟ#
# > kasera
# = ꯀꯥꯁꯦꯔꯥ
# < ꯀꯁꯦꯔꯥ#
# > chinminnasite
# = ꯆꯤꯟꯃꯤꯟꯅꯁꯤꯇꯦ
# < ꯆꯤꯟꯃꯤꯟꯇꯤꯁꯦ#
# > pheichom
# = ꯐꯩꯆꯣꯝ
# < ꯐꯩꯈꯨꯝ#
# > shrirampur
# = ꯁ꯭ꯔꯤꯔꯥꯝꯄꯨꯔ
# < ꯁꯔꯔꯤꯌꯥꯄ#
# > piksinkhi
# = ꯄꯤꯛꯁꯤꯟꯈꯤ
# < ꯄꯤꯈꯤꯈꯤ#
# > kungsinba
# = ꯀꯨꯡꯁꯤꯟꯕ
# < ꯀꯨꯡꯁꯤꯟꯕ#
# > oibi
# = ꯑꯣꯢꯕꯤ
# < ꯑꯣꯢꯕꯤ#
# > leipakpu
# = ꯂꯩꯄꯥꯛꯄꯨ
# < ꯂꯩꯄꯥꯛꯄꯨ#
# > lairik
# = ꯂꯥꯢꯔꯤꯛ
# < ꯂꯥꯢꯔꯤꯛ#
# > haoreima
# = ꯍꯥꯎꯔꯩꯃ
# < ꯍꯥꯎꯔꯩ#
# > kayana
# = ꯀꯌꯥꯅ
# < ꯀꯌꯥꯅ#
# > vasuki
# = ꯚꯥꯁꯨꯀꯤ
# < ꯁꯁꯤꯀꯤ#
# > imaalonbu
# = ꯏꯃꯥꯂꯣꯟꯕꯨ
# < ꯏꯃꯥꯂꯣꯟꯕ#
# > samdharshni
# = ꯁꯝꯙꯔꯁꯅꯤ
# < ꯁꯝꯗ꯭ꯔꯤꯅꯤ#
# > mayekki
# = ꯃꯌꯦꯛꯀꯤ
# < ꯃꯌꯦꯛꯀꯤ#
# > laanlou
# = ꯂꯥꯟꯂꯧ
# < ꯂꯥꯟꯂꯨ#
# > leandro
# = ꯂꯤꯟꯗ꯭ꯔꯣ
# < ꯂꯦꯟꯗꯣꯔꯣ#
# > khaada
# = ꯈꯥꯗ
# < ꯈꯥꯗ#
# > ifci
# = ꯑꯥꯢꯑꯦꯐꯁꯤꯑꯥꯢ
# < ꯏꯐꯤ#
# > sheboygan
# = ꯁꯤꯕꯣꯢꯒꯟ
# < ꯁꯦꯕꯣꯔꯟ#
# > maphamsu
# = ꯃꯐꯝꯁꯨ
# < ꯃꯐꯥꯁꯨ#
# > noble
# = ꯅꯣꯕꯜ
# < ꯅꯣꯕꯦ#
# > athouba
# = ꯑꯊꯧꯕ
# < ꯑꯊꯧꯕ#
# > sitaram
# = ꯁꯤꯇꯥꯔꯥꯝ
# < ꯁꯤꯇꯔꯥꯃ#
# > narwar
# = ꯅꯥꯋꯥꯔ
# < ꯅꯔꯔ#
# > intelligence
# = ꯏꯟꯇꯦꯂꯤꯖꯦꯟꯁ
# < ꯏꯟꯇꯦꯜꯇꯇꯦꯇꯤ#
# > laannaduna
# = ꯂꯥꯟꯅꯗꯨꯅ
# < ꯂꯥꯟꯅꯗꯨꯅ#
# > perth
# = ꯄꯔꯊ
# < ꯄꯦꯔꯦꯠ#
# > nongchuptana
# = ꯅꯣꯡꯆꯨꯞꯇꯅ
# < ꯅꯣꯡꯆꯨꯇꯥꯅ#
# > sara
# = ꯁꯔꯥ
# < ꯁꯔꯥ#
# > leiribani
# = ꯂꯩꯔꯤꯕꯅꯤ
# < ꯂꯩꯔꯤꯕꯅꯤ#
# > saharsa
# = ꯁꯍꯔꯁꯥ
# < ꯁꯍꯔꯁ#
# > jhindal
# = ꯓꯤꯟꯗꯥꯜ
# < ꯖꯤꯟꯗ#
# > palmer
# = ꯄꯥꯜꯃꯔ
# < ꯄꯥꯜꯃꯦꯔ#
# > madgaon
# = ꯃꯗꯒꯥꯎ
# < ꯃꯗꯗꯥꯟꯟ#
# > finserv
# = ꯐꯤꯟꯁꯔꯚ
# < ꯐꯤꯟꯁ꯭ꯔꯦ#
# > nambol
# = ꯅꯝꯕꯣꯜ
# < ꯅꯝꯕꯣꯜ#
# > lainingthou
# = ꯂꯥꯢꯅꯤꯡꯊꯧ
# < ꯂꯥꯢꯅꯤꯡꯐꯨ#
# > awangbagi
# = ꯑꯋꯥꯡꯕꯒꯤ
# < ꯑꯋꯥꯡꯕꯒꯤ#
# > allsec
# = ꯑꯣꯜꯁꯦꯛ
# < ꯑꯜꯜꯁꯦꯁ#
# > stop
# = ꯁ꯭ꯇꯣꯞ
# < ꯁ꯭ꯇꯣꯞ#
# > mckay
# = ꯃꯛꯀꯦ
# < ꯃꯀꯀꯥꯌ#
# > machaki
# = ꯃꯆꯥꯀꯤ
# < ꯃꯆꯥꯀꯤ#
# > sanareina
# = ꯁꯅꯥꯔꯩꯅ
# < ꯁꯅꯔꯥꯅꯥ#
# > dhaka
# = ꯙꯥꯀꯥ
# < ꯙꯀꯀꯥ#
# > baleshwar
# = ꯕꯥꯂꯦꯁ꯭ꯋꯔ
# < ꯕꯦꯂꯚꯋꯔ#
# > shangleichaa
# = ꯁꯪꯂꯩꯆꯥ
# < ꯁꯪꯂꯩꯆꯆ#
# > square
# = ꯁ꯭ꯀꯨꯋꯥꯔ
# < ꯁ꯭ꯔꯦ#
# > panthoibini
# = ꯄꯥꯟꯊꯣꯢꯕꯤꯅꯤ
# < ꯄꯥꯟꯊꯣꯢꯕꯅꯤ#
# > blair
# = ꯕ꯭ꯂꯦꯔ
# < ꯕ꯭ꯂꯥꯔꯔꯔ#
# > kolar
# = ꯀꯣꯂꯥꯔ
# < ꯀꯣꯂꯔꯤ#
# > nekhbet
# = ꯅꯦꯈꯕꯦꯠ
# < ꯅꯦꯈꯦꯠ#
# > castro
# = ꯀꯦꯁꯇ꯭ꯔꯣ
# < ꯀꯥꯁꯇꯔ#
# > lunghar
# = ꯂꯨꯡꯍꯥꯔ
# < ꯂꯨꯡꯍꯔ#
# > subex
# = ꯁꯨꯕꯦꯛꯁ
# < ꯁꯨꯖꯦꯛ#
# > ross
# = ꯔꯣꯁ
# < ꯔꯣꯁꯁ#
# > mayaamga
# = ꯃꯌꯥꯝꯒ
# < ꯃꯌꯥꯝꯒ#
# > saunders
# = ꯁꯣꯟꯗꯔꯁ
# < ꯁꯥꯟꯗꯦꯁꯁꯁ#
# > gati
# = ꯒꯇꯤ
# < ꯒꯥꯇꯤꯇꯤ#
# > changlakkhi
# = ꯆꯪꯂꯛꯈꯤ
# < ꯆꯪꯂꯈꯈꯤ#
# > electricity
# = ꯏꯂꯦꯛꯇ꯭ꯔꯤꯁꯤꯇꯤ
# < ꯏꯦꯦꯁꯤꯔꯤ#
# > niraj
# = ꯅꯤꯔꯖ
# < ꯅꯤꯔꯨ#
# > leisupi
# = ꯂꯩꯁꯨꯄꯤ
# < ꯂꯩꯁꯞꯄꯤ#
# > balmer
# = ꯕꯥꯜꯃꯔ
# < ꯕꯥꯦꯔꯦꯅꯔ#
# > shashan
# = ꯁꯥꯁꯟ
# < ꯁꯁꯟ#
# > atlantic
# = ꯑꯠꯂꯥꯟꯇꯤꯛ
# < ꯑꯠꯠꯇꯛꯇꯤꯟꯇꯛ#
# > woodbury
# = ꯋꯨꯗꯕꯔꯤ
# < ꯋꯣꯑꯣꯗꯔꯤꯌꯥ#
# > bellflower
# = ꯕꯦꯜꯐ꯭ꯂꯥꯎꯋꯔ
# < ꯕꯦꯜꯂꯦꯛꯔꯤ#
# > ningsing
# = ꯅꯤꯡꯁꯤꯡ
# < ꯅꯤꯡꯁꯤꯡ#
# > paringni
# = ꯄꯔꯤꯡꯅꯤ
# < ꯄꯔꯤꯒꯅꯤ#
# > haraobanachingbada
# = ꯍꯔꯥꯎꯕꯅꯆꯤꯡꯕꯗ
# < ꯍꯥꯔꯔꯣꯄꯆꯥꯜꯕꯟꯗꯕꯗꯡ#
# > phaaraba
# = ꯐꯥꯔꯕ
# < ꯐꯥꯔꯕ#
# > saluja
# = ꯁꯂꯨꯖꯥ
# < ꯁꯥꯨꯔ#
# > porompatni
# = ꯄꯣꯔꯣꯝꯄꯥꯠꯅꯤ
# < ꯄꯣꯔꯣꯝꯝꯇꯤꯅꯤ#
# > paakee
# = ꯄꯥꯛꯏ
# < ꯄꯥꯎ#
# > kangbu
# = ꯀꯥꯡꯕꯨ
# < ꯀꯪꯕꯨ#
# > kumpaapada
# = ꯀꯨꯝꯄꯥꯄꯗ
# < ꯀꯨꯝꯄꯥꯞꯄꯗ#
# > mountain
# = ꯃꯥꯎꯟꯇꯦꯟ
# < ꯃꯧꯟꯅꯥꯐꯤ#
# > colorado
# = ꯀꯣꯂꯣꯔꯥꯗꯣ
# < ꯀꯣꯑꯣꯔꯣꯔꯣ#
# > loupham
# = ꯂꯧꯐꯝ
# < ꯂꯧꯐꯝ#
# > coconut
# = ꯀꯣꯀꯣꯅꯠ
# < ꯀꯀꯣꯣꯟꯠꯁ#
# > gentry
# = ꯒꯦꯟꯇ꯭ꯔꯤ
# < ꯖꯦꯟꯇꯇ꯭ꯔꯤꯌꯥ#
# > avondale
# = ꯑꯥꯕꯣꯟꯗꯦꯜ
# < ꯑꯣꯗꯥꯦꯂꯦ#
# > enka
# = ꯏꯟꯀꯥ
# < ꯏꯀꯀꯀ#
# > kun
# = ꯀꯨꯟ
# < ꯀꯨꯟ#
# > khongthang
# = ꯈꯣꯡꯊꯥꯡ
# < ꯈꯣꯡꯊꯪ#
# > chakkouba
# = ꯆꯥꯛꯀꯧꯕ
# < ꯆꯥꯛꯀꯧꯕ#
# > paanggansinggi
# = ꯄꯥꯡꯒꯟꯁꯤꯡꯒꯤ
# < ꯄꯥꯡꯒꯥꯟꯁꯤꯡꯒꯤ#
# > siddiqui
# = ꯁꯤꯗꯤꯀꯤ
# < ꯁꯤꯗꯤꯗꯨ#
# > finserv
# = ꯐꯤꯟꯁꯔꯕ
# < ꯐꯤꯟꯁ꯭ꯔꯦ#
# > uppal
# = ꯎꯞꯄꯜ
# < ꯎꯄꯥꯄ#
# > khuntaalakkhi
# = ꯈꯨꯟꯇꯥꯂꯛꯈꯤ
# < ꯈꯨꯟꯇꯥꯛꯈꯈꯤ#
# > surprise
# = ꯁꯔꯄ꯭ꯔꯥꯢꯁ
# < ꯁꯨꯔꯤꯁꯤꯁꯦ#
# > varun
# = ꯚꯔꯨꯟ
# < ꯚꯔꯨꯟꯅ#
# > goutam
# = ꯒꯧꯇꯝ
# < ꯒꯣꯇꯝ#
# > senbagi
# = ꯁꯦꯟꯕꯒꯤ
# < ꯁꯦꯟꯕꯒꯤ#
# > tangkhaida
# = ꯇꯪꯈꯥꯢꯗ
# < ꯇꯥꯈꯪꯈ#
# > taiba
# = ꯇꯥꯢꯕ
# < ꯇꯥꯢꯕ#
# > chitradurga
# = ꯆꯤꯠꯇ꯭ꯔꯗꯨꯔꯒꯥ
# < ꯆꯤꯇ꯭ꯔꯨꯗꯒ#
# > laanda
# = ꯂꯥꯟꯗ
# < ꯂꯥꯟꯗ#
# > palatine
# = ꯄꯦꯂꯦꯇꯥꯢꯟ
# < ꯄꯥꯂꯦꯅꯦ#
# > pasupuleti
# = ꯄꯁꯨꯄꯨꯂꯦꯇꯤ
# < ꯄꯥꯁꯨꯞꯇꯤ#
# > nbcc
# = ꯑꯦꯟꯕꯤꯁꯤꯁꯤ
# < ꯅꯦꯁ꯭#
# > teleservices
# = ꯇꯦꯂꯦꯁꯔꯚꯤꯁꯁ
# < ꯇꯦꯂꯦꯦꯇꯁꯦꯔ#
# > jeykumaran
# = ꯖꯦꯀꯨꯃꯥꯔꯟ
# < ꯖꯦꯌꯨꯝꯨꯔꯥꯟ#
# > awaangda
# = ꯑꯋꯥꯡꯗ
# < ꯑꯋꯥꯡꯗ#
# > bend
# = ꯕꯦꯟꯗ
# < ꯕꯦꯟꯗ#
# > holloway
# = ꯍꯣꯂꯣꯋꯦ
# < ꯍꯣꯜꯂꯧꯇꯤ#
# > fineotex
# = ꯐꯥꯢꯟꯑꯣꯇꯦꯛꯁ
# < ꯐꯤꯅꯦꯛꯇ#
# > kupthana
# = ꯀꯨꯞꯊꯅ
# < ꯀꯨꯞꯊꯅ#
# > tide
# = ꯇꯥꯢꯗ
# < ꯇꯤꯗꯦ#
# > dillon
# = ꯗꯤꯜꯂꯣꯟ
# < ꯗꯤꯜꯂꯣꯟ#
# > afreen
# = ꯑꯐ꯭ꯔꯤꯟ
# < ꯑꯐꯦꯟꯟ#
# > phisa
# = ꯐꯤꯁꯥ
# < ꯐꯤꯁꯥ#
# > patiala
# = ꯄꯇꯤꯑꯥꯂꯥ
# < ꯄꯇꯤꯂꯥ#
# > aviation
# = ꯑꯦꯚꯤꯑꯦꯁꯟ
# < ꯑꯚꯤꯚꯇꯤꯌꯦꯟ#
# > bismarck
# = ꯕꯤꯁꯃꯥꯔꯛ
# < ꯕꯤꯃꯃꯛ#
# > rosario
# = ꯔꯣꯖꯥꯔꯤꯑꯣ
# < ꯔꯣꯁꯔꯥꯑ#
# > khunnung
# = ꯈꯨꯟꯅꯨꯡ
# < ꯈꯨꯟꯅꯁꯨ#
# > tenawa
# = ꯇꯦꯅꯋꯥ
# < ꯇꯦꯅꯥ#
# > ingkhonda
# = ꯏꯪꯈꯣꯟꯗ
# < ꯏꯈꯣꯡꯈꯟꯗ#
# > ema
# = ꯏꯃꯥ
# < ꯏꯃꯥ#
# > yoknaba
# = ꯌꯣꯛꯅꯕ
# < ꯌꯣꯛꯅꯕ#
# > fairfield
# = ꯐꯦꯔꯐꯤꯜꯗ
# < ꯐꯥꯢꯔꯤꯐꯦꯦꯟ#
# > maynard
# = ꯃꯦꯅꯥꯔꯗ
# < ꯃꯥꯅꯔꯦ#
# > lowell
# = ꯂꯣꯋꯦꯜ
# < ꯂꯣꯔꯦꯜ#
# > laguna
# = ꯂꯒꯨꯅꯥ
# < ꯂꯥꯎꯅ#
# > puraki
# = ꯄꯨꯔꯛꯏ
# < ꯄꯨꯔꯛꯏ#
# > phouoibi
# = ꯐꯧꯑꯣꯢꯕꯤ
# < ꯐꯧꯑꯣꯕꯕꯤ#
# > awaatapaa
# = ꯑꯋꯥꯠꯑꯄꯥ
# < ꯑꯋꯥꯥꯄꯥ#
# > chaipanita
# = ꯆꯥꯢꯄꯅꯤꯇ
# < ꯆꯥꯢꯄꯥꯇꯃꯤꯇ#
# > toubsingnasu
# = ꯇꯧꯕꯁꯤꯡꯅꯁꯨ
# < ꯇꯧꯕꯤꯁꯤꯡꯁꯨ#
# > ngaobadouna
# = ꯉꯥꯎꯕꯗꯧꯅ
# < ꯉꯥꯎꯕꯗꯗꯨꯅ#
# > murshidabad
# = ꯃꯨꯔꯁꯤꯗꯕꯥꯗ
# < ꯃꯨꯔꯤꯁꯗꯕꯗ#
# > dominguez
# = ꯗꯣꯃꯤꯟꯒꯦꯖ
# < ꯗꯣꯃꯤꯌꯦꯁꯥ#
# > pugh
# = ꯄꯤꯎ
# < ꯄꯨꯒꯓ#
# > koktong
# = ꯀꯣꯛꯇꯣꯡ
# < ꯀꯣꯛꯇꯣꯡ#
# > khangda
# = ꯈꯥꯡꯗ
# < ꯈꯪꯗ#
# > charamde
# = ꯆꯥꯔꯝꯗꯦ
# < ꯆꯔꯃꯦꯗ#
# > samjetshabam
# = ꯁꯝꯖꯦꯠꯁꯥꯕꯝ
# < ꯁꯝꯐꯚꯦꯕ#
# > heihei
# = ꯍꯩꯍꯩ
# < ꯍꯩꯍꯩ#
# > langjaa
# = ꯂꯪꯖꯥ
# < ꯂꯪꯖꯥ#
# > thabaksing
# = ꯊꯕꯛꯁꯤꯡ
# < ꯊꯥꯕꯛꯁꯤꯡ#
# > foseco
# = ꯐꯣꯁꯀꯣ
# < ꯐꯣꯁꯀꯣ#
# > madhya
# = ꯃꯙ꯭ꯌ
# < ꯃꯈꯣ#
# > khngle
# = ꯈꯪꯂꯦ
# < ꯈ꯭ꯡꯂꯦ#
# > maanna
# = ꯃꯥꯟꯅ
# < ꯃꯥꯟꯅ#
# > yong
# = ꯌꯣꯡ
# < ꯌꯣꯡ#
# > sangareddi
# = ꯁꯪꯒꯥꯔꯦꯗꯗꯤ
# < ꯁꯥꯒꯔꯔꯦꯗꯤ#
# > chaada
# = ꯆꯥꯗ
# < ꯆꯥꯗ#
# > tamlaba
# = ꯇꯝꯂꯕ
# < ꯇꯝꯂꯕ#
# > pebet
# = ꯄꯦꯕꯦꯠ
# < ꯄꯦꯕꯦꯠ#
# > colton
# = ꯀꯣꯜꯇꯟ
# < ꯀꯣꯢꯇꯣꯟ#
# > khubak
# = ꯈꯨꯕꯥꯛ
# < ꯈꯨꯕꯛ#
# > awasthi
# = ꯑꯋꯁꯊꯤ
# < ꯑꯋꯥꯁꯤꯇꯤ#
# > nadaf
# = ꯅꯗꯐ
# < ꯅꯗꯥ#
# > tamjakhibadugi
# = ꯇꯝꯖꯈꯤꯕꯗꯨꯒꯤ
# < ꯇꯝꯖꯈꯤꯕꯗꯒꯒꯤ#
# ...
# = ꯀꯦꯔꯔꯣꯜ
# < ꯀꯔꯔꯣꯔꯣꯜ#
# > humphutaraataret
# = ꯍꯨꯝꯐꯨꯇꯔꯥꯇꯔꯦꯠ
# < ꯍꯨꯝꯐꯨꯇꯔꯥꯔꯦꯇ#
# > budaun
# = ꯕꯗꯥꯌꯨ
# < ꯕꯨꯗꯗꯟ#
# > atupu
# = ꯑꯇꯨꯄꯨ
# < ꯑꯇꯨꯄꯨ#
# > mamingsingdudi
# = ꯃꯃꯤꯡꯁꯤꯡꯗꯨꯗꯤ
# < ꯃꯃꯤꯡꯁꯤꯡꯗꯤ#
# > wagh
# = ꯋꯥꯘ
# < ꯋꯥꯍ#
# > bhawani
# = ꯚꯋꯥꯅꯤ
# < ꯚꯋꯥꯅꯅꯤ#
# > lusiyaa
# = ꯂꯨꯁꯤꯌꯥ
# < ꯂꯨꯌꯤꯌꯥ#
# > powers
# = ꯄꯥꯎꯋꯔꯁ
# < ꯄꯣꯔꯦꯔꯁ#
# > thougatpa
# = ꯊꯧꯒꯠꯄ
# < ꯊꯧꯒꯥꯞ#
# > lonnachingba
# = ꯂꯣꯟꯅꯆꯤꯡꯕ
# < ꯂꯣꯟꯅꯆꯤꯡꯕ#
# > smart
# = ꯁ꯭ꯃꯥꯔꯇ
# < ꯁ꯭ꯔꯥꯇ#
# > palladium
# = ꯄꯜꯂꯥꯗꯤꯌꯝ
# < ꯄꯜꯂꯝꯗꯝ#
# > maplewood
# = ꯃꯦꯄꯜꯋꯨꯗ
# < ꯃꯦꯂꯦꯗꯣ#
# > yavatmal
# = ꯌꯚꯠꯃꯥꯜ
# < ꯌꯥꯕꯠꯇꯣꯜ#
# > ahmadnagar
# = ꯑꯍꯃꯗꯅꯒꯔ
# < ꯑꯍꯤꯅꯗꯔꯒꯔ#
# > hills
# = ꯍꯤꯜꯁ
# < ꯍꯤꯜꯁ#
# > angoubi
# = ꯑꯉꯧꯕꯤ
# < ꯑꯉꯧꯕꯤ#
# > louthoklaga
# = ꯂꯧꯊꯣꯛꯂꯒ
# < ꯂꯧꯊꯣꯛꯂꯒ#
# > balram
# = ꯕꯂꯔꯥꯝ
# < ꯕꯥꯝꯔꯝ#
# > yengbada
# = ꯌꯦꯡꯕꯗ
# < ꯌꯦꯡꯕꯗ#
# > kottayam
# = ꯀꯣꯇꯥꯌꯝ
# < ꯀꯣꯠꯇꯥꯃꯝ#
# > bennett
# = ꯕꯦꯟꯅꯦꯠ
# < ꯕꯦꯟꯇꯦꯠ#
# > wanghouba
# = ꯋꯥꯡꯍꯧꯕ
# < ꯋꯥꯡꯕꯧꯕ#
# > sawyer
# = ꯁꯣꯌꯔ
# < ꯁꯋꯦꯔꯔ#
# > assembly
# = ꯑꯦꯁꯦꯝꯕ꯭ꯂꯤ
# < ꯑꯁꯦꯦꯂꯝꯌꯤ#
# > jalor
# = ꯖꯥꯂꯣꯔ
# < ꯖꯂꯣꯔꯔ#
# > yanam
# = ꯌꯥꯅꯝ
# < ꯌꯥꯅꯝ#
# > he
# = ꯍꯦ
# < ꯍꯥ#
# > akolkar
# = ꯑꯀꯣꯜꯀꯥꯔ
# < ꯑꯀꯣꯛꯀꯔ#
# > piklingeidagi
# = ꯄꯤꯛꯂꯤꯉꯩꯗꯒꯤ
# < ꯄꯤꯛꯂꯤꯉꯒꯤ#
# > potter
# = ꯄꯣꯠꯇꯔ
# < ꯄꯣꯠꯇꯔ#
# > sintha
# = ꯁꯤꯟꯊꯥ
# < ꯁꯤꯟꯊꯥ#
# > jebina
# = ꯖꯦꯕꯤꯅ
# < ꯖꯦꯕꯤꯅ#
# > control
# = ꯀꯟꯇ꯭ꯔꯣꯜ
# < ꯀꯣꯟꯇꯣꯔꯣꯜ#
# > sugar
# = ꯁꯨꯒꯔ
# < ꯁꯨꯒꯔꯔ#
# > lingkhatli
# = ꯂꯤꯡꯈꯠꯂꯤ
# < ꯂꯤꯡꯈꯠꯂꯤ#
# > equipment
# = ꯏꯀꯨꯢꯞꯃꯦꯟꯠ
# < ꯏꯔꯧꯄꯃꯝꯇꯟ#
# > twin
# = ꯇ꯭ꯋꯤꯟ
# < ꯇꯤꯌꯤꯟ#
# > taanbada
# = ꯇꯥꯟꯕꯗ
# < ꯇꯥꯟꯗꯗ#
# > nongchenpam
# = ꯅꯣꯡꯆꯦꯟꯄꯝ
# < ꯅꯣꯡꯆꯦꯟꯐꯝ#
# > meza
# = ꯃꯦꯖꯥ
# < ꯃꯦꯓ#
# > pakthokpa
# = ꯄꯥꯛꯊꯣꯛꯄ
# < ꯄꯥꯛꯊꯣꯛꯄ#
# > machani
# = ꯃꯆꯥꯅꯤ
# < ꯃꯆꯥꯅꯤ#
# > charangpat
# = ꯆꯔꯥꯡꯄꯥꯠ
# < ꯆꯥꯔꯥꯇꯠ#
# > nahasing
# = ꯅꯍꯥꯁꯤꯡ
# < ꯅꯥꯍꯥꯁꯤꯡ#
# > houjiksu
# = ꯍꯧꯖꯤꯛꯁꯨ
# < ꯍꯧꯖꯤꯛꯁꯨ#
# > shoreline
# = ꯁꯣꯔꯂꯥꯢꯟ
# < ꯁꯣꯔꯦꯂꯦꯟ#
# > anganba
# = ꯑꯉꯟꯕ
# < ꯑꯉꯥꯟꯕ#
# > ningthem
# = ꯅꯤꯡꯊꯦꯝ
# < ꯅꯤꯡꯊꯦꯝ#
# > rhodes
# = ꯔꯣꯗꯁ
# < ꯔꯣꯗꯁꯁ#
# > feijom
# = ꯐꯩꯖꯣꯝ
# < ꯐꯩꯖꯣꯝ#
# > behuria
# = ꯕꯦꯍꯨꯔꯤꯑꯥ
# < ꯕꯦꯍ꯭ꯔꯤꯌꯥ#
# > kar
# = ꯀꯥꯔ
# < ꯀꯔ#
# > ithel
# = ꯏꯊꯦꯜ
# < ꯏꯊꯦꯜ#
# > bernardino
# = ꯕꯔꯅꯥꯔꯗꯤꯅꯣ
# < ꯕꯦꯔꯥꯔꯗꯅꯅ#
# > square
# = ꯁ꯭ꯀꯋꯥꯔ
# < ꯁꯤꯋꯔꯦ#
# > movers
# = ꯃꯨꯚꯔꯁ
# < ꯃꯣꯚꯦꯔ#
# > varun
# = ꯕꯔꯨꯟ
# < ꯚꯥꯔꯨꯟ#
# > lairen
# = ꯂꯥꯢꯔꯦꯟ
# < ꯂꯥꯢꯔꯦꯟ#
# > madden
# = ꯃꯦꯗꯗꯟ
# < ꯃꯥꯗꯦꯟ#
# > laifao
# = ꯂꯥꯢꯐꯥꯎ
# < ꯂꯥꯢꯐꯐꯥ#
# > matsya
# = ꯃꯠꯁ꯭ꯌ
# < ꯃꯇꯤꯌꯥ#
# > pandabha
# = ꯄꯥꯟꯗꯚ
# < ꯄꯥꯟꯥꯕ#
# > bulandshahr
# = ꯕꯨꯂꯟꯗꯁꯥꯔ
# < ꯕꯨꯂꯥꯟꯟꯗꯔꯦ#
# > waithungminnakhi
# = ꯋꯥꯢꯊꯨꯡꯃꯤꯟꯅꯈꯤ
# < ꯋꯥꯢꯊꯪꯈꯤꯤꯅꯤ#
# > phangde
# = ꯐꯪꯗꯦ
# < ꯐꯥꯡꯗꯦ#
# > charlottesville
# = ꯆꯥꯔꯂꯣꯠꯁꯕꯤꯜ
# < ꯆꯔꯔꯦꯇꯦ#
# > eros
# = ꯏꯔꯣꯁ
# < ꯏꯔꯣꯛꯁ#
# > brentwood
# = ꯕ꯭ꯔꯦꯟꯠꯋꯨꯗ
# < ꯕ꯭ꯔꯦꯠꯇꯣꯗ#
# > fontana
# = ꯐꯣꯟꯇꯥꯅꯥ
# < ꯐꯣꯟꯇꯅ#
# > kunthraataret
# = ꯀꯨꯟꯊ꯭ꯔꯥꯇꯔꯦꯠ
# < ꯀꯨꯟꯊ꯭ꯇꯔꯇꯦꯔꯥꯠ#
# > sidokpa
# = ꯁꯤꯗꯣꯛꯄ
# < ꯁꯤꯗꯣꯛꯄ#
# > firal
# = ꯐꯤꯔꯥꯜ
# < ꯐꯤꯔꯜ#
# > rohtak
# = ꯔꯣꯍꯇꯥꯛ
# < ꯔꯣꯠꯊꯛꯛ#
# > thaajajaba
# = ꯊꯥꯖꯖꯕ
# < ꯊꯥꯖꯖꯕ#
# > paak
# = ꯄꯥꯛ
# < ꯄꯥꯛ#
# > laakpadagi
# = ꯂꯥꯛꯄꯗꯒꯤ
# < ꯂꯥꯛꯄꯗꯒꯤ#
# > faoduna
# = ꯐꯥꯎꯗꯨꯅ
# < ꯐꯥꯎꯗꯨꯅ#
# > lonbu
# = ꯂꯣꯟꯕꯨ
# < ꯂꯣꯟꯕꯨ#
# > gurdaspur
# = ꯒꯨꯔꯗꯥꯁꯄꯨꯔ
# < ꯖꯨꯔꯔꯁꯨꯁ#
# > kangleichaa
# = ꯀꯪꯂꯩꯆꯥ
# < ꯀꯪꯂꯩꯆꯥ#
# > anou
# = ꯑꯅꯧ
# < ꯑꯅꯣ#
# > buildcon
# = ꯕꯤꯜꯗꯀꯣꯟ
# < ꯕꯨꯜꯗꯣꯟ#
# > ojha
# = ꯑꯣꯓꯥ
# < ꯑꯣꯖꯥ#
# > snow
# = ꯁ꯭ꯅꯣ
# < ꯁ꯭ꯋꯧꯚꯣ#
# > kayaana
# = ꯀꯌꯥꯅ
# < ꯀꯥꯅꯥ#
# > navkar
# = ꯅꯕꯀꯥꯔ
# < ꯅꯔꯥꯔꯔꯁ#
# > artemis
# = ꯑꯥꯔꯇꯃꯤꯁ
# < ꯑꯥꯔꯃꯃꯁꯤ#
# > loubasu
# = ꯂꯧꯕꯁꯨ
# < ꯂꯧꯕꯁꯨ#
# > bijandogi
# = ꯕꯤꯖꯥꯟꯗꯣꯒꯤ
# < ꯕꯤꯖꯥꯡꯗꯒꯤ#
# > oirakpa
# = ꯑꯣꯢꯔꯛꯄ
# < ꯑꯣꯢꯔꯛꯄꯥ#
# > thalon
# = ꯊꯥꯂꯣꯟ
# < ꯊꯥꯂꯣꯟ#
# > anishuba
# = ꯑꯅꯤꯁꯨꯕ
# < ꯑꯅꯤꯕꯨꯅ#
# > fine
# = ꯐꯥꯢꯟ
# < ꯐꯤꯅꯦ#
# > laphoidagi
# = ꯂꯐꯣꯢꯗꯒꯤ
# < ꯂꯥꯐꯣꯢꯗꯒꯤ#
# > dhaulakhandi
# = ꯙꯥꯎꯂꯈꯟꯗꯤ
# < ꯙꯥꯂꯟꯗꯤ#
# > kaang
# = ꯀꯥꯡ
# < ꯀꯥꯡ#
# > ningthouja
# = ꯅꯤꯡꯊꯧꯖꯥ
# < ꯅꯤꯡꯊꯧ#
# > montclair
# = ꯃꯣꯟꯠꯀ꯭ꯂꯦꯔ
# < ꯃꯣꯟꯇꯣꯔꯤ#
# > bhaskar
# = ꯚꯥꯁꯀꯔ
# < ꯚꯥꯀꯔ#
# > sak
# = ꯁꯛ
# < ꯁꯛ#
# > dronacharya
# = ꯗ꯭ꯔꯣꯅꯥꯆꯥꯔꯌ
# < ꯗ꯭ꯔꯦꯟꯅꯥꯥꯥ#
# > kayaamaromda
# = ꯀꯌꯥꯃꯔꯣꯝꯗ
# < ꯀꯌꯥꯃꯃꯝꯗꯨ#
# > mandal
# = ꯃꯟꯗꯜ
# < ꯃꯟꯗꯥꯜ#
# > basirhat
# = ꯕꯁꯤꯔꯠ
# < ꯕꯥꯖꯤꯇ꯭#
# > sayangsinggi
# = ꯁꯌꯥꯡꯁꯤꯡꯒꯤ
# < ꯁꯌꯥꯡꯁꯤꯡꯒꯤ#
# > aggarwal
# = ꯑꯒꯔꯋꯥꯜ
# < ꯑꯒꯥꯔꯥꯜ#
# > hainadi
# = ꯍꯥꯢꯅꯗꯤ
# < ꯍꯥꯢꯅꯗꯤ#
# > novato
# = ꯅꯣꯕꯥꯇꯣ
# < ꯅꯣꯚꯥ#
# > saruktana
# = ꯁꯔꯨꯛꯇꯅ
# < ꯁꯔꯨꯛꯇꯅ#
# > hess
# = ꯍꯦꯁ
# < ꯍꯦꯁꯁ#
# > waangkhatlakkhi
# = ꯋꯥꯡꯈꯠꯂꯛꯈꯤ
# < ꯋꯥꯡꯈꯠꯈꯤꯈ#
# > madhubani
# = ꯃꯙꯨꯕꯅꯤ
# < ꯃꯙꯨꯕꯅꯤ#
# > ortiz
# = ꯑꯣꯔꯇꯤꯖ
# < ꯑꯣꯔꯤꯇꯤꯌꯤꯑꯌ#
# > baxter
# = ꯕꯦꯛꯁꯇꯔ
# < ꯕꯥꯦꯇꯔ#
# > midwest
# = ꯃꯤꯗꯋꯦꯁꯠ
# < ꯃꯤꯗ꯭ꯁꯇ꯭ꯌꯦꯠ#
# > vijayapura
# = ꯕꯤꯖꯌꯥꯄꯨꯔꯥ
# < ꯚꯤꯖꯥꯐꯥꯔꯥ#
# > nischal
# = ꯅꯤꯁꯆꯜ
# < ꯅꯤꯁꯜ#
# > naanabagi
# = ꯅꯥꯅꯕꯒꯤ
# < ꯅꯥꯅꯕꯒꯤ#
# > morgan
# = ꯃꯣꯔꯒꯥꯟ
# < ꯃꯣꯔꯥꯟ#
# > shanthi
# = ꯁꯥꯟꯊꯤ
# < ꯁꯟꯊꯤ#
# > lalpicha
# = ꯂꯥꯜꯄꯤꯆꯥ
# < ꯂꯥꯜꯄꯤꯤꯆ#
# > yucaipa
# = ꯌꯨꯀꯥꯢꯄ
# < ꯌꯨꯀꯥꯢꯀꯥꯄ#
# > medizensar
# = ꯃꯦꯗꯤꯖꯦꯟꯁꯔ
# < ꯃꯦꯗꯦꯗꯤꯁ#
# > mairel
# = ꯃꯥꯢꯔꯦꯜ
# < ꯃꯥꯔꯦꯜ#
# > awaafam
# = ꯑꯋꯥꯐꯝ
# < ꯑꯋꯥꯐꯝ#
# > taplabadi
# = ꯇꯞꯂꯕꯗꯤ
# < ꯇꯞꯄꯕꯗꯤ#
# > romeda
# = ꯔꯣꯝꯗ
# < ꯔꯣꯃꯗ#
# > ngaakthoki
# = ꯉꯥꯛꯊꯣꯛꯏ
# < ꯉꯥꯛꯊꯣꯛꯀꯤ#
# > maangte
# = ꯃꯥꯡꯇꯦ
# < ꯃꯥꯡꯇꯦ#
# > hayengla
# = ꯍꯌꯦꯡꯂ
# < ꯍꯥꯌꯦꯡꯂꯥ#
# > lepte
# = ꯂꯦꯞꯇꯦ
# < ꯂꯦꯞꯇꯦ#
# > romeoville
# = ꯔꯣꯃꯤꯑꯣꯕꯤꯜ
# < ꯔꯣꯃꯦꯂꯜꯂꯦ#
# > jenon
# = ꯖꯦꯅꯣꯟ
# < ꯖꯦꯅꯣꯟ#
# > gtpl
# = ꯖꯤꯇꯤꯄꯤꯑꯦꯜ
# < ꯒꯦꯠꯄ#
# > passaic
# = ꯄꯁꯦꯢꯛ
# < ꯄꯥꯁꯥꯛꯄ#
# > waarinachingbasinggi
# = ꯋꯥꯔꯤꯅꯆꯤꯡꯕꯁꯤꯡꯒꯤ
# < ꯋꯥꯔꯤꯟꯆꯆꯤꯁꯁꯤꯡꯕꯤꯒꯤ#
# > sirohi
# = ꯁꯤꯔꯣꯍꯤ
# < ꯁꯤꯔꯤ#
# > mapaal
# = ꯃꯄꯥꯜ
# < ꯃꯄꯥꯜ#
# > kalki
# = ꯀꯥꯜꯀꯤ
# < ꯀꯜꯜꯀꯤ#
# > mainpuri
# = ꯃꯦꯟꯄꯨꯔꯤ
# < ꯃꯥꯢꯄ꯭ꯔꯔꯤ#
# > amblikani
# = ꯑꯦꯝꯕ꯭ꯂꯤꯀꯥꯅꯤ
# < ꯑꯦꯝꯕꯤꯛꯀꯤꯅꯤ#
# > alwar
# = ꯑꯜꯋꯥꯔ
# < ꯑꯜꯋꯔꯥ#
# > khundaba
# = ꯈꯨꯟꯗꯥꯕ
# < ꯈꯨꯟꯗꯕ#
# > thiruvananthapuram
# = ꯊꯤꯔꯨꯚꯅꯟꯊꯥꯄꯨꯔꯝ
# < ꯊꯤꯔꯦꯟꯕꯤꯟꯅꯥꯐꯝ#
# > sintaknabi
# = ꯁꯤꯟꯇꯥꯛꯅꯕꯤ
# < ꯁꯤꯟꯇꯥꯛꯕꯤ#
# > titagarh
# = ꯇꯤꯇꯥꯒꯔ
# < ꯇꯤꯇꯥꯈꯔ#
# > mandarin
# = ꯃꯟꯗꯥꯔꯤꯟ
# < ꯃꯟꯗꯔꯅꯤꯤ#
# > pithaki
# = ꯄꯤꯊꯛꯏ
# < ꯄꯤꯊꯥꯛꯤ#
# > putta
# = ꯄꯨꯠꯇꯥ
# < ꯄꯨꯇꯇ#
# > savita
# = ꯁꯚꯤꯇꯥ
# < ꯁꯥꯇꯇ#
# > ethel
# = ꯏꯊꯦꯜ
# < ꯏꯊꯦꯜ#
# > umba
# = ꯎꯝꯕ
# < ꯎꯝꯕ#
# > lithiumgi
# = ꯂꯤꯊꯤꯌꯝꯒꯤ
# < ꯂꯤꯊꯧꯃꯝꯒꯤ#
# > maharashtra
# = ꯃꯍꯥꯔꯥꯁꯇ꯭ꯔ
# < ꯃꯍꯔꯁꯥꯇꯔ#
# > pulap
# = ꯄꯨꯂꯞ
# < ꯄꯨꯂꯥꯞ#
# > abkhaziada
# = ꯑꯕꯈꯥꯓꯤꯌꯥꯗ
# < ꯑꯕꯈꯦꯤꯗ#
# > leitrabi
# = ꯂꯩꯇ꯭ꯔꯕꯤ
# < ꯂꯩꯇ꯭ꯔꯕꯤ#
# > houjikna
# = ꯍꯧꯖꯤꯛꯅ
# < ꯍꯧꯖꯤꯟ#
# > carpentersville
# = ꯀꯥꯔꯄꯦꯟꯇꯔꯁꯚꯤꯜ
# < ꯀꯔꯔꯦꯦꯦꯅꯦꯁꯦ#
# > ayers
# = ꯑꯦꯌꯔꯁ
# < ꯑꯌꯦꯔꯁꯁ#
# > nungsirei
# = ꯅꯨꯡꯁꯤꯔꯩ
# < ꯅꯨꯡꯁꯤꯔꯩ#
# > puwarisi
# = ꯄꯨꯋꯥꯔꯤꯁꯤ
# < ꯄꯨꯔꯥꯔꯤꯤ#
# > kayamarom
# = ꯀꯌꯥꯃꯔꯣꯝ
# < ꯀꯌꯥꯃꯃꯔꯝ#
# > animak
# = ꯑꯅꯤꯃꯛ
# < ꯑꯅꯤꯃꯛ#
# > dial
# = ꯗꯥꯢꯜ
# < ꯗꯤꯑꯥꯜ#
# > sangsaalol
# = ꯁꯪꯁꯥꯂꯣꯜ
# < ꯁꯪꯁꯥꯂꯣꯜ#
# > waaheiparengsing
# = ꯋꯥꯍꯩꯄꯔꯦꯡꯁꯤꯡ
# < ꯋꯥꯍꯩꯦꯦꯟꯁꯦꯡꯤꯡ#
# > cortes
# = ꯀꯣꯔꯇꯦꯁ
# < ꯀꯣꯔꯇꯁ#
# > uttarakhand
# = ꯎꯠꯇꯔꯥꯈꯟꯗ
# < ꯎꯠꯊꯛꯈꯔꯟꯗ#
# > yaaduna
# = ꯌꯥꯗꯨꯅ
# < ꯌꯥꯗꯨꯅ#
# > lewisville
# = ꯂꯤꯎꯋꯤꯁꯕꯤꯜ
# < ꯂꯦꯋꯤꯁꯂꯤꯂꯦ#
# > yaduna
# = ꯌꯥꯗꯨꯅ
# < ꯌꯥꯗꯨꯅ#
# > paakthokpana
# = ꯄꯥꯛꯊꯣꯛꯄꯅ
# < ꯄꯥꯛꯊꯣꯛꯅ#
# > halebid
# = ꯍꯥꯂꯦꯕꯤꯗ
# < ꯍꯂꯦꯕꯗꯤ#
# > pannaraga
# = ꯄꯥꯟꯅꯔꯒ
# < ꯄꯥꯟꯅꯔꯒ#
# > phylumni
# = ꯐꯥꯢꯂꯝꯅꯤ
# < ꯐꯤꯂꯝꯝꯤꯅꯤ#
# > ananki
# = ꯑꯥꯅꯟꯀꯤ
# < ꯑꯅꯅꯀꯀꯤ#
# > palli
# = ꯄꯥꯜꯂꯤ
# < ꯄꯥꯂꯤ#
# > fangkhibadugi
# = ꯐꯪꯈꯤꯕꯗꯨꯒꯤ
# < ꯐꯪꯈꯤꯕꯗꯒ#
# > manaonupi
# = ꯃꯅꯥꯎꯅꯨꯄꯤ
# < ꯃꯅꯥꯎꯅꯤꯄ#
# > waheiparengsing
# = ꯋꯥꯍꯩꯄꯔꯦꯡꯁꯤꯡ
# < ꯋꯥꯍꯩꯄꯦꯔꯤꯡꯁꯤꯡ#
# > denver
# = ꯗꯦꯟꯕꯔ
# < ꯗꯦꯟꯗ꯭ꯔꯦ#
# > yaade
# = ꯌꯥꯗꯦ
# < ꯌꯥꯗꯦ#
# > leirang
# = ꯂꯩꯔꯥꯡ
# < ꯂꯩꯔꯪ#
# > shurungni
# = ꯁꯨꯨꯔꯨꯡꯅꯤ
# < ꯁꯨꯔꯨꯡꯅꯤ#
# > hiramda
# = ꯍꯤꯔꯝꯗ
# < ꯍꯤꯔꯝꯗ#
# > silvassa
# = ꯁꯤꯜꯕꯥꯁꯥ
# < ꯁꯤꯜꯁꯕ#
# > palo
# = ꯄꯥꯂꯣ
# < ꯄꯥꯂꯣ#
# > linariba
# = ꯂꯤꯅꯔꯤꯕ
# < ꯂꯤꯅꯔꯔꯤꯕ#
# > vizianagaram
# = ꯕꯤꯖꯤꯑꯥꯅꯒꯔꯝ
# < ꯚꯤꯖꯤꯅꯥꯔꯝ#
# > lonnabada
# = ꯂꯣꯟꯅꯕꯗ
# < ꯂꯣꯟꯅꯗ#
# > ngaoraga
# = ꯉꯥꯎꯔꯒ
# < ꯉꯥꯎꯔꯒ#
# > rusian
# = ꯔꯨꯁꯤꯌꯥꯟ
# < ꯔꯨꯁꯤꯟꯁ#
# > asahi
# = ꯑꯁꯥꯍꯤ
# < ꯑꯁꯍꯤ#
# > laichinglempigi
# = ꯂꯥꯢꯆꯤꯡꯂꯦꯝꯄꯤꯒꯤ
# < ꯂꯥꯢꯈꯤꯡꯂꯝꯝꯒꯒꯤ#
# > claire
# = ꯀ꯭ꯂꯦꯔ
# < ꯀꯦꯔꯤꯌꯦ#
# > booth
# = ꯕꯨꯊ
# < ꯕꯣꯊꯊꯦꯠ#
# > contracts
# = ꯀꯣꯟꯇ꯭ꯔꯦꯛꯁ
# < ꯀꯣꯟꯇ꯭ꯔꯁꯁ#
# > sambhal
# = ꯁꯝꯚꯜ
# < ꯁꯝꯍꯜ#
# > shoes
# = ꯁꯨꯁ
# < ꯁꯧꯁ#
# > taankhibana
# = ꯇꯥꯟꯈꯤꯕꯅ
# < ꯇꯥꯈꯈꯤꯕꯅ#
# > thadoktuna
# = ꯊꯥꯗꯣꯛꯇꯨꯅ
# < ꯊꯥꯗꯣꯛꯇꯨ#
# > pangduna
# = ꯄꯥꯡꯗꯨꯅ
# < ꯄꯪꯗꯨꯅ#
# > damoh
# = ꯗꯃꯣꯍ
# < ꯗꯥꯍꯣꯣ#
# > laatpaki
# = ꯂꯥꯠꯄꯀꯤ
# < ꯂꯥꯇꯛꯛꯀꯤ#
# > kavi
# = ꯀꯕꯤ
# < ꯀꯥꯕꯤ#
# > moradabad
# = ꯃꯣꯔꯥꯗꯕꯥꯗ
# < ꯃꯣꯔꯗꯗꯕꯗ#
# > mandi
# = ꯃꯥꯟꯗꯤ
# < ꯃꯟꯗꯤ#
# > nathdwara
# = ꯅꯊꯗ꯭ꯋꯥꯔꯥ
# < ꯅꯠꯗ꯭ꯔꯥ#
# > sasidharan
# = ꯁꯁꯤꯙꯔꯟ
# < ꯁꯥꯖꯤꯗꯔꯥꯟ#
# > ongani
# = ꯑꯣꯟꯒꯅꯤ
# < ꯑꯣꯟꯒꯅꯤ#
# > khuyum
# = ꯈꯨꯌꯨꯝ
# < ꯈꯨꯌꯨꯝ#
# > communications
# = ꯀꯃꯨꯅꯤꯀꯦꯁꯟ
# < ꯀꯣꯃꯦꯟꯅꯦꯁꯁꯤ#
# > chakma
# = ꯆꯛꯃꯥ
# < ꯆꯥꯃ#
# > chitranshi
# = ꯆꯤꯇ꯭ꯔꯟꯁꯤ
# < ꯆꯤꯠꯇ꯭ꯔꯥꯟꯁꯤ#
# > panggalbagi
# = ꯄꯥꯡꯒꯜꯕꯒꯤ
# < ꯄꯥꯡꯒꯜꯂꯒꯤ#
# > haute
# = ꯑꯎꯠ
# < ꯍꯥꯇꯦꯠ#
# > turen
# = ꯇꯨꯔꯦꯟ
# < ꯇꯨꯔꯦꯟ#
# > haijei
# = ꯍꯥꯢꯖꯩ
# < ꯍꯥꯢꯖꯩ#
# > tiruchchirappalli
# = ꯇꯤꯔꯨꯆꯤꯔꯥꯄꯂꯤ
# < ꯇꯤꯔꯨꯐꯤꯔꯂꯨꯝꯅꯤ#
# > jagaragallu
# = ꯖꯒꯔꯒꯜꯂꯨ
# < ꯖꯥꯒꯥꯔꯂꯝ#
# > novak
# = ꯅꯣꯚꯥꯛ
# < ꯅꯣꯔꯥꯛ#
# > remains
# = ꯔꯤꯃꯦꯟꯁ
# < ꯔꯦꯃꯥꯃꯤꯟꯁ#
# > ouria
# = ꯑꯧꯔꯤꯌꯥ
# < ꯑꯧꯔꯥꯌꯥ#
# > saknakhi
# = ꯁꯛꯅꯈꯤ
# < ꯁꯥꯛꯈꯤ#
# > biotec
# = ꯕꯥꯢꯑꯣꯇꯦꯛ
# < ꯕꯤꯑꯣꯛꯠ#
# > dudeja
# = ꯗꯨꯗꯦꯖꯥ
# < ꯗꯨꯗꯦꯗ#
# > porwal
# = ꯄꯣꯔꯋꯥꯜ
# < ꯄꯣꯔꯥꯥꯋꯥꯜ#
# > eagan
# = ꯏꯒꯟ
# < ꯏꯥꯥꯒꯟ#
# > shores
# = ꯁꯣꯔꯁ
# < ꯁꯣꯔꯦꯁ#
# > mayoknaba
# = ꯃꯥꯌꯣꯛꯅꯕ
# < ꯃꯌꯣꯛꯅꯕ#
# > gudepu
# = ꯒꯨꯗꯦꯄꯨ
# < ꯖꯨꯗꯗꯦ#
# > kalidas
# = ꯀꯥꯂꯤꯗꯥꯁ
# < ꯀꯥꯂꯤꯗꯁ#
# > khuman
# = ꯈꯨꯃꯟ
# < ꯈꯨꯃꯅ#
# > haor
# = ꯍꯥꯑꯣꯔ
# < ꯍꯥꯎꯔ#
# > ekha
# = ꯏꯈꯥ
# < ꯏꯈꯥ#
# > kayamarumna
# = ꯀꯌꯥꯃꯔꯨꯝꯅ
# < ꯀꯌꯥꯃꯔꯝꯨꯅ#
# > gould
# = ꯒꯣꯜꯗ
# < ꯒꯧꯗ#
# > lonsingdudi
# = ꯂꯣꯟꯁꯤꯡꯗꯨꯗꯤ
# < ꯂꯣꯟꯁꯤꯡꯗꯨ#
# > hinton
# = ꯍꯤꯟꯇꯟ
# < ꯍꯤꯟꯇꯣꯟ#
# > koubi
# = ꯀꯧꯕꯤ
# < ꯀꯧꯕꯤ#
# > epakachouba
# = ꯏꯄꯥꯛꯑꯆꯧꯕ
# < ꯏꯄꯥꯎꯆꯣꯝꯕ#
# > kerr
# = ꯀꯦꯔ
# < ꯀꯦꯔꯔ#
# > imarat
# = ꯏꯃꯥꯔꯠ
# < ꯏꯔꯥꯇꯠ#
# > hankhibagi
# = ꯍꯟꯈꯤꯕꯒꯤ
# < ꯍꯥꯈꯤꯟꯕꯒꯤ#
# > thapaalongi
# = ꯊꯄꯥꯂꯣꯟꯒꯤ
# < ꯊꯥꯄꯥꯂꯣꯟꯒꯤ#
# > health
# = ꯍꯦꯜꯊ
# < ꯍꯦꯞꯊꯦ#
# > peel
# = ꯄꯤꯜ
# < ꯄꯤꯜ#
# > hans
# = ꯍꯦꯟ꯭ꯁ
# < ꯍꯥꯟꯁ#
# > neongi
# = ꯅꯤꯌꯣꯟꯒꯤ
# < ꯅꯦꯑꯣꯡꯒꯤ#
# > felipe
# = ꯐꯦꯂꯤꯄꯦ
# < ꯐꯦꯂꯤꯄꯦ#
# > hourakliba
# = ꯍꯧꯔꯛꯂꯤꯕ
# < ꯍꯧꯔꯛꯂꯤꯕ#
# > yektuna
# = ꯌꯦꯛꯇꯨꯅ
# < ꯌꯦꯛꯇꯨꯅ#
# > kansal
# = ꯀꯥꯟꯁꯜ
# < ꯀꯟꯁꯥꯜ#
# > setpi
# = ꯁꯦꯠꯄꯤ
# < ꯁꯦꯠꯄꯤ#
# > urbandale
# = ꯑꯔꯕꯥꯟꯗꯦꯜ
# < ꯌꯨꯔꯖꯦꯦ#
# > longganga
# = ꯂꯣꯡꯒꯥꯟꯒ
# < ꯂꯣꯡꯒꯥꯡ#
# > ishing
# = ꯏꯁꯤꯡ
# < ꯏꯁꯤꯡ#
# > manunggi
# = ꯃꯅꯨꯡꯒꯤ
# < ꯃꯅꯨꯡꯒꯤ#
# > morepen
# = ꯃꯣꯔꯄꯦꯟ
# < ꯃꯣꯔꯦꯄꯦꯟ#
# > nizamabad
# = ꯅꯤꯖꯥꯃꯕꯥꯗ
# < ꯅꯤꯖꯥꯗꯕ#
# > sahu
# = ꯁꯥꯍꯨ
# < ꯁꯥꯍꯨ#
# > ulhasnagar
# = ꯎꯜꯍꯥꯁꯅꯒꯔ
# < ꯎꯍꯚꯁꯤꯔꯥꯁ#
# > lusiya
# = ꯂꯨꯁꯤꯌꯥ
# < ꯂꯨꯌꯤꯌꯥ#
# > raichur
# = ꯔꯥꯢꯆꯨꯔ
# < ꯔꯥꯢꯊꯨꯔ#
# > rewari
# = ꯔꯦꯋꯥꯔꯤ
# < ꯔꯦꯋꯥꯔꯤ#
# > phabagi
# = ꯐꯕꯒꯤ
# < ꯐꯕꯒꯤ#
# > sitising
# = ꯁꯤꯇꯤꯁꯤꯡ
# < ꯁꯤꯇꯤꯁꯤꯡ#
# > kelly
# = ꯀꯦꯜꯂꯤ
# < ꯀꯦꯜꯂꯤ#
# > sebastian
# = ꯁꯦꯕꯥꯁꯇꯤꯌꯥꯟ
# < ꯁꯦꯕꯥꯔꯦꯟꯅꯤ#
# > khullaakpani
# = ꯈꯨꯜꯂꯥꯛꯄꯅꯤ
# < ꯈꯨꯜꯂꯛꯄꯅꯤ#
# > solapur
# = ꯁꯣꯂꯥꯄꯨꯔ
# < ꯁꯣꯄꯥꯔꯔꯨ#
# > madikeri
# = ꯃꯥꯗꯀꯔꯤ
# < ꯃꯤꯗ꯭ꯔꯤꯀꯔꯤ#
# > shivamogga
# = ꯁꯤꯚꯃꯣꯒꯥ
# < ꯁꯤꯕꯥꯥꯣ#
# > vaish
# = ꯚꯥꯢꯁ
# < ꯚꯥꯢꯁ#
# > sasan
# = ꯁꯥꯁꯟ
# < ꯁꯁꯥꯟ#
# > nashik
# = ꯅꯥꯁꯤꯛ
# < ꯅꯥꯤꯁ#
# > yengsinba
# = ꯌꯦꯡꯁꯤꯟꯕ
# < ꯌꯦꯡꯁꯤꯟꯕ#
# > labs
# = ꯂꯦꯕꯁ
# < ꯂꯥꯕꯁ#
# > shalimar
# = ꯁꯥꯂꯤꯃꯥꯔ
# < ꯁꯂꯤꯃꯁꯤꯌꯔ#
# > ayodhya
# = ꯑꯌꯣꯙ꯭ꯌꯥ
# < ꯑꯌꯣꯌꯗꯥ#
# > rajapalayam
# = ꯔꯥꯖꯄꯥꯂꯌꯝ
# < ꯔꯥꯖꯥꯐꯝ#
# > jay
# = ꯖꯦ
# < ꯖꯥꯌ#
# > ngaohanbagi
# = ꯉꯥꯎꯍꯟꯕꯒꯤ
# < ꯉꯥꯍꯍꯡꯕꯒꯤ#
# > churaachaanna
# = ꯆꯨꯔꯥꯆꯥꯟꯅ
# < ꯆꯨꯔꯥꯟꯆꯅꯥ#
# > etawah
# = ꯏꯇꯥꯋꯥ
# < ꯏꯇꯋꯋꯥ#
# > lishaang
# = ꯂꯤꯁꯥꯡ
# < ꯂꯤꯡꯁꯥ#
# > jadhav
# = ꯖꯥꯙꯚ
# < ꯖꯥꯗꯚꯔ#
# > phoureima
# = ꯐꯧꯔꯩꯃ
# < ꯐꯧꯔꯩ#
# > mityengpham
# = ꯃꯤꯠꯌꯦꯡꯐꯝ
# < ꯃꯤꯠꯦꯐꯝ#
# > organic
# = ꯑꯣꯔꯒꯥꯅꯤꯛ
# < ꯑꯣꯔꯥꯅꯁꯛꯁꯤ#
# > khagokpam
# = ꯈꯥꯒꯣꯛꯄꯝ
# < ꯈꯥꯒꯣꯢꯄꯝ#
# > chicopee
# = ꯆꯤꯀꯣꯄꯤ
# < ꯆꯤꯀꯣꯄ#
# > jambawan
# = ꯖꯥꯝꯕꯋꯟ
# < ꯖꯝꯕꯔꯣꯟ#
# > agrada
# = ꯑꯥꯒ꯭ꯔꯥꯗ
# < ꯑꯔꯗꯗ#
# > pradeshta
# = ꯄ꯭ꯔꯗꯦꯁꯇ
# < ꯄ꯭ꯗꯦꯁꯇ#
# > ewanglon
# = ꯏꯋꯥꯡꯂꯣꯟ
# < ꯏꯋꯥꯉꯂꯣꯟ#
# > vilas
# = ꯕꯤꯂꯥꯁ
# < ꯚꯤꯂꯥꯁ#
# > thouninarammi
# = ꯊꯧꯅꯤꯅꯔꯝꯃꯤ
# < ꯊꯧꯅꯤꯅꯔꯝꯝꯤ#
# > taklamba
# = ꯇꯥꯛꯂꯝꯕ
# < ꯇꯥꯛꯂꯝꯕ#
# > saknairaba
# = ꯁꯛꯅꯥꯢꯔꯕ
# < ꯁꯥꯀꯔꯅꯤꯕ#
# > prince
# = ꯄ꯭ꯔꯤꯟꯁ
# < ꯄ꯭ꯔꯤꯄꯦꯟ#
# > tyler
# = ꯇꯥꯢꯂꯔ
# < ꯇꯤꯂꯦꯔꯤ#
# > yanaba
# = ꯌꯥꯅꯕ
# < ꯌꯥꯅꯕ#
# > aartifek
# = ꯑꯥꯔꯇꯤꯐꯦꯛ
# < ꯑꯥꯔꯇꯛꯄꯛ#
# > laishangsinggi
# = ꯂꯥꯢꯁꯪꯁꯤꯡꯒꯤ
# < ꯂꯥꯢꯁꯪꯁꯤꯡꯒꯤ#
# > paannaraga
# = ꯄꯥꯟꯅꯔꯒ
# < ꯄꯥꯟꯅꯔꯔꯒ#
# > walnut
# = ꯋꯥꯜꯅꯠ
# < ꯋꯥꯜꯅꯨꯇ#
# > nayak
# = ꯅꯥꯌꯛ
# < ꯅꯥꯌꯛ#
# > sikarwar
# = ꯁꯤꯀꯔꯋꯥꯔ
# < ꯁꯤꯀꯥꯛꯔꯔ#
# > maikeigasu
# = ꯃꯥꯢꯀꯩꯒꯁꯨ
# < ꯃꯥꯢꯉꯩ#
# > lappada
# = ꯂꯥꯞꯄꯗ
# < ꯂꯥꯞꯄꯗ#
# > wangkhatpa
# = ꯋꯥꯡꯈꯠꯄ
# < ꯋꯥꯡꯈꯠꯄ#
# > nath
# = ꯅꯥꯊ
# < ꯅꯊꯠ#
# > laphoisi
# = ꯂꯐꯣꯢꯁꯤ
# < ꯂꯥꯐꯣꯢꯁꯤ#
# > moody
# = ꯃꯨꯗꯤ
# < ꯃꯣꯑꯣꯢꯅꯤ#
# > mahavidya
# = ꯃꯍꯥꯋꯤꯗ꯭ꯌꯥ
# < ꯃꯍꯥꯌꯤꯗ#
# > lunglei
# = ꯂꯨꯡꯂꯩ
# < ꯂꯨꯡꯂꯩ#
# > hawthorne
# = ꯍꯣꯊꯣꯔꯟ
# < ꯍꯥꯊꯣꯟꯔꯦ#
# > priyadarshi
# = ꯄ꯭ꯔꯤꯌꯥꯗꯔꯁꯤ
# < ꯄ꯭ꯔꯥꯁꯤꯁꯤ#
# > tools
# = ꯇꯨꯜꯁ
# < ꯇꯣꯠꯁꯠ#
# > saruksingda
# = ꯁꯔꯨꯛꯁꯤꯡꯗ
# < ꯁꯔꯨꯛꯁꯤꯡ#
# > infotech
# = ꯏꯟꯐꯣꯇꯦꯛ
# < ꯏꯟꯐꯧꯈ#
# > bharat
# = ꯚꯥꯔꯠ
# < ꯚꯔꯥꯠ#
# > thaajanabi
# = ꯊꯥꯖꯅꯕꯤ
# < ꯊꯥꯖꯅꯕꯤ#
# > lily
# = ꯂꯤꯂꯤ
# < ꯂꯤꯂꯤꯌꯤ#
# > merta
# = ꯃꯔꯇꯥ
# < ꯃꯦꯔꯥ#
# > ising
# = ꯏꯁꯤꯡ
# < ꯏꯁꯪ#
# > maxina
# = ꯃꯦꯛꯁꯤꯅꯥ
# < ꯃꯀꯤꯅ#
# > channana
# = ꯆꯥꯟꯅꯅ
# < ꯆꯟꯅꯅ#
# > syngene
# = ꯁꯤꯟꯖꯤꯟ
# < ꯁꯤꯡꯅꯦ#
# > santa
# = ꯁꯦꯟꯇ
# < ꯁꯟꯇ#
# > thingkhiba
# = ꯊꯤꯡꯈꯤꯕ
# < ꯊꯤꯡꯈꯤꯕ#
# > carpentersville
# = ꯀꯥꯔꯄꯦꯟꯇꯔꯁꯕꯤꯜ
# < ꯀꯦꯔꯦꯟꯦꯔꯑꯦꯠꯂꯦ#
# > egypt
# = ꯏꯓꯤꯞ
# < ꯏꯖꯤꯠ#
# > luhonggadouribina
# = ꯂꯨꯍꯣꯡꯒꯗꯧꯔꯤꯕꯤꯅ
# < ꯂꯨꯍꯣꯡꯈꯣꯗꯗꯉꯅꯅꯨꯕꯅ#
# > purinaraga
# = ꯄꯨꯔꯤꯅꯔꯒ
# < ꯄꯨꯔꯤꯔꯥꯉꯥ#
# > sacramento
# = ꯁꯥꯀ꯭ꯔꯃꯦꯟꯇꯣ
# < ꯁꯁꯇꯔꯇꯣꯣꯅ#
# > khunsigi
# = ꯈꯨꯟꯁꯤꯒꯤ
# < ꯈꯨꯟꯁꯤꯒꯤ#
# > naoriya
# = ꯅꯥꯎꯔꯤꯌꯥ
# < ꯅꯥꯎꯔꯤꯌꯥ#
# > sudanga
# = ꯁꯨꯗꯟꯒ
# < ꯁꯨꯗꯗꯒꯟ#
# > charong
# = ꯆꯔꯣꯡ
# < ꯆꯥꯔꯣꯡ#
# > khongchangloi
# = ꯈꯣꯡꯆꯪꯂꯣꯢ
# < ꯈꯣꯡꯆꯥꯂꯣꯢ#
# > sennaba
# = ꯁꯦꯟꯅꯕ
# < ꯁꯦꯟꯅꯕ#
# > wipro
# = ꯋꯤꯄ꯭ꯔꯣ
# < ꯋꯤꯄ꯭ꯔꯣ#
# > wa
# = ꯋꯥ
# < ꯋꯥ#
# > ngaangkhaleima
# = ꯉꯥꯡꯈꯂꯩꯃ
# < ꯉꯥꯡꯈꯩꯊꯩꯃꯃ#
# > kharada
# = ꯈꯔꯗ
# < ꯈꯔꯗꯗ#
# > pallamba
# = ꯄꯜꯂꯝꯕ
# < ꯄꯥꯜꯂꯝꯕ#
# > gowa
# = ꯒꯣꯋꯥ
# < ꯒꯣꯋꯥ#
# > haktaktaki
# = ꯍꯥꯛꯇꯛꯇꯀꯤ
# < ꯍꯥꯛꯇꯥꯛꯀꯤ#
# > khenchonglongi
# = ꯈꯦꯟꯆꯣꯡꯂꯣꯟꯒꯤ
# < ꯈꯦꯟꯆꯣꯡꯂꯤ#
# > hamirpur
# = ꯍꯃꯤꯔꯄꯨꯔ
# < ꯍꯥꯃ꯭ꯔꯨꯔ#
# > archaeological
# = ꯑꯥꯔꯀꯦꯌꯣꯂꯣꯖꯤꯀꯦꯜ
# < ꯑꯥꯔꯥꯎꯄꯦꯜꯂꯤ#
# > garud
# = ꯒꯥꯔꯨꯗ
# < ꯚꯔꯨꯗ#
# > technoplast
# = ꯇꯦꯛꯅꯣꯄ꯭ꯂꯥꯁꯠ
# < ꯇꯦꯛꯈꯣꯟꯇꯦꯁ#
# > ahanpa
# = ꯑꯍꯥꯟꯄ
# < ꯑꯍꯥꯟꯄ#
# > paabadani
# = ꯄꯥꯕꯗꯅꯤ
# < ꯄꯥꯕꯕꯅꯤ#
# > singh
# = ꯁꯤꯡ
# < ꯁꯤꯡꯊ#
# > kalamazoo
# = ꯀꯥꯂꯥꯃꯥꯖꯨ
# < ꯀꯂꯥꯃꯥ#
# > linda
# = ꯂꯤꯟꯗꯥ
# < ꯂꯤꯟꯗ#
# > yoimongba
# = ꯌꯣꯢꯃꯣꯡꯕ
# < ꯌꯣꯢꯃꯣꯡꯕ#
# > kheipik
# = ꯈꯩꯄꯤꯛ
# < ꯈꯩꯄꯤ#
# > dharmshala
# = ꯙꯔꯃꯁꯥꯂꯥ
# < ꯙꯥꯔꯜꯂ#
# > moines
# = ꯃꯣꯢꯟ
# < ꯃꯣꯢꯅꯦ#
# > leingakta
# = ꯂꯩꯉꯥꯛꯇ
# < ꯂꯩꯉꯥꯛꯇꯇ#
# > konthoucham
# = ꯀꯣꯟꯊꯧꯆꯝ
# < ꯀꯣꯟꯊꯧꯐꯝꯝ#
# > chaobasi
# = ꯆꯥꯎꯕꯁꯤ
# < ꯆꯥꯎꯕꯁꯤ#
# > kolte
# = ꯀꯣꯜꯇꯦ
# < ꯀꯣꯜꯇꯦ#
# > paamchate
# = ꯄꯥꯝꯆꯇꯦ
# < ꯄꯥꯝꯈꯠ#
# > avery
# = ꯑꯦꯚꯔꯤ
# < ꯑꯚꯦꯔꯤ#
# > phaorabadi
# = ꯐꯥꯎꯔꯕꯗꯤ
# < ꯐꯥꯎꯔꯕꯗꯤ#
# > kappa
# = ꯀꯞꯄ
# < ꯀꯞꯄ#
# > lirambadagi
# = ꯂꯤꯔꯝꯕꯗꯒꯤ
# < ꯂꯤꯔꯝꯕꯒꯤ#
# > sarangpur
# = ꯁꯥꯔꯪꯄꯨꯔ
# < ꯁꯔꯥꯄꯥꯛꯔꯨ#
# > nizamat
# = ꯅꯤꯖꯥꯃꯠ
# < ꯅꯤꯌꯥꯝ#
# > napa
# = ꯅꯦꯄꯥ
# < ꯅꯥꯄ#
# > coimbatore
# = ꯀꯣꯏꯝꯕꯇꯣꯔ
# < ꯀꯦꯢꯕꯔꯔꯦꯔꯦ#
# > phaahanli
# = ꯐꯥꯍꯟꯂꯤ
# < ꯐꯥꯍꯜꯂꯤ#
# > hapnaba
# = ꯍꯥꯞꯅꯕ
# < ꯍꯥꯞꯅꯕ#
# > montgomery
# = ꯃꯣꯟꯠꯒꯣꯃꯦꯔꯤ
# < ꯃꯣꯟꯇꯣꯔꯤꯌꯤ#
# > phoenix
# = ꯐꯤꯅꯤꯛꯁ
# < ꯐꯣꯅꯤꯛ#
# > haangdokkhi
# = ꯍꯥꯡꯗꯣꯛꯈꯤ
# < ꯍꯥꯡꯗꯣꯛꯈꯤ#
# > worth
# = ꯋꯔꯊ
# < ꯋꯣꯔꯦꯠ#
# > apcotex
# = ꯑꯦꯞꯀꯣꯇꯦꯛꯁ
# < ꯑꯦꯄꯦꯟꯁꯤꯇ#
# > waachetmaanbi
# = ꯋꯥꯆꯦꯠꯃꯥꯟꯕꯤ
# < ꯋꯥꯆꯦꯝꯦꯝꯕꯤꯅꯤ#
# > paamjaba
# = ꯄꯥꯝꯖꯕ
# < ꯄꯥꯝꯖꯕ#
# > wangkhi
# = ꯋꯥꯡꯈꯤ
# < ꯋꯥꯈꯈꯤ#
# > sikkimese
# = ꯁꯤꯛꯀꯤꯝꯃꯤꯁ
# < ꯁꯤꯀꯤꯝꯁꯤ#
# > fabulous
# = ꯐꯦꯕꯨꯂꯁ
# < ꯐꯥꯕꯨꯁꯁꯁ#
# > mcmillan
# = ꯃꯛꯃꯤꯂꯟ
# < ꯃꯦꯀꯤꯂꯤꯟꯂ#
# > lanleima
# = ꯂꯥꯟꯂꯩꯃ
# < ꯂꯥꯟꯂꯩꯃ#
# > saluk
# = ꯁꯂꯨꯛ
# < ꯁꯥꯀꯛ#
# > utlammi
# = ꯎꯠꯂꯝꯃꯤ
# < ꯌꯠꯂꯝꯃꯤ#
# > bush
# = ꯕꯨꯁ
# < ꯕꯨꯁ#
# > movers
# = ꯃꯨꯕꯔꯁ
# < ꯃꯣꯚꯔꯁ#
# > innovation
# = ꯏꯟꯅꯣꯚꯦꯁꯟ
# < ꯏꯟꯅ꯭ꯟꯇꯣꯅꯅꯤ#
# > kulkarni
# = ꯀꯨꯜꯀꯥꯔꯅꯤ
# < ꯀꯨꯜꯀꯔꯅꯤ#
# > shadai
# = ꯁꯥꯗꯥꯢ
# < ꯁꯗꯗꯤ#
# > new
# = ꯅꯤꯎ
# < ꯅꯦꯋꯣ#
# > barry
# = ꯕꯦꯔꯤ
# < ꯕꯔꯔꯤꯌꯥ#
# > khatoon
# = ꯈꯥꯇꯨꯟ
# < ꯈꯥꯇꯣꯟ#
# > kullu
# = ꯀꯨꯂꯨ
# < ꯀꯨꯜꯂꯨ#
# > mclaughlin
# = ꯃꯛꯂꯣꯘꯂꯤꯟ
# < ꯃꯦꯄꯂꯜꯂꯤ#
# > yumsaalon
# = ꯌꯨꯝꯁꯥꯂꯣꯟ
# < ꯌꯨꯝꯁꯥꯎꯍꯣꯟ#
# > thengnabani
# = ꯊꯦꯡꯅꯕꯅꯤ
# < ꯊꯦꯡꯅꯕꯅꯤ#
# > samarjit
# = ꯁꯃꯔꯖꯤꯠ
# < ꯁꯃꯃꯥꯢꯇꯥ#
# > manana
# = ꯃꯅꯥꯅ
# < ꯃꯅꯅ#
# > aromatics
# = ꯑꯦꯔꯣꯃꯦꯇꯤꯛꯁ
# < ꯑꯔꯣꯃꯤꯇꯤꯛꯁ#
# > sarath
# = ꯁꯔꯊ
# < ꯁꯔꯥꯠ#
# > rock
# = ꯔꯣꯛ
# < ꯔꯣꯛꯀ#
# > singjamei
# = ꯁꯤꯡꯖꯃꯩ
# < ꯁꯤꯡꯖꯥꯃꯤ#
# > dabur
# = ꯗꯥꯕꯔ
# < ꯗꯥꯕꯔꯔ#
# > kuppa
# = ꯀꯨꯞꯄ
# < ꯀꯨꯞꯄ#
# > pakhouba
# = ꯄꯛꯍꯧꯕ
# < ꯄꯥꯢꯈꯧꯕ#
# > lainingda
# = ꯂꯥꯢꯅꯤꯡꯗ
# < ꯂꯥꯢꯅꯤꯡꯗ#
# > leinaotaabi
# = ꯂꯩꯅꯥꯎꯇꯥꯕꯤ
# < ꯂꯩꯅꯥꯟꯇꯇꯤꯕꯤ#
# > praveenchand
# = ꯄ꯭ꯔꯚꯤꯟꯆꯟꯗ
# < ꯄ꯭ꯔꯦꯖꯦꯟꯗꯥ#
# > pembroke
# = ꯄꯦꯝꯕ꯭ꯔꯣꯛ
# < ꯄꯦꯝꯕꯣꯔꯔ#
# > blackburn
# = ꯕ꯭ꯂꯦꯛꯕꯔꯟ
# < ꯕ꯭ꯔꯥꯔꯨꯛꯕꯨꯟ#
# > kumon
# = ꯀꯨꯝꯑꯣꯟ
# < ꯀꯨꯃꯣꯟ#
# > leinaotabi
# = ꯂꯩꯅꯥꯎꯇꯥꯕꯤ
# < ꯂꯩꯅꯥꯥꯇꯕꯇꯤ#
# > duncanville
# = ꯗꯟꯀꯦꯟꯕꯤꯜ
# < ꯗꯨꯟꯀꯟꯟꯦ#
# > lengsinbiraksi
# = ꯂꯦꯡꯁꯤꯟꯕꯤꯔꯛꯁꯤ
# < ꯂꯦꯡꯁꯤꯟꯅꯔꯤꯕꯁꯤ#
# > salazar
# = ꯁꯥꯂꯥꯖꯥꯔ
# < ꯁꯥꯂꯔꯥ#
# > cables
# = ꯀꯦꯕꯜꯁ
# < ꯀꯦꯕꯦꯁꯦ#
# > eshing
# = ꯏꯁꯤꯡ
# < ꯏꯁꯤꯡ#
# > laanpung
# = ꯂꯥꯟꯄꯨꯡ
# < ꯂꯥꯟꯄꯨꯡ#
# > bhadauriya
# = ꯚꯗꯨꯔꯤꯑꯥ
# < ꯚꯗꯗꯔꯥꯥꯔ#
# > malegaon
# = ꯃꯥꯂꯦꯒꯥꯎ
# < ꯃꯥꯥꯔꯌꯣꯡ#
# > ramon
# = ꯔꯥꯃꯣꯟ
# < ꯔꯥꯃꯣꯟ#
# > rakhecha
# = ꯔꯥꯈꯦꯆꯥ
# < ꯔꯥꯈꯆ#
# > awaangdagi
# = ꯑꯋꯥꯡꯗꯒꯤ
# < ꯑꯋꯥꯡꯗꯒꯤ#
# > amangshang
# = ꯑꯃꯥꯡꯁꯪ
# < ꯑꯃꯥꯡꯁꯪ#
# > ahaanba
# = ꯑꯍꯥꯟꯕ
# < ꯑꯍꯥꯟꯕ#
# > gepelina
# = ꯒꯦꯄꯦꯂꯤꯅꯥ
# < ꯒꯦꯄꯦꯄꯤꯂꯤꯅ#
# > aloibada
# = ꯑꯂꯣꯢꯕꯗ
# < ꯑꯂꯣꯢꯕꯗ#
# > covina
# = ꯀꯣꯕꯤꯅꯥ
# < ꯀꯤꯕꯅ#
# > sreeleathers
# = ꯁ꯭ꯔꯤꯂꯦꯗꯔꯁ
# < ꯁꯦꯔꯦꯔꯦꯦꯦꯦꯁꯨ#
# > adugei
# = ꯑꯗꯨꯒꯩ
# < ꯑꯨꯒꯩ#
# > duncanville
# = ꯗꯟꯀꯦꯟꯚꯤꯜ
# < ꯗꯨꯟꯀꯨꯟꯦꯦꯦꯂꯦ#
# > dinu
# = ꯗꯤꯅꯨ
# < ꯗꯤꯅꯨ#
# > brooklyn
# = ꯕ꯭ꯔꯨꯛꯂꯤꯟ
# < ꯕ꯭ꯔꯣꯟꯀꯣꯟ#
# > rampur
# = ꯔꯥꯝꯄꯨꯔ
# < ꯔꯝꯄꯨꯔ#
# > imung
# = ꯏꯃꯨꯡ
# < ꯏꯅꯨꯡ#
# > aventura
# = ꯑꯚꯦꯟꯆꯨꯔꯥ
# < ꯑꯦꯦꯟꯇ꯭ꯔꯥ#
# > thaakhraba
# = ꯊꯥꯈ꯭ꯔꯕ
# < ꯊꯥꯈ꯭ꯔꯕ#
# > richardson
# = ꯔꯤꯆꯥꯔꯗꯁꯟ
# < ꯔꯤꯆꯔꯁꯟ#
# > grapevine
# = ꯒ꯭ꯔꯦꯞꯚꯥꯢꯟ
# < ꯔ꯭ꯔꯦꯄꯇꯇꯤ#
# > khanaona
# = ꯈꯅꯥꯎꯅ
# < ꯈꯅꯅꯥ#
# > miyengkhaada
# = ꯃꯤꯌꯦꯡꯈꯥꯗ
# < ꯃꯤꯌꯦꯡꯈꯥꯗ#
# > alameda
# = ꯑꯦꯂꯥꯃꯦꯗ
# < ꯑꯂꯥꯃꯗ#
# > maong
# = ꯃꯑꯣꯡ
# < ꯃꯑꯣꯡ#
# > iqbal
# = ꯏꯛꯕꯥꯜ
# < ꯏꯥꯕꯜ#
# > gardner
# = ꯒꯥꯔꯗꯅꯔ
# < ꯒꯔꯦꯟꯅꯔꯤ#
# > hines
# = ꯍꯥꯢꯟꯁ
# < ꯍꯤꯅꯁ#
# > kipgen
# = ꯀꯤꯞꯒꯦꯟ
# < ꯀꯤꯡꯦꯦꯟ#
# > yellam
# = ꯌꯦꯜꯂꯥꯝ
# < ꯌꯦꯜꯂꯝ#
# > deerfield
# = ꯗꯤꯑꯔꯐꯤꯜꯗ
# < ꯗꯤꯔꯦꯤꯐꯦꯜ#
# > leingaklamba
# = ꯂꯩꯉꯥꯛꯂꯝꯕ
# < ꯂꯩꯉꯥꯛꯂꯕ#
# > chopra
# = ꯆꯣꯄ꯭ꯔꯥ
# < ꯆꯣꯞꯔ#
# > hanglabadi
# = ꯍꯪꯂꯕꯗꯤ
# < ꯍꯪꯂꯕꯗꯤ#
# > hades
# = ꯍꯦꯗꯤꯁ
# < ꯍꯗꯦꯦꯁꯦ#
# > russell
# = ꯔꯁꯁꯦꯜ
# < ꯔꯨꯁꯦꯜ#
# > purana
# = ꯄꯨꯔꯥꯅ
# < ꯄꯨꯔꯅ#
# > burnsville
# = ꯕꯔꯟꯁꯕꯤꯜ
# < ꯕꯨꯔꯁꯦꯠꯅꯦ#
# > takli
# = ꯇꯥꯛꯂꯤ
# < ꯇꯥꯛꯂꯤ#
# > soma
# = ꯁꯣꯃꯥ
# < ꯁꯣꯃ#
# > latli
# = ꯂꯥꯠꯂꯤ
# < ꯂꯥꯠꯂꯤ#
# > pidolhalli
# = ꯄꯤꯗꯣꯜꯍꯜꯂꯤ
# < ꯄꯤꯗꯣꯜꯈꯤ#
# > golden
# = ꯒꯣꯜꯗꯟ
# < ꯒꯣꯜꯗꯦꯟ#
# > miramar
# = ꯃꯤꯔꯥꯃꯥꯔ
# < ꯃꯤꯃꯥꯔꯔ#
# > development
# = ꯗꯤꯕꯦꯂꯞꯃꯦꯟꯠ
# < ꯗꯦꯇꯦꯂꯣꯟꯦꯇꯠ#
# > kanojia
# = ꯀꯅꯣꯖꯤꯑꯥ
# < ꯀꯅꯖꯤꯖꯥ#
# > inunglon
# = ꯏꯅꯨꯡꯂꯣꯟ
# < ꯏꯅꯨꯡꯂꯦꯡ#
# > khakempagi
# = ꯈꯥꯀꯦꯝꯄꯒꯤ
# < ꯈꯥꯛꯀꯦꯝꯗꯒꯤ#
# > nagoria
# = ꯅꯥꯒꯣꯔꯤꯑꯥ
# < ꯅꯥꯒꯣꯔꯤꯌꯥ#
# > hunduna
# = ꯍꯨꯟꯗꯨꯅ
# < ꯍꯨꯟꯗꯨꯅꯅ#
# > chada
# = ꯆꯥꯗ
# < ꯆꯥꯗ#
# > chandigarh
# = ꯆꯟꯗꯤꯒꯔ
# < ꯆꯟꯗ꯭ꯔꯤꯖꯥ#
# > potshangpam
# = ꯄꯣꯠꯁꯪꯄꯝ
# < ꯄꯣꯠꯁꯥꯡꯄꯝ#
# > mamangthakta
# = ꯃꯃꯥꯡꯊꯛꯇ
# < ꯃꯃꯥꯡꯊꯥꯛꯇ#
# > rabon
# = ꯔꯥꯕꯣꯟ
# < ꯔꯥꯕꯣꯟ#
# > jabalpur
# = ꯖꯕꯜꯄꯨꯔ
# < ꯖꯥꯕꯥꯔꯥꯔꯦ#
# > lucie
# = ꯂꯨꯁꯤ
# < ꯂꯨꯀꯤ#
# > thoujaldagi
# = ꯊꯧꯖꯥꯜꯗꯒꯤ
# < ꯊꯧꯖꯥꯜꯗꯒꯤ#
# > narayan
# = ꯅꯥꯔꯥꯌꯟ
# < ꯅꯔꯥꯟ#
# > makhoina
# = ꯃꯈꯣꯢꯅ
# < ꯃꯈꯣꯢꯅꯥ#
# > bristol
# = ꯕ꯭ꯔꯤꯁꯇꯜ
# < ꯔ꯭ꯔꯤꯁꯣ#
# > patil
# = ꯄꯥꯇꯤꯜ
# < ꯄꯥꯇꯂꯜ#
# > maiba
# = ꯃꯥꯢꯕ
# < ꯃꯥꯢꯕ#
# > humfunipan
# = ꯍꯨꯝꯐꯨꯅꯤꯄꯥꯟ
# < ꯍꯨꯝꯍꯨꯅꯅꯥꯄꯤ#
# > ngaangnarakliba
# = ꯉꯥꯡꯅꯔꯛꯂꯤꯕ
# < ꯉꯥꯡꯅꯔꯛꯂꯕꯤ#
# > suman
# = ꯁꯨꯃꯟ
# < ꯁꯨꯃꯟ#
# > tubi
# = ꯇꯨꯕꯤ
# < ꯇꯨꯕꯤ#
# > aster
# = ꯑꯦꯁꯇꯔ
# < ꯑꯁꯇꯦꯔ#
# > puyaasingdadi
# = ꯄꯨꯌꯥꯁꯤꯡꯗꯗꯤ
# < ꯄꯨꯌꯥꯡꯗꯗꯤꯡꯗ#
# > stephens
# = ꯁ꯭ꯇꯤꯕꯟꯁ
# < ꯁ꯭ꯦꯦꯦꯦꯦꯦꯦꯦꯁꯁꯁ#
# > registration
# = ꯔꯦꯖꯤꯁꯇ꯭ꯔꯦꯁꯟ
# < ꯔꯤꯔꯤꯁꯇꯤꯁꯣꯟ#
# > ahaanpa
# = ꯑꯍꯥꯟꯄ
# < ꯑꯍꯥꯟꯄꯥ#
# > yelhoungeigi
# = ꯌꯦꯜꯍꯧꯉꯩꯒꯤ
# < ꯌꯦꯍꯨꯡꯅꯒꯤ#
# > nagarjuna
# = ꯅꯥꯒꯥꯔꯖꯨꯅꯥ
# < ꯅꯥꯔꯖꯨꯅꯨ#
# > agarwal
# = ꯑꯒꯔꯋꯥꯜ
# < ꯑꯔꯔꯥꯋꯥꯜ#
# > udaipur
# = ꯎꯗꯦꯄꯨꯔ
# < ꯎꯗꯥꯢꯄꯔ#
# > artemis
# = ꯑꯥꯔꯇꯤꯃꯤꯁ
# < ꯑꯥꯇꯦꯃꯤꯁꯁ#
# > hill
# = ꯍꯤꯜ
# < ꯍꯤꯜ#
# > mathews
# = ꯃꯦꯊꯤꯎꯁ
# < ꯃꯊꯦꯛꯁ#
# > tougumbasung
# = ꯇꯧꯒꯨꯝꯕꯁꯨꯡ
# < ꯇꯧꯒꯨꯝꯕꯁꯡ#
# > thajanabigi
# = ꯊꯥꯖꯅꯕꯤꯒꯤ
# < ꯊꯥꯖꯤꯕꯒꯤ#
# > seithai
# = ꯁꯩꯊꯥꯢ
# < ꯁꯩꯊꯥꯢ#
# > marumsu
# = ꯃꯔꯨꯝꯁꯨ
# < ꯃꯔꯨꯞꯁꯨ#
# > etou
# = ꯏꯇꯧ
# < ꯏꯇꯧ#
# > patrick
# = ꯄꯦꯇ꯭ꯔꯤꯛ
# < ꯄꯥꯇꯤꯛ#
# > meghwal
# = ꯃꯦꯘ꯭ꯋꯥꯜ
# < ꯃꯦꯚꯥꯜ#
# > lemlei
# = ꯂꯦꯝꯂꯩ
# < ꯂꯦꯝꯂꯩ#
# > lehi
# = ꯂꯦꯍꯤ
# < ꯂꯦꯍꯤ#
# > chingshang
# = ꯆꯤꯡꯁꯥꯡ
# < ꯆꯤꯡꯁꯪ#
# > khaoda
# = ꯈꯥꯎꯗ
# < ꯈꯥꯎꯗ#
# > kaangbuni
# = ꯀꯥꯡꯕꯨꯅꯤ
# < ꯀꯥꯡꯕꯨꯅꯤ#
# > saaphaba
# = ꯁꯥꯐꯕ
# < ꯁꯥꯐꯕ#
# > sutlej
# = ꯁꯠꯂꯖ
# < ꯁꯨꯠꯂꯦꯕ#
# > chaturvedi
# = ꯆꯇꯨꯔꯕꯦꯗꯤ
# < ꯆꯇꯨꯔꯦꯔꯦꯗꯤ#
# > miraibai
# = ꯃꯤꯔꯥꯢꯕꯥꯢ
# < ꯃꯤꯔꯕꯤꯤ#
# > malik
# = ꯃꯂꯤꯛ
# < ꯃꯥꯂꯀꯤꯛ#
# > pham
# = ꯐꯥꯝ
# < ꯐꯝ#
# > hakchaangdagi
# = ꯍꯛꯆꯥꯡꯗꯒꯤ
# < ꯍꯛꯆꯪꯒꯒꯒꯤ#
# > barwani
# = ꯕꯥꯔꯋꯥꯅꯤ
# < ꯕꯔꯥꯢꯅꯤ#
# > fatehpur
# = ꯐꯇꯦꯍꯄꯨꯔ
# < ꯐ꯭ꯊꯨꯊꯇꯨꯔ#
# > phone
# = ꯐꯣꯟ
# < ꯐꯣꯅꯦ#
# Test Accuracy : 0.266113

# %%
print("Test Accuracy : %f" % (test_accuracy))
# Out:
# Test Accuracy : 0.266113

# %%
# Save the model
PATH = "./VanillaDec_models/"
torch.save(encoder.state_dict(),PATH+'encoder.pt')
torch.save(decoder.state_dict(),PATH+'decoder.pt')

# %%
input_size = input_lang.n_chrs
output_size = output_lang.n_chrs
embedding_size = 128
hidden_layer_size = 256
num_layers = 4
cell_type = 'LSTM'
dropout_prob = 0.1
learning_rate = 0.001
bidirectional = True
epochs = 10

encoder = EncoderRNN(input_size=input_size,embedding_size=embedding_size,hidden_layer_size=hidden_layer_size,num_encoder_layers=num_layers,cell_type=cell_type,dropout_prob=dropout_prob,bidirectional=bidirectional).to(device)
decoder = DecoderRNN(output_size=output_size,embedding_size=embedding_size,hidden_layer_size=hidden_layer_size,num_decoder_layers=num_layers,cell_type=cell_type,dropout_prob=dropout_prob,bidirectional=bidirectional).to(device)
encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate)
decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate)
criterion = nn.NLLLoss()
run(encoder,decoder,encoder_optimizer,decoder_optimizer,criterion,epochs)

# %%
test_accuracy,test_loss = eval_acc_test(encoder,decoder,test_pairs,criterion)
print("Test Accuracy : %f" % (test_accuracy))

# %%
print("Test Accuracy : %f" % (test_accuracy))

# %%
# Save the model
PATH = "./VanillaDec_models/"
torch.save(encoder.state_dict(),PATH+'encoder1.pt')
torch.save(decoder.state_dict(),PATH+'decoder1.pt')
