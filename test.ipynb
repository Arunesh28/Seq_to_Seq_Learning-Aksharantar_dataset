# %%
import csv
file1 = open('./predictions_vanilla/test_output.txt', 'r')
lines = file1.readlines()

lines = [x[2:-1] for x in lines]
# print(lines)


i = 0
while(i+2<len(lines)):
    # info = [lines[i],lines[i+2][:-1]]
    if lines[i+1] == lines[i+2][:-1]:
        # for j in [0,1,2]:
        #     print(lines[i+j])
        print(">",lines[i])
        print("=",lines[i+1])
        print(">",lines[i+2][:-1])
        print()
    i += 3
# Out:
# > pakhangpana
# = ꯄꯥꯈꯪꯄꯅ
# > ꯄꯥꯈꯪꯄꯅ
#
# > famdengba
# = ꯐꯝꯗꯦꯡꯕ
# > ꯐꯝꯗꯦꯡꯕ
#
# > phampalda
# = ꯐꯝꯄꯥꯜꯗ
# > ꯐꯝꯄꯥꯜꯗ
#
# > londada
# = ꯂꯣꯟꯗꯥꯗ
# > ꯂꯣꯟꯗꯥꯗ
#
# > mut
# = ꯃꯨꯠ
# > ꯃꯨꯠ
#
# > sanpa
# = ꯁꯥꯟꯄ
# > ꯁꯥꯟꯄ
#
# > challi
# = ꯆꯜꯂꯤ
# > ꯆꯜꯂꯤ
#
# > pambei
# = ꯄꯥꯝꯕꯩ
# > ꯄꯥꯝꯕꯩ
#
# > laanngamduna
# = ꯂꯥꯟꯉꯝꯗꯨꯅ
# > ꯂꯥꯟꯉꯝꯗꯨꯅ
#
# > ngaareima
# = ꯉꯥꯔꯩꯃ
# > ꯉꯥꯔꯩꯃ
#
# > mirolgi
# = ꯃꯤꯔꯣꯜꯒꯤ
# > ꯃꯤꯔꯣꯜꯒꯤ
#
# > manna
# = ꯃꯥꯟꯅ
# > ꯃꯥꯟꯅ
#
# > fanglakkhi
# = ꯐꯪꯂꯛꯈꯤ
# > ꯐꯪꯂꯛꯈꯤ
#
# > yambada
# = ꯌꯥꯝꯕꯗ
# > ꯌꯥꯝꯕꯗ
#
# > ima
# = ꯏꯃꯥ
# > ꯏꯃꯥ
#
# > nemba
# = ꯅꯦꯝꯕ
# > ꯅꯦꯝꯕ
#
# > lara
# = ꯂꯥꯔꯥ
# > ꯂꯥꯔꯥ
#
# > ten
# = ꯇꯦꯟ
# > ꯇꯦꯟ
#
# > saruk
# = ꯁꯔꯨꯛ
# > ꯁꯔꯨꯛ
#
# > saada
# = ꯁꯥꯗ
# > ꯁꯥꯗ
#
# > leiphamna
# = ꯂꯩꯐꯝꯅ
# > ꯂꯩꯐꯝꯅ
#
# > waareng
# = ꯋꯥꯔꯦꯡ
# > ꯋꯥꯔꯦꯡ
#
# > asuppa
# = ꯑꯁꯨꯞꯄ
# > ꯑꯁꯨꯞꯄ
#
# > kangbagi
# = ꯀꯪꯕꯒꯤ
# > ꯀꯪꯕꯒꯤ
#
# > tolli
# = ꯇꯣꯜꯂꯤ
# > ꯇꯣꯜꯂꯤ
#
# > chingsinfam
# = ꯆꯤꯡꯁꯤꯟꯐꯝ
# > ꯆꯤꯡꯁꯤꯟꯐꯝ
#
# > thamphamni
# = ꯊꯝꯐꯝꯅꯤ
# > ꯊꯝꯐꯝꯅꯤ
#
# > parag
# = ꯄꯔꯥꯒ
# > ꯄꯔꯥꯒ
#
# > telheipagi
# = ꯇꯦꯜꯍꯩꯄꯒꯤ
# > ꯇꯦꯜꯍꯩꯄꯒꯤ
#
# ...
